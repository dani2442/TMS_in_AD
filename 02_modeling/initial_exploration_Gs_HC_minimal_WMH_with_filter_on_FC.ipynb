# %%
# Note that all the code is basically taken from Gustavo Patow's WholeBrain module (https://github.com/dagush/WholeBrain)

# Load all the packages needed for analyses
import sys
import numpy as np
import scipy.io as sio
from numba import jit
import matplotlib.pyplot as plt
import pickle

# Set up Hopf as our model 
import WholeBrain.Models.supHopf as Hopf
from WholeBrain.simulate_SimOnly import Tmaxneuronal
Hopf.initialValue = 0.1
neuronalModel = Hopf

# Set up our integrator
import WholeBrain.Integrator_EulerMaruyama as myIntegrator
integrator = myIntegrator
integrator.neuronalModel = neuronalModel
integrator.verbose = False
integrator.clamping = False

# Set up the integration parameters
dt = 5e-5
# tmax is equal to the number of timepoints: 193
tmax= 193
ds = 1e-4
Tmaxneuronal = int((tmax+dt))

import WholeBrain.simulate_SimOnly as simulateBOLD
simulateBOLD.warmUp = True
simulateBOLD.integrator = integrator
simulateBOLD.warmUpFactor = 606./2000.

# Set up the code to obtain the variables we want to maximize similarity to empirical FC
import WholeBrain.Observables.FC as FC
import WholeBrain.Observables.phFCD as phFCD
import WholeBrain.Optimizers.ParmSeep as ParmSeep
ParmSeep.simulateBOLD = simulateBOLD
ParmSeep.integrator = integrator
ParmSeep.verbose = True

# set BOLD filter settings
import WholeBrain.Utils.filteredPowerSpectralDensity as filtPowSpectr
import WholeBrain.BOLDFilters as BOLDfilters

# These filters are applied in the filtPowSpectr function that we use to extract the intrinsic frequencies of each region.
# They are also applied to process the FC and swFCD and phFCD, but you can set the corresponding parameter to False later on. 0.04-0.07 Hz common to extract intrinsic frequencies
BOLDfilters.flp = 0.04
BOLDfilters.fhi = 0.07
BOLDfilters.TR = 3.0

# Get the list of names of all regions in the AAL atlas. This is needed to get the right indices, to then filter the FC
import csv
# This is a sublist of labels of the cortical regions that were included in the paper by Demirtas et al. - AAL atlas (78 regions, excluding infratentorial and deep)
with open ('/home/riccardo/ADNI_Hopf/Utils/aal_regions_included.csv', newline='') as f:
    new_reader = csv.reader(f)
    included_regions = list(new_reader)
f.close()

# Get the AAL atlas labels
import nilearn.datasets as datasets
aal = datasets.fetch_atlas_aal()
labels = np.array(aal.labels)
# create an array with the indices of each label (note that these are not the label number from the nifti image)
indices = np.array([i for i in enumerate(labels)])
SC_regions_index = np.isin(labels, included_regions)
# filter the indices that we want based on the position so to have a final SC matrix only for the regions we considered.
SC_78_regions_aal_atlas = indices[SC_regions_index]
filter_SC = np.array([int(i) for i in SC_78_regions_aal_atlas[:,0]])

# Set file path for SC matrix
x_path = '/home/riccardo/ADNI_Hopf/Utils/'
# Load structural connectivity matrix and use it as parameter in Hopf model
xfile = 'SCmatrices88healthy.mat' 
M = sio.loadmat(x_path + xfile); 
mat = M['SCmatrices']
# averaging the SC among subjects
mat0 = np.mean(mat,axis = 0)
# Filter the SC to have just the 78 regions we considered
x_mat0 = mat0[filter_SC]
new_mat0 = x_mat0.T[filter_SC]
# Prevent full synchronization of the model
SCnorm = new_mat0 * 0.2 / new_mat0.max() 
np.fill_diagonal(SCnorm,0)
print('SCnorm.shape={}'.format(new_mat0.shape))    
Hopf.setParms({'SC':SCnorm})

# Set the base_a_value to the same as previous studies
base_a_value = -0.02
# We want to warmup the timeseries before modeling
warmUp = True
warmUpFactor = 10.
# Out:
# SCnorm.shape=(78, 78)

# %%
# ------------------------------------------------
# Configure and compute Simulation for fixed a = -0.02 and fitting G to HC to find the best G
# ------------------------------------------------
# Load the list of names for all HC
list_HC = np.load('/home/riccardo/ADNI_Hopf/Results/subject_list_timeseries_HC.npy')
# Load the list of names for the selected HC with minimal WMH
filter_HC = np.load('/home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/subject_list_wmh_volumes_HC_minimal.npy', allow_pickle = True).flatten()
# Get the indices of the selected HC with minimal WMH
timeseries_idx = [idx for idx, sub in enumerate(list_HC) if sub in filter_HC]
# Load the timeseries for all HC
timeseries_all = np.load('/home/riccardo/ADNI_Hopf/Results/timeseries_HC.npy')
# Filter the timeseries of all HC to obtain just the selected HC with minimal WMH
timeseries = timeseries_all[timeseries_idx]
nsubjects, nNodes, Tmax = timeseries.shape
all_fMRI = {s: d for s,d in enumerate(timeseries)} 

simulateBOLD.TR = 3.  # Recording interval: 1 sample every 3 seconds
simulateBOLD.dt = 0.1 * simulateBOLD.TR / 2.
simulateBOLD.Tmax = Tmax  # This is the length, in seconds
simulateBOLD.dtt = simulateBOLD.TR  # We are not using milliseconds
simulateBOLD.t_min = 10 * simulateBOLD.TR
# simulateBOLD.recomputeTmaxneuronal() <- do not update Tmaxneuronal this way!
# simulateBOLD.warmUpFactor = 6.
simulateBOLD.Tmaxneuronal = (Tmax-1) * simulateBOLD.TR + 30
integrator.ds = simulateBOLD.TR  # record every TR millisecond

base_a_value = -0.02
# Hopf.beta = 0.01
f_diff = filtPowSpectr.filtPowSpetraMultipleSubjects(timeseries, TR=3.)  # should be baseline_group_ts .. or baseling_group[0].reshape((1,52,193))
f_diff[np.where(f_diff == 0)] = np.mean(f_diff[np.where(f_diff != 0)])  # f_diff(find(f_diff==0))=mean(f_diff(find(f_diff~=0)))

Hopf.setParms({'a': base_a_value})
Hopf.omega = 2 * np.pi * f_diff

print("ADHopf Setup done!")
# Out:
# filtPowSpetraMultipleSubjects: subject 0 (of 3)
# filtPowSpetraMultipleSubjects: subject 1 (of 3)
# filtPowSpetraMultipleSubjects: subject 2 (of 3)
# ADHopf Setup done!

# %%
warmUp = True
warmUpFactor = 10.

subjectName = ''
conditionToStudy='hc'
mode = 'homogeneous'  # homogeneous/heterogeneous
# Since we haven't filtered the data in the previous step from Nilearn, we are going to filter them. 
distanceSettings = {'FC': (FC, True), 'phFCD': (phFCD, True)}

def computeSubjectSimulation():
    # integrator.neuronalModel.SC = C
    # integrator.initBookkeeping(N, Tmaxneuronal)
    if warmUp:
        currObsVars = integrator.warmUpAndSimulate(dt, Tmaxneuronal, TWarmUp=Tmaxneuronal/warmUpFactor)
    else:
        currObsVars = integrator.simulate(dt, Tmaxneuronal)
    # currObsVars = integrator.returnBookkeeping()  # curr_xn, curr_rn
    neuro_act = currObsVars[:,1,:]  # curr_rn
    return neuro_act
    
outFilePath = '/home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/Finding_the_best_G/filter_0.04-0.07_initial/'

Gs = np.round(np.arange(0.5,5,0.05),3)

def fittingPipeline_homogeneous(all_fMRI,
                    distanceSettings,  # This is a dictionary of {name: (distance module, apply filters bool)}
                    gs):
    print("\n\n###################################################################")
    print("# Fitting with ParmSeep")
    print("###################################################################\n")
    # Now, optimize all we (G) values: determine optimal G to work with
    gParms = [{'we': g} for g in Gs]
    fitting = ParmSeep.distanceForAll_Parms(all_fMRI,
                                            Gs, 
                                            gParms,
                                            NumSimSubjects=10,
                                            distanceSettings=distanceSettings,
                                            parmLabel='finding_best_G_',
                                            outFilePath=outFilePath)

    optimal = {sd: distanceSettings[sd][0].findMinMax(fitting[sd]) for sd in distanceSettings}
    return optimal, fitting

best_parameters, fitting = fittingPipeline_homogeneous(all_fMRI=all_fMRI, distanceSettings=distanceSettings, gs=Gs)

import matplotlib.pyplot as plt

for ds in distanceSettings:
          plt.plot(Gs, fitting[ds], label = ds)
          plt.legend()
          optimValDist = distanceSettings[ds][0].findMinMax(fitting[ds])
          parmPos = [a for a in np.nditer(Gs)][optimValDist[1]]
          print(f"# Optimal {ds} =     {optimValDist[0]} @ {np.round(parmPos, decimals=3)}")
plt.savefig(outFilePath + '/initial_exploration_plot.png')
# Out:
# ###################################################################
# # Fitting with ParmSeep
# ###################################################################
#
#
#
# *************** Starting: optim1D.distanceForAll_Parms *****************
#
#
# tc(3 subjects): each entry has N=78 regions
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/Finding_the_best_G/filter_0.04-0.07_initial//fNeuro_emp.mat
#    Processing signal 1/3 Subject: 0 (78x193) -> computed in 4.415037607999693 seconds
#    Processing signal 2/3 Subject: 1 (78x193) -> computed in 3.7334510349974153 seconds
#    Processing signal 3/3 Subject: 2 (78x193) -> computed in 3.4379541100061033 seconds
#
#
#  ====================== Model Simulations ======================
#
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/Finding_the_best_G/filter_0.04-0.07_initial//fitting_finding_best_G_0.5.mat
#    --- BEGIN TIME @ finding_best_G_=0.5 ---
# Current a is: -0.02
# Current G is: 0.5
#    Simulating finding_best_G_=0.5 -> subject 0/10!!!
#    Simulating finding_best_G_=0.5 -> subject 1/10!!!
#    Simulating finding_best_G_=0.5 -> subject 2/10!!!
#    Simulating finding_best_G_=0.5 -> subject 3/10!!!
#    Simulating finding_best_G_=0.5 -> subject 4/10!!!
#    Simulating finding_best_G_=0.5 -> subject 5/10!!!
#    Simulating finding_best_G_=0.5 -> subject 6/10!!!
#    Simulating finding_best_G_=0.5 -> subject 7/10!!!
#    Simulating finding_best_G_=0.5 -> subject 8/10!!!
#    Simulating finding_best_G_=0.5 -> subject 9/10!!!
#    Processing signal 1/10 Subject: 0 (78x193) -> computed in 3.516954019003606 seconds
#    Processing signal 2/10 Subject: 1 (78x193) -> computed in 3.58028068299609 seconds
#    Processing signal 3/10 Subject: 2 (78x193) -> computed in 3.738979235997249 seconds
#    Processing signal 4/10 Subject: 3 (78x193) -> computed in 3.7273877810002887 seconds
#    Processing signal 5/10 Subject: 4 (78x193) -> computed in 3.746260572996107 seconds
#    Processing signal 6/10 Subject: 5 (78x193) -> computed in 3.3958012590010185 seconds
#    Processing signal 7/10 Subject: 6 (78x193) -> computed in 3.3431093230028637 seconds
#    Processing signal 8/10 Subject: 7 (78x193) -> computed in 3.3462469229998533 seconds
#    Processing signal 9/10 Subject: 8 (78x193) -> computed in 3.4143448819959303 seconds
#    Processing signal 10/10 Subject: 9 (78x193) -> computed in 3.5443539359985152 seconds
#    --- TOTAL TIME: 38.2702772709963 seconds ---
# #0/1: FC: 0.309916761200926; phFCD: 0.6565574142073529;
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/Finding_the_best_G/filter_0.04-0.07_initial//fitting_finding_best_G_0.55.mat
#    --- BEGIN TIME @ finding_best_G_=0.55 ---
# Current a is: -0.02
# Current G is: 0.55
#    Simulating finding_best_G_=0.55 -> subject 0/10!!!
#    Simulating finding_best_G_=0.55 -> subject 1/10!!!
#    Simulating finding_best_G_=0.55 -> subject 2/10!!!
#    Simulating finding_best_G_=0.55 -> subject 3/10!!!
#    Simulating finding_best_G_=0.55 -> subject 4/10!!!
#    Simulating finding_best_G_=0.55 -> subject 5/10!!!
#    Simulating finding_best_G_=0.55 -> subject 6/10!!!
#    Simulating finding_best_G_=0.55 -> subject 7/10!!!
#    Simulating finding_best_G_=0.55 -> subject 8/10!!!
#    Simulating finding_best_G_=0.55 -> subject 9/10!!!
#    Processing signal 1/10 Subject: 0 (78x193) -> computed in 3.6854453739942983 seconds
#    Processing signal 2/10 Subject: 1 (78x193) -> computed in 3.6780710730017745 seconds
#    Processing signal 3/10 Subject: 2 (78x193) -> computed in 3.50674977300514 seconds
#    Processing signal 4/10 Subject: 3 (78x193) -> computed in 3.4696322090021567 seconds
#    Processing signal 5/10 Subject: 4 (78x193) -> computed in 3.5714254080012324 seconds
#    Processing signal 6/10 Subject: 5 (78x193) -> computed in 3.439966132005793 seconds
#    Processing signal 7/10 Subject: 6 (78x193) -> computed in 3.4407924990009633 seconds
#    Processing signal 8/10 Subject: 7 (78x193) -> computed in 3.7988148200020078 seconds
#    Processing signal 9/10 Subject: 8 (78x193) -> computed in 3.693548338000255 seconds
#    Processing signal 10/10 Subject: 9 (78x193) -> computed in 4.293694277999748 seconds
#    --- TOTAL TIME: 39.2966817320048 seconds ---
# #1/1: FC: 0.375916387382186; phFCD: 0.6287161702706379;
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/Finding_the_best_G/filter_0.04-0.07_initial//fitting_finding_best_G_0.6.mat
#    --- BEGIN TIME @ finding_best_G_=0.6 ---
# Current a is: -0.02
# Current G is: 0.6
#    Simulating finding_best_G_=0.6 -> subject 0/10!!!
#    Simulating finding_best_G_=0.6 -> subject 1/10!!!
#    Simulating finding_best_G_=0.6 -> subject 2/10!!!
#    Simulating finding_best_G_=0.6 -> subject 3/10!!!
#    Simulating finding_best_G_=0.6 -> subject 4/10!!!
#    Simulating finding_best_G_=0.6 -> subject 5/10!!!
#    Simulating finding_best_G_=0.6 -> subject 6/10!!!
#    Simulating finding_best_G_=0.6 -> subject 7/10!!!
#    Simulating finding_best_G_=0.6 -> subject 8/10!!!
#    Simulating finding_best_G_=0.6 -> subject 9/10!!!
#    Processing signal 1/10 Subject: 0 (78x193) -> computed in 3.7993086209971807 seconds
#    Processing signal 2/10 Subject: 1 (78x193) -> computed in 3.9533131119969767 seconds
#    Processing signal 3/10 Subject: 2 (78x193) -> computed in 3.706965138997475 seconds
#    Processing signal 4/10 Subject: 3 (78x193) -> computed in 3.683137678002822 seconds
#    Processing signal 5/10 Subject: 4 (78x193) -> computed in 3.4244771209996543 seconds
#    Processing signal 6/10 Subject: 5 (78x193) -> computed in 3.7051099710006383 seconds
#    Processing signal 7/10 Subject: 6 (78x193) -> computed in 3.715317018002679 seconds
#    Processing signal 8/10 Subject: 7 (78x193) -> computed in 3.8866501829979825 seconds
#    Processing signal 9/10 Subject: 8 (78x193) -> computed in 3.6057601159991464 seconds
#    Processing signal 10/10 Subject: 9 (78x193) -> computed in 3.815210417000344 seconds
#    --- TOTAL TIME: 39.848122576993774 seconds ---
# #2/1: FC: 0.336099838201557; phFCD: 0.6472641552200916;
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/Finding_the_best_G/filter_0.04-0.07_initial//fitting_finding_best_G_0.65.mat
#    --- BEGIN TIME @ finding_best_G_=0.65 ---
# Current a is: -0.02
# Current G is: 0.65
#    Simulating finding_best_G_=0.65 -> subject 0/10!!!
#    Simulating finding_best_G_=0.65 -> subject 1/10!!!
#    Simulating finding_best_G_=0.65 -> subject 2/10!!!
#    Simulating finding_best_G_=0.65 -> subject 3/10!!!
#    Simulating finding_best_G_=0.65 -> subject 4/10!!!
#    Simulating finding_best_G_=0.65 -> subject 5/10!!!
#    Simulating finding_best_G_=0.65 -> subject 6/10!!!
#    Simulating finding_best_G_=0.65 -> subject 7/10!!!
#    Simulating finding_best_G_=0.65 -> subject 8/10!!!
#    Simulating finding_best_G_=0.65 -> subject 9/10!!!
#    Processing signal 1/10 Subject: 0 (78x193) -> computed in 3.5755470160002005 seconds
#    Processing signal 2/10 Subject: 1 (78x193) -> computed in 3.4544270129990764 seconds
#    Processing signal 3/10 Subject: 2 (78x193) -> computed in 3.642759327995009 seconds
#    Processing signal 4/10 Subject: 3 (78x193) -> computed in 3.8274849350054865 seconds
#    Processing signal 5/10 Subject: 4 (78x193) -> computed in 3.574045239998668 seconds
#    Processing signal 6/10 Subject: 5 (78x193) -> computed in 3.5437634990012157 seconds
#    Processing signal 7/10 Subject: 6 (78x193) -> computed in 3.318109612002445 seconds
#    Processing signal 8/10 Subject: 7 (78x193) -> computed in 3.186224522003613 seconds
#    Processing signal 9/10 Subject: 8 (78x193) -> computed in 3.6903859929952887 seconds
#    Processing signal 10/10 Subject: 9 (78x193) -> computed in 3.3176234179991297 seconds
#    --- TOTAL TIME: 37.53414116700151 seconds ---
# #3/1: FC: 0.34661217029659547; phFCD: 0.6295162972029558;
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/Finding_the_best_G/filter_0.04-0.07_initial//fitting_finding_best_G_0.7.mat
#    --- BEGIN TIME @ finding_best_G_=0.7 ---
# Current a is: -0.02
# Current G is: 0.7
#    Simulating finding_best_G_=0.7 -> subject 0/10!!!
#    Simulating finding_best_G_=0.7 -> subject 1/10!!!
#    Simulating finding_best_G_=0.7 -> subject 2/10!!!
#    Simulating finding_best_G_=0.7 -> subject 3/10!!!
#    Simulating finding_best_G_=0.7 -> subject 4/10!!!
#    Simulating finding_best_G_=0.7 -> subject 5/10!!!
#    Simulating finding_best_G_=0.7 -> subject 6/10!!!
#    Simulating finding_best_G_=0.7 -> subject 7/10!!!
#    Simulating finding_best_G_=0.7 -> subject 8/10!!!
#    Simulating finding_best_G_=0.7 -> subject 9/10!!!
#    Processing signal 1/10 Subject: 0 (78x193) -> computed in 3.412026728001365 seconds
#    Processing signal 2/10 Subject: 1 (78x193) -> computed in 3.687912415996834 seconds
#    Processing signal 3/10 Subject: 2 (78x193) -> computed in 3.610672753005929 seconds
#    Processing signal 4/10 Subject: 3 (78x193) -> computed in 3.6856599649981945 seconds
#    Processing signal 5/10 Subject: 4 (78x193) -> computed in 3.7371134470013203 seconds
#    Processing signal 6/10 Subject: 5 (78x193) -> computed in 3.9266183329964406 seconds
#    Processing signal 7/10 Subject: 6 (78x193) -> computed in 3.7985549989971332 seconds
#    Processing signal 8/10 Subject: 7 (78x193) -> computed in 3.573495354001352 seconds
#    Processing signal 9/10 Subject: 8 (78x193) -> computed in 3.5647247470042203 seconds
#    Processing signal 10/10 Subject: 9 (78x193) -> computed in 3.5142585180001333 seconds
#    --- TOTAL TIME: 38.88523493100365 seconds ---
# #4/1: FC: 0.3335982678378021; phFCD: 0.6132780271091165;
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/Finding_the_best_G/filter_0.04-0.07_initial//fitting_finding_best_G_0.75.mat
#    --- BEGIN TIME @ finding_best_G_=0.75 ---
# Current a is: -0.02
# Current G is: 0.75
#    Simulating finding_best_G_=0.75 -> subject 0/10!!!
#    Simulating finding_best_G_=0.75 -> subject 1/10!!!
#    Simulating finding_best_G_=0.75 -> subject 2/10!!!
#    Simulating finding_best_G_=0.75 -> subject 3/10!!!
#    Simulating finding_best_G_=0.75 -> subject 4/10!!!
#    Simulating finding_best_G_=0.75 -> subject 5/10!!!
#    Simulating finding_best_G_=0.75 -> subject 6/10!!!
#    Simulating finding_best_G_=0.75 -> subject 7/10!!!
#    Simulating finding_best_G_=0.75 -> subject 8/10!!!
#    Simulating finding_best_G_=0.75 -> subject 9/10!!!
#    Processing signal 1/10 Subject: 0 (78x193) -> computed in 3.584752317001403 seconds
#    Processing signal 2/10 Subject: 1 (78x193) -> computed in 4.083219708998513 seconds
#    Processing signal 3/10 Subject: 2 (78x193) -> computed in 3.522971131998929 seconds
#    Processing signal 4/10 Subject: 3 (78x193) -> computed in 3.6351785310034757 seconds
#    Processing signal 5/10 Subject: 4 (78x193) -> computed in 3.4924949620035477 seconds
#    Processing signal 6/10 Subject: 5 (78x193) -> computed in 3.6048255610003253 seconds
#    Processing signal 7/10 Subject: 6 (78x193) -> computed in 3.323610118997749 seconds
#    Processing signal 8/10 Subject: 7 (78x193) -> computed in 3.091420307995577 seconds
#    Processing signal 9/10 Subject: 8 (78x193) -> computed in 3.289971099999093 seconds
#    Processing signal 10/10 Subject: 9 (78x193) -> computed in 3.361793793999823 seconds
#    --- TOTAL TIME: 37.41078727599961 seconds ---
# #5/1: FC: 0.35103074951696195; phFCD: 0.597001223990208;
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/Finding_the_best_G/filter_0.04-0.07_initial//fitting_finding_best_G_0.8.mat
#    --- BEGIN TIME @ finding_best_G_=0.8 ---
# Current a is: -0.02
# Current G is: 0.8
#    Simulating finding_best_G_=0.8 -> subject 0/10!!!
#    Simulating finding_best_G_=0.8 -> subject 1/10!!!
#    Simulating finding_best_G_=0.8 -> subject 2/10!!!
#    Simulating finding_best_G_=0.8 -> subject 3/10!!!
#    Simulating finding_best_G_=0.8 -> subject 4/10!!!
#    Simulating finding_best_G_=0.8 -> subject 5/10!!!
#    Simulating finding_best_G_=0.8 -> subject 6/10!!!
#    Simulating finding_best_G_=0.8 -> subject 7/10!!!
#    Simulating finding_best_G_=0.8 -> subject 8/10!!!
#    Simulating finding_best_G_=0.8 -> subject 9/10!!!
#    Processing signal 1/10 Subject: 0 (78x193) -> computed in 3.425892881001346 seconds
#    Processing signal 2/10 Subject: 1 (78x193) -> computed in 3.455862081005762 seconds
#    Processing signal 3/10 Subject: 2 (78x193) -> computed in 3.3927171989998897 seconds
#    Processing signal 4/10 Subject: 3 (78x193) -> computed in 3.404365898000833 seconds
#    Processing signal 5/10 Subject: 4 (78x193) -> computed in 3.5047124289994827 seconds
#    Processing signal 6/10 Subject: 5 (78x193) -> computed in 3.517354242998408 seconds
#    Processing signal 7/10 Subject: 6 (78x193) -> computed in 3.6607239930017386 seconds
#    Processing signal 8/10 Subject: 7 (78x193) -> computed in 3.3679652540013194 seconds
#    Processing signal 9/10 Subject: 8 (78x193) -> computed in 3.4097594729973935 seconds
#    Processing signal 10/10 Subject: 9 (78x193) -> computed in 3.295484511007089 seconds
#    --- TOTAL TIME: 36.847259383001074 seconds ---
# #6/1: FC: 0.3275080497692613; phFCD: 0.5802824244072714;
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/Finding_the_best_G/filter_0.04-0.07_initial//fitting_finding_best_G_0.85.mat
#    --- BEGIN TIME @ finding_best_G_=0.85 ---
# Current a is: -0.02
# Current G is: 0.85
#    Simulating finding_best_G_=0.85 -> subject 0/10!!!
#    Simulating finding_best_G_=0.85 -> subject 1/10!!!
#    Simulating finding_best_G_=0.85 -> subject 2/10!!!
#    Simulating finding_best_G_=0.85 -> subject 3/10!!!
#    Simulating finding_best_G_=0.85 -> subject 4/10!!!
#    Simulating finding_best_G_=0.85 -> subject 5/10!!!
#    Simulating finding_best_G_=0.85 -> subject 6/10!!!
#    Simulating finding_best_G_=0.85 -> subject 7/10!!!
#    Simulating finding_best_G_=0.85 -> subject 8/10!!!
#    Simulating finding_best_G_=0.85 -> subject 9/10!!!
#    Processing signal 1/10 Subject: 0 (78x193) -> computed in 3.9517053599993233 seconds
#    Processing signal 2/10 Subject: 1 (78x193) -> computed in 3.41247211600421 seconds
#    Processing signal 3/10 Subject: 2 (78x193) -> computed in 3.378277719995822 seconds
#    Processing signal 4/10 Subject: 3 (78x193) -> computed in 3.295637908995559 seconds
#    Processing signal 5/10 Subject: 4 (78x193) -> computed in 3.243127027999435 seconds
#    Processing signal 6/10 Subject: 5 (78x193) -> computed in 3.308980720998079 seconds
#    Processing signal 7/10 Subject: 6 (78x193) -> computed in 3.2626906329969643 seconds
#    Processing signal 8/10 Subject: 7 (78x193) -> computed in 3.3928580090068863 seconds
#    Processing signal 9/10 Subject: 8 (78x193) -> computed in 3.2947263599999133 seconds
#    Processing signal 10/10 Subject: 9 (78x193) -> computed in 3.459901519003324 seconds
#    --- TOTAL TIME: 36.571554949005076 seconds ---
# #7/1: FC: 0.3566877947304381; phFCD: 0.5394623509678589;
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/Finding_the_best_G/filter_0.04-0.07_initial//fitting_finding_best_G_0.9.mat
#    --- BEGIN TIME @ finding_best_G_=0.9 ---
# Current a is: -0.02
# Current G is: 0.9
#    Simulating finding_best_G_=0.9 -> subject 0/10!!!
#    Simulating finding_best_G_=0.9 -> subject 1/10!!!
#    Simulating finding_best_G_=0.9 -> subject 2/10!!!
#    Simulating finding_best_G_=0.9 -> subject 3/10!!!
#    Simulating finding_best_G_=0.9 -> subject 4/10!!!
#    Simulating finding_best_G_=0.9 -> subject 5/10!!!
#    Simulating finding_best_G_=0.9 -> subject 6/10!!!
#    Simulating finding_best_G_=0.9 -> subject 7/10!!!
#    Simulating finding_best_G_=0.9 -> subject 8/10!!!
#    Simulating finding_best_G_=0.9 -> subject 9/10!!!
#    Processing signal 1/10 Subject: 0 (78x193) -> computed in 3.433013370995468 seconds
#    Processing signal 2/10 Subject: 1 (78x193) -> computed in 3.377045075998467 seconds
#    Processing signal 3/10 Subject: 2 (78x193) -> computed in 3.6031344500006526 seconds
#    Processing signal 4/10 Subject: 3 (78x193) -> computed in 3.484298536001006 seconds
#    Processing signal 5/10 Subject: 4 (78x193) -> computed in 3.4273784729957697 seconds
#    Processing signal 6/10 Subject: 5 (78x193) -> computed in 3.3906567599988193 seconds
#    Processing signal 7/10 Subject: 6 (78x193) -> computed in 3.9471918209965224 seconds
#    Processing signal 8/10 Subject: 7 (78x193) -> computed in 3.5685998990011285 seconds
#    Processing signal 9/10 Subject: 8 (78x193) -> computed in 3.608916103003139 seconds
#    Processing signal 10/10 Subject: 9 (78x193) -> computed in 3.3675138739999966 seconds
#    --- TOTAL TIME: 37.75270306799939 seconds ---
# #8/1: FC: 0.34704591947404884; phFCD: 0.5238882088943289;
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/Finding_the_best_G/filter_0.04-0.07_initial//fitting_finding_best_G_0.95.mat
#    --- BEGIN TIME @ finding_best_G_=0.95 ---
# Current a is: -0.02
# Current G is: 0.95
#    Simulating finding_best_G_=0.95 -> subject 0/10!!!
#    Simulating finding_best_G_=0.95 -> subject 1/10!!!
#    Simulating finding_best_G_=0.95 -> subject 2/10!!!
#    Simulating finding_best_G_=0.95 -> subject 3/10!!!
#    Simulating finding_best_G_=0.95 -> subject 4/10!!!
#    Simulating finding_best_G_=0.95 -> subject 5/10!!!
#    Simulating finding_best_G_=0.95 -> subject 6/10!!!
#    Simulating finding_best_G_=0.95 -> subject 7/10!!!
#    Simulating finding_best_G_=0.95 -> subject 8/10!!!
#    Simulating finding_best_G_=0.95 -> subject 9/10!!!
#    Processing signal 1/10 Subject: 0 (78x193) -> computed in 3.551078634998703 seconds
#    Processing signal 2/10 Subject: 1 (78x193) -> computed in 3.4720986430038465 seconds
#    Processing signal 3/10 Subject: 2 (78x193) -> computed in 3.337733508000383 seconds
#    Processing signal 4/10 Subject: 3 (78x193) -> computed in 3.4612332969991257 seconds
#    Processing signal 5/10 Subject: 4 (78x193) -> computed in 3.3219412179969368 seconds
#    Processing signal 6/10 Subject: 5 (78x193) -> computed in 3.3746690270054387 seconds
#    Processing signal 7/10 Subject: 6 (78x193) -> computed in 3.4845359059982 seconds
#    Processing signal 8/10 Subject: 7 (78x193) -> computed in 3.483234071994957 seconds
#    Processing signal 9/10 Subject: 8 (78x193) -> computed in 3.612166518003505 seconds
#    Processing signal 10/10 Subject: 9 (78x193) -> computed in 3.460575572004018 seconds
#    --- TOTAL TIME: 37.0086646560012 seconds ---
# #9/1: FC: 0.3801530321466714; phFCD: 0.5485176118591051;
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/Finding_the_best_G/filter_0.04-0.07_initial//fitting_finding_best_G_1.0.mat
#    --- BEGIN TIME @ finding_best_G_=1.0 ---
# Current a is: -0.02
# Current G is: 1.0
#    Simulating finding_best_G_=1.0 -> subject 0/10!!!
#    Simulating finding_best_G_=1.0 -> subject 1/10!!!
#    Simulating finding_best_G_=1.0 -> subject 2/10!!!
#    Simulating finding_best_G_=1.0 -> subject 3/10!!!
#    Simulating finding_best_G_=1.0 -> subject 4/10!!!
#    Simulating finding_best_G_=1.0 -> subject 5/10!!!
#    Simulating finding_best_G_=1.0 -> subject 6/10!!!
#    Simulating finding_best_G_=1.0 -> subject 7/10!!!
#    Simulating finding_best_G_=1.0 -> subject 8/10!!!
#    Simulating finding_best_G_=1.0 -> subject 9/10!!!
#    Processing signal 1/10 Subject: 0 (78x193) -> computed in 3.6350498419997166 seconds
#    Processing signal 2/10 Subject: 1 (78x193) -> computed in 3.536507821001578 seconds
#    Processing signal 3/10 Subject: 2 (78x193) -> computed in 3.905757537999307 seconds
#    Processing signal 4/10 Subject: 3 (78x193) -> computed in 3.3266855649999343 seconds
#    Processing signal 5/10 Subject: 4 (78x193) -> computed in 3.2817114460049197 seconds
#    Processing signal 6/10 Subject: 5 (78x193) -> computed in 3.3260814550012583 seconds
#    Processing signal 7/10 Subject: 6 (78x193) -> computed in 3.179949794001004 seconds
#    Processing signal 8/10 Subject: 7 (78x193) -> computed in 3.2133452929992927 seconds
#    Processing signal 9/10 Subject: 8 (78x193) -> computed in 3.265876997000305 seconds
#    Processing signal 10/10 Subject: 9 (78x193) -> computed in 3.1500670749956043 seconds
#    --- TOTAL TIME: 36.53982289900159 seconds ---
# #10/1: FC: 0.35029783133908626; phFCD: 0.5326420055306225;
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/Finding_the_best_G/filter_0.04-0.07_initial//fitting_finding_best_G_1.05.mat
#    --- BEGIN TIME @ finding_best_G_=1.05 ---
# Current a is: -0.02
# Current G is: 1.05
#    Simulating finding_best_G_=1.05 -> subject 0/10!!!
#    Simulating finding_best_G_=1.05 -> subject 1/10!!!
#    Simulating finding_best_G_=1.05 -> subject 2/10!!!
#    Simulating finding_best_G_=1.05 -> subject 3/10!!!
#    Simulating finding_best_G_=1.05 -> subject 4/10!!!
#    Simulating finding_best_G_=1.05 -> subject 5/10!!!
#    Simulating finding_best_G_=1.05 -> subject 6/10!!!
#    Simulating finding_best_G_=1.05 -> subject 7/10!!!
#    Simulating finding_best_G_=1.05 -> subject 8/10!!!
#    Simulating finding_best_G_=1.05 -> subject 9/10!!!
#    Processing signal 1/10 Subject: 0 (78x193) -> computed in 3.551006738001888 seconds
#    Processing signal 2/10 Subject: 1 (78x193) -> computed in 3.6117041739998967 seconds
#    Processing signal 3/10 Subject: 2 (78x193) -> computed in 3.6174794499966083 seconds
#    Processing signal 4/10 Subject: 3 (78x193) -> computed in 3.486135519000527 seconds
#    Processing signal 5/10 Subject: 4 (78x193) -> computed in 3.4933318170005805 seconds
#    Processing signal 6/10 Subject: 5 (78x193) -> computed in 3.4154280350048793 seconds
#    Processing signal 7/10 Subject: 6 (78x193) -> computed in 3.4821771979986806 seconds
#    Processing signal 8/10 Subject: 7 (78x193) -> computed in 3.43182278599852 seconds
#    Processing signal 9/10 Subject: 8 (78x193) -> computed in 3.4633169210064807 seconds
#    Processing signal 10/10 Subject: 9 (78x193) -> computed in 3.5333845959976315 seconds
#    --- TOTAL TIME: 37.59649200300191 seconds ---
# #11/1: FC: 0.3046395170430367; phFCD: 0.4485108119135047;
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/Finding_the_best_G/filter_0.04-0.07_initial//fitting_finding_best_G_1.1.mat
#    --- BEGIN TIME @ finding_best_G_=1.1 ---
# Current a is: -0.02
# Current G is: 1.1
#    Simulating finding_best_G_=1.1 -> subject 0/10!!!
#    Simulating finding_best_G_=1.1 -> subject 1/10!!!
#    Simulating finding_best_G_=1.1 -> subject 2/10!!!
#    Simulating finding_best_G_=1.1 -> subject 3/10!!!
#    Simulating finding_best_G_=1.1 -> subject 4/10!!!
#    Simulating finding_best_G_=1.1 -> subject 5/10!!!
#    Simulating finding_best_G_=1.1 -> subject 6/10!!!
#    Simulating finding_best_G_=1.1 -> subject 7/10!!!
#    Simulating finding_best_G_=1.1 -> subject 8/10!!!
#    Simulating finding_best_G_=1.1 -> subject 9/10!!!
#    Processing signal 1/10 Subject: 0 (78x193) -> computed in 3.4814260749990353 seconds
#    Processing signal 2/10 Subject: 1 (78x193) -> computed in 3.573561064004025 seconds
#    Processing signal 3/10 Subject: 2 (78x193) -> computed in 3.564247570000589 seconds
#    Processing signal 4/10 Subject: 3 (78x193) -> computed in 3.410694081998372 seconds
#    Processing signal 5/10 Subject: 4 (78x193) -> computed in 3.675931887002662 seconds
#    Processing signal 6/10 Subject: 5 (78x193) -> computed in 3.752171926003939 seconds
#    Processing signal 7/10 Subject: 6 (78x193) -> computed in 3.6165701249992708 seconds
#    Processing signal 8/10 Subject: 7 (78x193) -> computed in 3.5082813820044976 seconds
#    Processing signal 9/10 Subject: 8 (78x193) -> computed in 3.484245029001613 seconds
#    Processing signal 10/10 Subject: 9 (78x193) -> computed in 3.71252247600205 seconds
#    --- TOTAL TIME: 38.1842180120002 seconds ---
# #12/1: FC: 0.3871407047945479; phFCD: 0.4608391132870937;
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/Finding_the_best_G/filter_0.04-0.07_initial//fitting_finding_best_G_1.15.mat
#    --- BEGIN TIME @ finding_best_G_=1.15 ---
# Current a is: -0.02
# Current G is: 1.15
#    Simulating finding_best_G_=1.15 -> subject 0/10!!!
#    Simulating finding_best_G_=1.15 -> subject 1/10!!!
#    Simulating finding_best_G_=1.15 -> subject 2/10!!!
#    Simulating finding_best_G_=1.15 -> subject 3/10!!!
#    Simulating finding_best_G_=1.15 -> subject 4/10!!!
#    Simulating finding_best_G_=1.15 -> subject 5/10!!!
#    Simulating finding_best_G_=1.15 -> subject 6/10!!!
#    Simulating finding_best_G_=1.15 -> subject 7/10!!!
#    Simulating finding_best_G_=1.15 -> subject 8/10!!!
#    Simulating finding_best_G_=1.15 -> subject 9/10!!!
#    Processing signal 1/10 Subject: 0 (78x193) -> computed in 3.487032350996742 seconds
#    Processing signal 2/10 Subject: 1 (78x193) -> computed in 3.6294162269987282 seconds
#    Processing signal 3/10 Subject: 2 (78x193) -> computed in 3.614252075996774 seconds
#    Processing signal 4/10 Subject: 3 (78x193) -> computed in 3.288175528003194 seconds
#    Processing signal 5/10 Subject: 4 (78x193) -> computed in 3.3819473429975915 seconds
#    Processing signal 6/10 Subject: 5 (78x193) -> computed in 3.4412170400028117 seconds
#    Processing signal 7/10 Subject: 6 (78x193) -> computed in 3.539463250002882 seconds
#    Processing signal 8/10 Subject: 7 (78x193) -> computed in 3.5489820299990242 seconds
#    Processing signal 9/10 Subject: 8 (78x193) -> computed in 3.3468054039985873 seconds
#    Processing signal 10/10 Subject: 9 (78x193) -> computed in 3.3256683419967885 seconds
#    --- TOTAL TIME: 36.90211918600107 seconds ---
# #13/1: FC: 0.3665236005428916; phFCD: 0.44937440500476;
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/Finding_the_best_G/filter_0.04-0.07_initial//fitting_finding_best_G_1.2.mat
#    --- BEGIN TIME @ finding_best_G_=1.2 ---
# Current a is: -0.02
# Current G is: 1.2
#    Simulating finding_best_G_=1.2 -> subject 0/10!!!
#    Simulating finding_best_G_=1.2 -> subject 1/10!!!
#    Simulating finding_best_G_=1.2 -> subject 2/10!!!
#    Simulating finding_best_G_=1.2 -> subject 3/10!!!
#    Simulating finding_best_G_=1.2 -> subject 4/10!!!
#    Simulating finding_best_G_=1.2 -> subject 5/10!!!
#    Simulating finding_best_G_=1.2 -> subject 6/10!!!
#    Simulating finding_best_G_=1.2 -> subject 7/10!!!
#    Simulating finding_best_G_=1.2 -> subject 8/10!!!
#    Simulating finding_best_G_=1.2 -> subject 9/10!!!
#    Processing signal 1/10 Subject: 0 (78x193) -> computed in 3.6505031069973484 seconds
#    Processing signal 2/10 Subject: 1 (78x193) -> computed in 3.707293800995103 seconds
#    Processing signal 3/10 Subject: 2 (78x193) -> computed in 3.7297169270023005 seconds
#    Processing signal 4/10 Subject: 3 (78x193) -> computed in 3.587564178997127 seconds
#    Processing signal 5/10 Subject: 4 (78x193) -> computed in 3.3232603649958037 seconds
#    Processing signal 6/10 Subject: 5 (78x193) -> computed in 3.320776101005322 seconds
#    Processing signal 7/10 Subject: 6 (78x193) -> computed in 3.4225377300026594 seconds
#    Processing signal 8/10 Subject: 7 (78x193) -> computed in 3.3851938340012566 seconds
#    Processing signal 9/10 Subject: 8 (78x193) -> computed in 3.4005784380060504 seconds
#    Processing signal 10/10 Subject: 9 (78x193) -> computed in 3.5221958330002963 seconds
#    --- TOTAL TIME: 37.65450200600026 seconds ---
# #14/1: FC: 0.34126218608939557; phFCD: 0.4781109751121991;
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/Finding_the_best_G/filter_0.04-0.07_initial//fitting_finding_best_G_1.25.mat
#    --- BEGIN TIME @ finding_best_G_=1.25 ---
# Current a is: -0.02
# Current G is: 1.25
#    Simulating finding_best_G_=1.25 -> subject 0/10!!!
#    Simulating finding_best_G_=1.25 -> subject 1/10!!!
#    Simulating finding_best_G_=1.25 -> subject 2/10!!!
#    Simulating finding_best_G_=1.25 -> subject 3/10!!!
#    Simulating finding_best_G_=1.25 -> subject 4/10!!!
#    Simulating finding_best_G_=1.25 -> subject 5/10!!!
#    Simulating finding_best_G_=1.25 -> subject 6/10!!!
#    Simulating finding_best_G_=1.25 -> subject 7/10!!!
#    Simulating finding_best_G_=1.25 -> subject 8/10!!!
#    Simulating finding_best_G_=1.25 -> subject 9/10!!!
#    Processing signal 1/10 Subject: 0 (78x193) -> computed in 3.7134561860002577 seconds
#    Processing signal 2/10 Subject: 1 (78x193) -> computed in 5.988022539997473 seconds
#    Processing signal 3/10 Subject: 2 (78x193) -> computed in 5.875521957997989 seconds
#    Processing signal 4/10 Subject: 3 (78x193) -> computed in 4.210053490998689 seconds
#    Processing signal 5/10 Subject: 4 (78x193) -> computed in 3.7328475729955244 seconds
#    Processing signal 6/10 Subject: 5 (78x193) -> computed in 3.678079835997778 seconds
#    Processing signal 7/10 Subject: 6 (78x193) -> computed in 3.811349126001005 seconds
#    Processing signal 8/10 Subject: 7 (78x193) -> computed in 3.8997046740041696 seconds
#    Processing signal 9/10 Subject: 8 (78x193) -> computed in 3.3254526969976723 seconds
#    Processing signal 10/10 Subject: 9 (78x193) -> computed in 3.273013986006845 seconds
#    --- TOTAL TIME: 44.092427374002 seconds ---
# #15/1: FC: 0.37846238150056; phFCD: 0.4862482433473866;
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/Finding_the_best_G/filter_0.04-0.07_initial//fitting_finding_best_G_1.3.mat
#    --- BEGIN TIME @ finding_best_G_=1.3 ---
# Current a is: -0.02
# Current G is: 1.3
#    Simulating finding_best_G_=1.3 -> subject 0/10!!!
#    Simulating finding_best_G_=1.3 -> subject 1/10!!!
#    Simulating finding_best_G_=1.3 -> subject 2/10!!!
#    Simulating finding_best_G_=1.3 -> subject 3/10!!!
#    Simulating finding_best_G_=1.3 -> subject 4/10!!!
#    Simulating finding_best_G_=1.3 -> subject 5/10!!!
#    Simulating finding_best_G_=1.3 -> subject 6/10!!!
#    Simulating finding_best_G_=1.3 -> subject 7/10!!!
#    Simulating finding_best_G_=1.3 -> subject 8/10!!!
#    Simulating finding_best_G_=1.3 -> subject 9/10!!!
#    Processing signal 1/10 Subject: 0 (78x193) -> computed in 3.366090368006553 seconds
#    Processing signal 2/10 Subject: 1 (78x193) -> computed in 3.2925128689967096 seconds
#    Processing signal 3/10 Subject: 2 (78x193) -> computed in 3.336658167994756 seconds
#    Processing signal 4/10 Subject: 3 (78x193) -> computed in 3.3641618299952825 seconds
#    Processing signal 5/10 Subject: 4 (78x193) -> computed in 3.3797857310055406 seconds
#    Processing signal 6/10 Subject: 5 (78x193) -> computed in 3.3003572290035663 seconds
#    Processing signal 7/10 Subject: 6 (78x193) -> computed in 3.350006125001528 seconds
#    Processing signal 8/10 Subject: 7 (78x193) -> computed in 3.2786100290031754 seconds
#    Processing signal 9/10 Subject: 8 (78x193) -> computed in 3.266523435995623 seconds
#    Processing signal 10/10 Subject: 9 (78x193) -> computed in 3.7787800259975484 seconds
#    --- TOTAL TIME: 36.05908798999735 seconds ---
# #16/1: FC: 0.3551088923215134; phFCD: 0.4545695634434924;
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/Finding_the_best_G/filter_0.04-0.07_initial//fitting_finding_best_G_1.35.mat
#    --- BEGIN TIME @ finding_best_G_=1.35 ---
# Current a is: -0.02
# Current G is: 1.35
#    Simulating finding_best_G_=1.35 -> subject 0/10!!!
#    Simulating finding_best_G_=1.35 -> subject 1/10!!!
#    Simulating finding_best_G_=1.35 -> subject 2/10!!!
#    Simulating finding_best_G_=1.35 -> subject 3/10!!!
#    Simulating finding_best_G_=1.35 -> subject 4/10!!!
#    Simulating finding_best_G_=1.35 -> subject 5/10!!!
#    Simulating finding_best_G_=1.35 -> subject 6/10!!!
#    Simulating finding_best_G_=1.35 -> subject 7/10!!!
#    Simulating finding_best_G_=1.35 -> subject 8/10!!!
#    Simulating finding_best_G_=1.35 -> subject 9/10!!!
#    Processing signal 1/10 Subject: 0 (78x193) -> computed in 3.6943216340005165 seconds
#    Processing signal 2/10 Subject: 1 (78x193) -> computed in 3.619050008004706 seconds
#    Processing signal 3/10 Subject: 2 (78x193) -> computed in 3.5578592120000394 seconds
#    Processing signal 4/10 Subject: 3 (78x193) -> computed in 3.4750981789984507 seconds
#    Processing signal 5/10 Subject: 4 (78x193) -> computed in 3.468809679005062 seconds
#    Processing signal 6/10 Subject: 5 (78x193) -> computed in 3.7324354289958137 seconds
#    Processing signal 7/10 Subject: 6 (78x193) -> computed in 4.046606305004389 seconds
#    Processing signal 8/10 Subject: 7 (78x193) -> computed in 3.725470754005073 seconds
#    Processing signal 9/10 Subject: 8 (78x193) -> computed in 3.5937435740052024 seconds
#    Processing signal 10/10 Subject: 9 (78x193) -> computed in 3.954956684996432 seconds
#    --- TOTAL TIME: 39.39392891999887 seconds ---
# #17/1: FC: 0.3357359470095476; phFCD: 0.4434652522779818;
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/Finding_the_best_G/filter_0.04-0.07_initial//fitting_finding_best_G_1.4.mat
#    --- BEGIN TIME @ finding_best_G_=1.4 ---
# Current a is: -0.02
# Current G is: 1.4
#    Simulating finding_best_G_=1.4 -> subject 0/10!!!
#    Simulating finding_best_G_=1.4 -> subject 1/10!!!
#    Simulating finding_best_G_=1.4 -> subject 2/10!!!
#    Simulating finding_best_G_=1.4 -> subject 3/10!!!
#    Simulating finding_best_G_=1.4 -> subject 4/10!!!
#    Simulating finding_best_G_=1.4 -> subject 5/10!!!
#    Simulating finding_best_G_=1.4 -> subject 6/10!!!
#    Simulating finding_best_G_=1.4 -> subject 7/10!!!
#    Simulating finding_best_G_=1.4 -> subject 8/10!!!
#    Simulating finding_best_G_=1.4 -> subject 9/10!!!
#    Processing signal 1/10 Subject: 0 (78x193) -> computed in 3.349960398998519 seconds
#    Processing signal 2/10 Subject: 1 (78x193) -> computed in 3.331611499997962 seconds
#    Processing signal 3/10 Subject: 2 (78x193) -> computed in 3.455252298997948 seconds
#    Processing signal 4/10 Subject: 3 (78x193) -> computed in 3.5133961970059318 seconds
#    Processing signal 5/10 Subject: 4 (78x193) -> computed in 4.2188362970046 seconds
#    Processing signal 6/10 Subject: 5 (78x193) -> computed in 3.6181140990011045 seconds
#    Processing signal 7/10 Subject: 6 (78x193) -> computed in 3.656485599996813 seconds
#    Processing signal 8/10 Subject: 7 (78x193) -> computed in 3.4725814039993566 seconds
#    Processing signal 9/10 Subject: 8 (78x193) -> computed in 3.5782175040003494 seconds
#    Processing signal 10/10 Subject: 9 (78x193) -> computed in 3.9478334079976776 seconds
#    --- TOTAL TIME: 38.50060930699692 seconds ---
# #18/1: FC: 0.4063142325296588; phFCD: 0.4295978965501609;
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/Finding_the_best_G/filter_0.04-0.07_initial//fitting_finding_best_G_1.45.mat
#    --- BEGIN TIME @ finding_best_G_=1.45 ---
# Current a is: -0.02
# Current G is: 1.45
#    Simulating finding_best_G_=1.45 -> subject 0/10!!!
#    Simulating finding_best_G_=1.45 -> subject 1/10!!!
#    Simulating finding_best_G_=1.45 -> subject 2/10!!!
#    Simulating finding_best_G_=1.45 -> subject 3/10!!!
#    Simulating finding_best_G_=1.45 -> subject 4/10!!!
#    Simulating finding_best_G_=1.45 -> subject 5/10!!!
#    Simulating finding_best_G_=1.45 -> subject 6/10!!!
#    Simulating finding_best_G_=1.45 -> subject 7/10!!!
#    Simulating finding_best_G_=1.45 -> subject 8/10!!!
#    Simulating finding_best_G_=1.45 -> subject 9/10!!!
#    Processing signal 1/10 Subject: 0 (78x193) -> computed in 3.43919110600109 seconds
#    Processing signal 2/10 Subject: 1 (78x193) -> computed in 3.574335206998512 seconds
#    Processing signal 3/10 Subject: 2 (78x193) -> computed in 3.3864607100040303 seconds
#    Processing signal 4/10 Subject: 3 (78x193) -> computed in 3.363826312001038 seconds
#    Processing signal 5/10 Subject: 4 (78x193) -> computed in 3.4672056139970664 seconds
#    Processing signal 6/10 Subject: 5 (78x193) -> computed in 3.4467794180018245 seconds
#    Processing signal 7/10 Subject: 6 (78x193) -> computed in 3.5234197190002305 seconds
#    Processing signal 8/10 Subject: 7 (78x193) -> computed in 3.506897727995238 seconds
#    Processing signal 9/10 Subject: 8 (78x193) -> computed in 3.5704611289984314 seconds
#    Processing signal 10/10 Subject: 9 (78x193) -> computed in 3.33486454100057 seconds
#    --- TOTAL TIME: 36.99192558899813 seconds ---
# #19/1: FC: 0.4026411937363469; phFCD: 0.43057935536515707;
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/Finding_the_best_G/filter_0.04-0.07_initial//fitting_finding_best_G_1.5.mat
#    --- BEGIN TIME @ finding_best_G_=1.5 ---
# Current a is: -0.02
# Current G is: 1.5
#    Simulating finding_best_G_=1.5 -> subject 0/10!!!
#    Simulating finding_best_G_=1.5 -> subject 1/10!!!
#    Simulating finding_best_G_=1.5 -> subject 2/10!!!
#    Simulating finding_best_G_=1.5 -> subject 3/10!!!
#    Simulating finding_best_G_=1.5 -> subject 4/10!!!
#    Simulating finding_best_G_=1.5 -> subject 5/10!!!
#    Simulating finding_best_G_=1.5 -> subject 6/10!!!
#    Simulating finding_best_G_=1.5 -> subject 7/10!!!
#    Simulating finding_best_G_=1.5 -> subject 8/10!!!
#    Simulating finding_best_G_=1.5 -> subject 9/10!!!
#    Processing signal 1/10 Subject: 0 (78x193) -> computed in 3.454874863004079 seconds
#    Processing signal 2/10 Subject: 1 (78x193) -> computed in 3.6221909660016536 seconds
#    Processing signal 3/10 Subject: 2 (78x193) -> computed in 3.855061233000015 seconds
#    Processing signal 4/10 Subject: 3 (78x193) -> computed in 3.7872012250008993 seconds
#    Processing signal 5/10 Subject: 4 (78x193) -> computed in 3.514259818002756 seconds
#    Processing signal 6/10 Subject: 5 (78x193) -> computed in 3.596266516004107 seconds
#    Processing signal 7/10 Subject: 6 (78x193) -> computed in 3.381355777004501 seconds
#    Processing signal 8/10 Subject: 7 (78x193) -> computed in 3.3644115310016787 seconds
#    Processing signal 9/10 Subject: 8 (78x193) -> computed in 3.3512444349980797 seconds
#    Processing signal 10/10 Subject: 9 (78x193) -> computed in 3.3175700860010693 seconds
#    --- TOTAL TIME: 37.7332623839975 seconds ---
# #20/1: FC: 0.39479484526781633; phFCD: 0.3708169001314657;
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/Finding_the_best_G/filter_0.04-0.07_initial//fitting_finding_best_G_1.55.mat
#    --- BEGIN TIME @ finding_best_G_=1.55 ---
# Current a is: -0.02
# Current G is: 1.55
#    Simulating finding_best_G_=1.55 -> subject 0/10!!!
#    Simulating finding_best_G_=1.55 -> subject 1/10!!!
#    Simulating finding_best_G_=1.55 -> subject 2/10!!!
#    Simulating finding_best_G_=1.55 -> subject 3/10!!!
#    Simulating finding_best_G_=1.55 -> subject 4/10!!!
#    Simulating finding_best_G_=1.55 -> subject 5/10!!!
#    Simulating finding_best_G_=1.55 -> subject 6/10!!!
#    Simulating finding_best_G_=1.55 -> subject 7/10!!!
#    Simulating finding_best_G_=1.55 -> subject 8/10!!!
#    Simulating finding_best_G_=1.55 -> subject 9/10!!!
#    Processing signal 1/10 Subject: 0 (78x193) -> computed in 3.46985749599844 seconds
#    Processing signal 2/10 Subject: 1 (78x193) -> computed in 3.551793496000755 seconds
#    Processing signal 3/10 Subject: 2 (78x193) -> computed in 3.3804582209995715 seconds
#    Processing signal 4/10 Subject: 3 (78x193) -> computed in 3.3619256250021863 seconds
#    Processing signal 5/10 Subject: 4 (78x193) -> computed in 3.3551219619985204 seconds
#    Processing signal 6/10 Subject: 5 (78x193) -> computed in 3.3733623059961246 seconds
#    Processing signal 7/10 Subject: 6 (78x193) -> computed in 3.3268837079958757 seconds
#    Processing signal 8/10 Subject: 7 (78x193) -> computed in 3.3229279480001424 seconds
#    Processing signal 9/10 Subject: 8 (78x193) -> computed in 3.3090770470007556 seconds
#    Processing signal 10/10 Subject: 9 (78x193) -> computed in 3.285759386999416 seconds
#    --- TOTAL TIME: 36.1528283880034 seconds ---
# #21/1: FC: 0.37141808084762656; phFCD: 0.3301441588467292;
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/Finding_the_best_G/filter_0.04-0.07_initial//fitting_finding_best_G_1.6.mat
#    --- BEGIN TIME @ finding_best_G_=1.6 ---
# Current a is: -0.02
# Current G is: 1.6
#    Simulating finding_best_G_=1.6 -> subject 0/10!!!
#    Simulating finding_best_G_=1.6 -> subject 1/10!!!
#    Simulating finding_best_G_=1.6 -> subject 2/10!!!
#    Simulating finding_best_G_=1.6 -> subject 3/10!!!
#    Simulating finding_best_G_=1.6 -> subject 4/10!!!
#    Simulating finding_best_G_=1.6 -> subject 5/10!!!
#    Simulating finding_best_G_=1.6 -> subject 6/10!!!
#    Simulating finding_best_G_=1.6 -> subject 7/10!!!
#    Simulating finding_best_G_=1.6 -> subject 8/10!!!
#    Simulating finding_best_G_=1.6 -> subject 9/10!!!
#    Processing signal 1/10 Subject: 0 (78x193) -> computed in 3.455769154999871 seconds
#    Processing signal 2/10 Subject: 1 (78x193) -> computed in 3.3949385519954376 seconds
#    Processing signal 3/10 Subject: 2 (78x193) -> computed in 3.4876535380026326 seconds
#    Processing signal 4/10 Subject: 3 (78x193) -> computed in 3.3780185119976522 seconds
#    Processing signal 5/10 Subject: 4 (78x193) -> computed in 3.379150312001002 seconds
#    Processing signal 6/10 Subject: 5 (78x193) -> computed in 3.4229136080030003 seconds
#    Processing signal 7/10 Subject: 6 (78x193) -> computed in 3.366334307997022 seconds
#    Processing signal 8/10 Subject: 7 (78x193) -> computed in 3.4217310060048476 seconds
#    Processing signal 9/10 Subject: 8 (78x193) -> computed in 3.442847605998395 seconds
#    Processing signal 10/10 Subject: 9 (78x193) -> computed in 3.3529197050011135 seconds
#    --- TOTAL TIME: 36.516177543002414 seconds ---
# #22/1: FC: 0.3826514485940769; phFCD: 0.29800761593907243;
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/Finding_the_best_G/filter_0.04-0.07_initial//fitting_finding_best_G_1.65.mat
#    --- BEGIN TIME @ finding_best_G_=1.65 ---
# Current a is: -0.02
# Current G is: 1.65
#    Simulating finding_best_G_=1.65 -> subject 0/10!!!
#    Simulating finding_best_G_=1.65 -> subject 1/10!!!
#    Simulating finding_best_G_=1.65 -> subject 2/10!!!
#    Simulating finding_best_G_=1.65 -> subject 3/10!!!
#    Simulating finding_best_G_=1.65 -> subject 4/10!!!
#    Simulating finding_best_G_=1.65 -> subject 5/10!!!
#    Simulating finding_best_G_=1.65 -> subject 6/10!!!
#    Simulating finding_best_G_=1.65 -> subject 7/10!!!
#    Simulating finding_best_G_=1.65 -> subject 8/10!!!
#    Simulating finding_best_G_=1.65 -> subject 9/10!!!
#    Processing signal 1/10 Subject: 0 (78x193) -> computed in 3.421844908996718 seconds
#    Processing signal 2/10 Subject: 1 (78x193) -> computed in 3.4470488100050716 seconds
#    Processing signal 3/10 Subject: 2 (78x193) -> computed in 3.428541511995718 seconds
#    Processing signal 4/10 Subject: 3 (78x193) -> computed in 3.339313222000783 seconds
#    Processing signal 5/10 Subject: 4 (78x193) -> computed in 3.4317776229945594 seconds
#    Processing signal 6/10 Subject: 5 (78x193) -> computed in 3.440544969998882 seconds
#    Processing signal 7/10 Subject: 6 (78x193) -> computed in 3.3111747750008362 seconds
#    Processing signal 8/10 Subject: 7 (78x193) -> computed in 3.4001616009991267 seconds
#    Processing signal 9/10 Subject: 8 (78x193) -> computed in 3.3247853229986504 seconds
#    Processing signal 10/10 Subject: 9 (78x193) -> computed in 3.3070741170013207 seconds
#    --- TOTAL TIME: 36.25756846600416 seconds ---
# #23/1: FC: 0.3787619007532179; phFCD: 0.26156897411487373;
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/Finding_the_best_G/filter_0.04-0.07_initial//fitting_finding_best_G_1.7.mat
#    --- BEGIN TIME @ finding_best_G_=1.7 ---
# Current a is: -0.02
# Current G is: 1.7
#    Simulating finding_best_G_=1.7 -> subject 0/10!!!
#    Simulating finding_best_G_=1.7 -> subject 1/10!!!
#    Simulating finding_best_G_=1.7 -> subject 2/10!!!
#    Simulating finding_best_G_=1.7 -> subject 3/10!!!
#    Simulating finding_best_G_=1.7 -> subject 4/10!!!
#    Simulating finding_best_G_=1.7 -> subject 5/10!!!
#    Simulating finding_best_G_=1.7 -> subject 6/10!!!
#    Simulating finding_best_G_=1.7 -> subject 7/10!!!
#    Simulating finding_best_G_=1.7 -> subject 8/10!!!
#    Simulating finding_best_G_=1.7 -> subject 9/10!!!
#    Processing signal 1/10 Subject: 0 (78x193) -> computed in 3.8284095589988283 seconds
#    Processing signal 2/10 Subject: 1 (78x193) -> computed in 3.9810353470020345 seconds
#    Processing signal 3/10 Subject: 2 (78x193) -> computed in 3.4145099360030144 seconds
#    Processing signal 4/10 Subject: 3 (78x193) -> computed in 3.4454636049995315 seconds
#    Processing signal 5/10 Subject: 4 (78x193) -> computed in 3.6209607050041086 seconds
#    Processing signal 6/10 Subject: 5 (78x193) -> computed in 3.5233225429983577 seconds
#    Processing signal 7/10 Subject: 6 (78x193) -> computed in 3.6802068519973545 seconds
#    Processing signal 8/10 Subject: 7 (78x193) -> computed in 3.5777053120036726 seconds
#    Processing signal 9/10 Subject: 8 (78x193) -> computed in 3.590206188004231 seconds
#    Processing signal 10/10 Subject: 9 (78x193) -> computed in 3.5498014979966683 seconds
#    --- TOTAL TIME: 38.672884587002045 seconds ---
# #24/1: FC: 0.3041607911307256; phFCD: 0.355662088036629;
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/Finding_the_best_G/filter_0.04-0.07_initial//fitting_finding_best_G_1.75.mat
#    --- BEGIN TIME @ finding_best_G_=1.75 ---
# Current a is: -0.02
# Current G is: 1.75
#    Simulating finding_best_G_=1.75 -> subject 0/10!!!
#    Simulating finding_best_G_=1.75 -> subject 1/10!!!
#    Simulating finding_best_G_=1.75 -> subject 2/10!!!
#    Simulating finding_best_G_=1.75 -> subject 3/10!!!
#    Simulating finding_best_G_=1.75 -> subject 4/10!!!
#    Simulating finding_best_G_=1.75 -> subject 5/10!!!
#    Simulating finding_best_G_=1.75 -> subject 6/10!!!
#    Simulating finding_best_G_=1.75 -> subject 7/10!!!
#    Simulating finding_best_G_=1.75 -> subject 8/10!!!
#    Simulating finding_best_G_=1.75 -> subject 9/10!!!
#    Processing signal 1/10 Subject: 0 (78x193) -> computed in 3.503513715004374 seconds
#    Processing signal 2/10 Subject: 1 (78x193) -> computed in 3.4577180170017527 seconds
#    Processing signal 3/10 Subject: 2 (78x193) -> computed in 3.698287422004796 seconds
#    Processing signal 4/10 Subject: 3 (78x193) -> computed in 3.013669525003934 seconds
#    Processing signal 5/10 Subject: 4 (78x193) -> computed in 3.3942549280036474 seconds
#    Processing signal 6/10 Subject: 5 (78x193) -> computed in 3.135505590995308 seconds
#    Processing signal 7/10 Subject: 6 (78x193) -> computed in 3.5529322840011446 seconds
#    Processing signal 8/10 Subject: 7 (78x193) -> computed in 3.8617786019967753 seconds
#    Processing signal 9/10 Subject: 8 (78x193) -> computed in 3.589967517997138 seconds
#    Processing signal 10/10 Subject: 9 (78x193) -> computed in 3.7450248199966154 seconds
#    --- TOTAL TIME: 37.50672983199911 seconds ---
# #25/1: FC: 0.37828979365105064; phFCD: 0.3668661317376128;
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/Finding_the_best_G/filter_0.04-0.07_initial//fitting_finding_best_G_1.8.mat
#    --- BEGIN TIME @ finding_best_G_=1.8 ---
# Current a is: -0.02
# Current G is: 1.8
#    Simulating finding_best_G_=1.8 -> subject 0/10!!!
#    Simulating finding_best_G_=1.8 -> subject 1/10!!!
#    Simulating finding_best_G_=1.8 -> subject 2/10!!!
#    Simulating finding_best_G_=1.8 -> subject 3/10!!!
#    Simulating finding_best_G_=1.8 -> subject 4/10!!!
#    Simulating finding_best_G_=1.8 -> subject 5/10!!!
#    Simulating finding_best_G_=1.8 -> subject 6/10!!!
#    Simulating finding_best_G_=1.8 -> subject 7/10!!!
#    Simulating finding_best_G_=1.8 -> subject 8/10!!!
#    Simulating finding_best_G_=1.8 -> subject 9/10!!!
#    Processing signal 1/10 Subject: 0 (78x193) -> computed in 2.952247002001968 seconds
#    Processing signal 2/10 Subject: 1 (78x193) -> computed in 2.8655749640020076 seconds
#    Processing signal 3/10 Subject: 2 (78x193) -> computed in 3.1791690589961945 seconds
#    Processing signal 4/10 Subject: 3 (78x193) -> computed in 3.216492234998441 seconds
#    Processing signal 5/10 Subject: 4 (78x193) -> computed in 2.8415694939976675 seconds
#    Processing signal 6/10 Subject: 5 (78x193) -> computed in 3.3001877749993582 seconds
# ...
#    Simulating finding_best_G_=4.55 -> subject 1/10!!!
#    Simulating finding_best_G_=4.55 -> subject 2/10!!!
#    Simulating finding_best_G_=4.55 -> subject 3/10!!!
#    Simulating finding_best_G_=4.55 -> subject 4/10!!!
#    Simulating finding_best_G_=4.55 -> subject 5/10!!!
#    Simulating finding_best_G_=4.55 -> subject 6/10!!!
#    Simulating finding_best_G_=4.55 -> subject 7/10!!!
#    Simulating finding_best_G_=4.55 -> subject 8/10!!!
#    Simulating finding_best_G_=4.55 -> subject 9/10!!!
#    Processing signal 1/10 Subject: 0 (78x193) -> computed in 2.7207753430047887 seconds
#    Processing signal 2/10 Subject: 1 (78x193) -> computed in 2.671998543002701 seconds
#    Processing signal 3/10 Subject: 2 (78x193) -> computed in 2.7210410490006325 seconds
#    Processing signal 4/10 Subject: 3 (78x193) -> computed in 2.8171674929981236 seconds
#    Processing signal 5/10 Subject: 4 (78x193) -> computed in 2.8528744659997756 seconds
#    Processing signal 6/10 Subject: 5 (78x193) -> computed in 2.770736887003295 seconds
#    Processing signal 7/10 Subject: 6 (78x193) -> computed in 2.734116970001196 seconds
#    Processing signal 8/10 Subject: 7 (78x193) -> computed in 2.7061725550011033 seconds
#    Processing signal 9/10 Subject: 8 (78x193) -> computed in 2.7257669620012166 seconds
#    Processing signal 10/10 Subject: 9 (78x193) -> computed in 2.7621279550003237 seconds
#    --- TOTAL TIME: 29.343178350995004 seconds ---
# #81/1: FC: 0.29619965345625127; phFCD: 0.24366698399746134;
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/Finding_the_best_G/filter_0.04-0.07_initial//fitting_finding_best_G_4.6.mat
#    --- BEGIN TIME @ finding_best_G_=4.6 ---
# Current a is: -0.02
# Current G is: 4.6
#    Simulating finding_best_G_=4.6 -> subject 0/10!!!
#    Simulating finding_best_G_=4.6 -> subject 1/10!!!
#    Simulating finding_best_G_=4.6 -> subject 2/10!!!
#    Simulating finding_best_G_=4.6 -> subject 3/10!!!
#    Simulating finding_best_G_=4.6 -> subject 4/10!!!
#    Simulating finding_best_G_=4.6 -> subject 5/10!!!
#    Simulating finding_best_G_=4.6 -> subject 6/10!!!
#    Simulating finding_best_G_=4.6 -> subject 7/10!!!
#    Simulating finding_best_G_=4.6 -> subject 8/10!!!
#    Simulating finding_best_G_=4.6 -> subject 9/10!!!
#    Processing signal 1/10 Subject: 0 (78x193) -> computed in 2.672843605003436 seconds
#    Processing signal 2/10 Subject: 1 (78x193) -> computed in 2.672599302997696 seconds
#    Processing signal 3/10 Subject: 2 (78x193) -> computed in 2.675323182993452 seconds
#    Processing signal 4/10 Subject: 3 (78x193) -> computed in 2.7405367360042874 seconds
#    Processing signal 5/10 Subject: 4 (78x193) -> computed in 2.6461230060012895 seconds
#    Processing signal 6/10 Subject: 5 (78x193) -> computed in 2.6782014220007113 seconds
#    Processing signal 7/10 Subject: 6 (78x193) -> computed in 2.692803712998284 seconds
#    Processing signal 8/10 Subject: 7 (78x193) -> computed in 2.670593609997013 seconds
#    Processing signal 9/10 Subject: 8 (78x193) -> computed in 2.6369127049983945 seconds
#    Processing signal 10/10 Subject: 9 (78x193) -> computed in 2.6427733050004463 seconds
#    --- TOTAL TIME: 28.534189147998404 seconds ---
# #82/1: FC: 0.3021639500556939; phFCD: 0.20456276349789204;
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/Finding_the_best_G/filter_0.04-0.07_initial//fitting_finding_best_G_4.65.mat
#    --- BEGIN TIME @ finding_best_G_=4.65 ---
# Current a is: -0.02
# Current G is: 4.65
#    Simulating finding_best_G_=4.65 -> subject 0/10!!!
#    Simulating finding_best_G_=4.65 -> subject 1/10!!!
#    Simulating finding_best_G_=4.65 -> subject 2/10!!!
#    Simulating finding_best_G_=4.65 -> subject 3/10!!!
#    Simulating finding_best_G_=4.65 -> subject 4/10!!!
#    Simulating finding_best_G_=4.65 -> subject 5/10!!!
#    Simulating finding_best_G_=4.65 -> subject 6/10!!!
#    Simulating finding_best_G_=4.65 -> subject 7/10!!!
#    Simulating finding_best_G_=4.65 -> subject 8/10!!!
#    Simulating finding_best_G_=4.65 -> subject 9/10!!!
#    Processing signal 1/10 Subject: 0 (78x193) -> computed in 2.7161700910000945 seconds
#    Processing signal 2/10 Subject: 1 (78x193) -> computed in 2.6762664709967794 seconds
#    Processing signal 3/10 Subject: 2 (78x193) -> computed in 2.6698300700008986 seconds
#    Processing signal 4/10 Subject: 3 (78x193) -> computed in 2.667929326999001 seconds
#    Processing signal 5/10 Subject: 4 (78x193) -> computed in 2.640104927995708 seconds
#    Processing signal 6/10 Subject: 5 (78x193) -> computed in 2.6571208280001883 seconds
#    Processing signal 7/10 Subject: 6 (78x193) -> computed in 2.6653253399999812 seconds
#    Processing signal 8/10 Subject: 7 (78x193) -> computed in 2.7174747360040783 seconds
#    Processing signal 9/10 Subject: 8 (78x193) -> computed in 2.6287497380035347 seconds
#    Processing signal 10/10 Subject: 9 (78x193) -> computed in 2.636324371997034 seconds
#    --- TOTAL TIME: 28.532512084995687 seconds ---
# #83/1: FC: 0.35187200296646226; phFCD: 0.11624733668797316;
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/Finding_the_best_G/filter_0.04-0.07_initial//fitting_finding_best_G_4.7.mat
#    --- BEGIN TIME @ finding_best_G_=4.7 ---
# Current a is: -0.02
# Current G is: 4.7
#    Simulating finding_best_G_=4.7 -> subject 0/10!!!
#    Simulating finding_best_G_=4.7 -> subject 1/10!!!
#    Simulating finding_best_G_=4.7 -> subject 2/10!!!
#    Simulating finding_best_G_=4.7 -> subject 3/10!!!
#    Simulating finding_best_G_=4.7 -> subject 4/10!!!
#    Simulating finding_best_G_=4.7 -> subject 5/10!!!
#    Simulating finding_best_G_=4.7 -> subject 6/10!!!
#    Simulating finding_best_G_=4.7 -> subject 7/10!!!
#    Simulating finding_best_G_=4.7 -> subject 8/10!!!
#    Simulating finding_best_G_=4.7 -> subject 9/10!!!
#    Processing signal 1/10 Subject: 0 (78x193) -> computed in 2.701444508995337 seconds
#    Processing signal 2/10 Subject: 1 (78x193) -> computed in 2.6352596750002704 seconds
#    Processing signal 3/10 Subject: 2 (78x193) -> computed in 2.7361648730002344 seconds
#    Processing signal 4/10 Subject: 3 (78x193) -> computed in 2.6838161449995823 seconds
#    Processing signal 5/10 Subject: 4 (78x193) -> computed in 2.676254924001114 seconds
#    Processing signal 6/10 Subject: 5 (78x193) -> computed in 2.7057103219995042 seconds
#    Processing signal 7/10 Subject: 6 (78x193) -> computed in 2.7556274730013683 seconds
#    Processing signal 8/10 Subject: 7 (78x193) -> computed in 2.6983565039990935 seconds
#    Processing signal 9/10 Subject: 8 (78x193) -> computed in 2.6398505050019594 seconds
#    Processing signal 10/10 Subject: 9 (78x193) -> computed in 2.6571932099977857 seconds
#    --- TOTAL TIME: 28.708007649998763 seconds ---
# #84/1: FC: 0.38119659650741305; phFCD: 0.18468878915635345;
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/Finding_the_best_G/filter_0.04-0.07_initial//fitting_finding_best_G_4.75.mat
#    --- BEGIN TIME @ finding_best_G_=4.75 ---
# Current a is: -0.02
# Current G is: 4.75
#    Simulating finding_best_G_=4.75 -> subject 0/10!!!
#    Simulating finding_best_G_=4.75 -> subject 1/10!!!
#    Simulating finding_best_G_=4.75 -> subject 2/10!!!
#    Simulating finding_best_G_=4.75 -> subject 3/10!!!
#    Simulating finding_best_G_=4.75 -> subject 4/10!!!
#    Simulating finding_best_G_=4.75 -> subject 5/10!!!
#    Simulating finding_best_G_=4.75 -> subject 6/10!!!
#    Simulating finding_best_G_=4.75 -> subject 7/10!!!
#    Simulating finding_best_G_=4.75 -> subject 8/10!!!
#    Simulating finding_best_G_=4.75 -> subject 9/10!!!
#    Processing signal 1/10 Subject: 0 (78x193) -> computed in 2.659258313004102 seconds
#    Processing signal 2/10 Subject: 1 (78x193) -> computed in 2.6406579800022882 seconds
#    Processing signal 3/10 Subject: 2 (78x193) -> computed in 2.604204880997713 seconds
#    Processing signal 4/10 Subject: 3 (78x193) -> computed in 2.6354324810017715 seconds
#    Processing signal 5/10 Subject: 4 (78x193) -> computed in 2.717684734001523 seconds
#    Processing signal 6/10 Subject: 5 (78x193) -> computed in 2.6305914359982125 seconds
#    Processing signal 7/10 Subject: 6 (78x193) -> computed in 2.6324696489973576 seconds
#    Processing signal 8/10 Subject: 7 (78x193) -> computed in 2.6022225500055356 seconds
#    Processing signal 9/10 Subject: 8 (78x193) -> computed in 2.6434139530028915 seconds
#    Processing signal 10/10 Subject: 9 (78x193) -> computed in 2.6790814549967763 seconds
#    --- TOTAL TIME: 28.224956240999745 seconds ---
# #85/1: FC: 0.31248092661691473; phFCD: 0.22008477265515214;
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/Finding_the_best_G/filter_0.04-0.07_initial//fitting_finding_best_G_4.8.mat
#    --- BEGIN TIME @ finding_best_G_=4.8 ---
# Current a is: -0.02
# Current G is: 4.8
#    Simulating finding_best_G_=4.8 -> subject 0/10!!!
#    Simulating finding_best_G_=4.8 -> subject 1/10!!!
#    Simulating finding_best_G_=4.8 -> subject 2/10!!!
#    Simulating finding_best_G_=4.8 -> subject 3/10!!!
#    Simulating finding_best_G_=4.8 -> subject 4/10!!!
#    Simulating finding_best_G_=4.8 -> subject 5/10!!!
#    Simulating finding_best_G_=4.8 -> subject 6/10!!!
#    Simulating finding_best_G_=4.8 -> subject 7/10!!!
#    Simulating finding_best_G_=4.8 -> subject 8/10!!!
#    Simulating finding_best_G_=4.8 -> subject 9/10!!!
#    Processing signal 1/10 Subject: 0 (78x193) -> computed in 2.637377284998365 seconds
#    Processing signal 2/10 Subject: 1 (78x193) -> computed in 2.675545082995086 seconds
#    Processing signal 3/10 Subject: 2 (78x193) -> computed in 2.597584581002593 seconds
#    Processing signal 4/10 Subject: 3 (78x193) -> computed in 2.6229350800058455 seconds
#    Processing signal 5/10 Subject: 4 (78x193) -> computed in 2.6885542800009716 seconds
#    Processing signal 6/10 Subject: 5 (78x193) -> computed in 2.703631880998728 seconds
#    Processing signal 7/10 Subject: 6 (78x193) -> computed in 2.6522467809991213 seconds
#    Processing signal 8/10 Subject: 7 (78x193) -> computed in 2.6650509649989544 seconds
#    Processing signal 9/10 Subject: 8 (78x193) -> computed in 2.6580510300045717 seconds
#    Processing signal 10/10 Subject: 9 (78x193) -> computed in 2.624076330997923 seconds
#    --- TOTAL TIME: 28.353218887001276 seconds ---
# #86/1: FC: 0.3220221941542581; phFCD: 0.1933564531483748;
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/Finding_the_best_G/filter_0.04-0.07_initial//fitting_finding_best_G_4.85.mat
#    --- BEGIN TIME @ finding_best_G_=4.85 ---
# Current a is: -0.02
# Current G is: 4.85
#    Simulating finding_best_G_=4.85 -> subject 0/10!!!
#    Simulating finding_best_G_=4.85 -> subject 1/10!!!
#    Simulating finding_best_G_=4.85 -> subject 2/10!!!
#    Simulating finding_best_G_=4.85 -> subject 3/10!!!
#    Simulating finding_best_G_=4.85 -> subject 4/10!!!
#    Simulating finding_best_G_=4.85 -> subject 5/10!!!
#    Simulating finding_best_G_=4.85 -> subject 6/10!!!
#    Simulating finding_best_G_=4.85 -> subject 7/10!!!
#    Simulating finding_best_G_=4.85 -> subject 8/10!!!
#    Simulating finding_best_G_=4.85 -> subject 9/10!!!
#    Processing signal 1/10 Subject: 0 (78x193) -> computed in 2.6730183720064815 seconds
#    Processing signal 2/10 Subject: 1 (78x193) -> computed in 2.6446611720020883 seconds
#    Processing signal 3/10 Subject: 2 (78x193) -> computed in 2.6617400659961277 seconds
#    Processing signal 4/10 Subject: 3 (78x193) -> computed in 2.6847406619999674 seconds
#    Processing signal 5/10 Subject: 4 (78x193) -> computed in 2.6914713619989925 seconds
#    Processing signal 6/10 Subject: 5 (78x193) -> computed in 2.6373910559996148 seconds
#    Processing signal 7/10 Subject: 6 (78x193) -> computed in 2.5700271539972164 seconds
#    Processing signal 8/10 Subject: 7 (78x193) -> computed in 2.6759229520030203 seconds
#    Processing signal 9/10 Subject: 8 (78x193) -> computed in 2.741293161001522 seconds
#    Processing signal 10/10 Subject: 9 (78x193) -> computed in 2.6447596669968334 seconds
#    --- TOTAL TIME: 28.410584104996815 seconds ---
# #87/1: FC: 0.36668847136690813; phFCD: 0.22586699306405544;
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/Finding_the_best_G/filter_0.04-0.07_initial//fitting_finding_best_G_4.9.mat
#    --- BEGIN TIME @ finding_best_G_=4.9 ---
# Current a is: -0.02
# Current G is: 4.9
#    Simulating finding_best_G_=4.9 -> subject 0/10!!!
#    Simulating finding_best_G_=4.9 -> subject 1/10!!!
#    Simulating finding_best_G_=4.9 -> subject 2/10!!!
#    Simulating finding_best_G_=4.9 -> subject 3/10!!!
#    Simulating finding_best_G_=4.9 -> subject 4/10!!!
#    Simulating finding_best_G_=4.9 -> subject 5/10!!!
#    Simulating finding_best_G_=4.9 -> subject 6/10!!!
#    Simulating finding_best_G_=4.9 -> subject 7/10!!!
#    Simulating finding_best_G_=4.9 -> subject 8/10!!!
#    Simulating finding_best_G_=4.9 -> subject 9/10!!!
#    Processing signal 1/10 Subject: 0 (78x193) -> computed in 2.691830686002504 seconds
#    Processing signal 2/10 Subject: 1 (78x193) -> computed in 2.675575385997945 seconds
#    Processing signal 3/10 Subject: 2 (78x193) -> computed in 2.608218487999693 seconds
#    Processing signal 4/10 Subject: 3 (78x193) -> computed in 2.587073793001764 seconds
#    Processing signal 5/10 Subject: 4 (78x193) -> computed in 2.634475093000219 seconds
#    Processing signal 6/10 Subject: 5 (78x193) -> computed in 2.6164760879983078 seconds
#    Processing signal 7/10 Subject: 6 (78x193) -> computed in 2.6459659620013554 seconds
#    Processing signal 8/10 Subject: 7 (78x193) -> computed in 2.6405834629986202 seconds
#    Processing signal 9/10 Subject: 8 (78x193) -> computed in 2.6700121270041564 seconds
#    Processing signal 10/10 Subject: 9 (78x193) -> computed in 2.7016087820011307 seconds
#    --- TOTAL TIME: 28.272971450001933 seconds ---
# #88/1: FC: 0.3809180522519669; phFCD: 0.29298245614035084;
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/Finding_the_best_G/filter_0.04-0.07_initial//fitting_finding_best_G_4.95.mat
#    --- BEGIN TIME @ finding_best_G_=4.95 ---
# Current a is: -0.02
# Current G is: 4.95
#    Simulating finding_best_G_=4.95 -> subject 0/10!!!
#    Simulating finding_best_G_=4.95 -> subject 1/10!!!
#    Simulating finding_best_G_=4.95 -> subject 2/10!!!
#    Simulating finding_best_G_=4.95 -> subject 3/10!!!
#    Simulating finding_best_G_=4.95 -> subject 4/10!!!
#    Simulating finding_best_G_=4.95 -> subject 5/10!!!
#    Simulating finding_best_G_=4.95 -> subject 6/10!!!
#    Simulating finding_best_G_=4.95 -> subject 7/10!!!
#    Simulating finding_best_G_=4.95 -> subject 8/10!!!
#    Simulating finding_best_G_=4.95 -> subject 9/10!!!
#    Processing signal 1/10 Subject: 0 (78x193) -> computed in 2.6992294829979073 seconds
#    Processing signal 2/10 Subject: 1 (78x193) -> computed in 2.6864579750035773 seconds
#    Processing signal 3/10 Subject: 2 (78x193) -> computed in 2.6559558759981883 seconds
#    Processing signal 4/10 Subject: 3 (78x193) -> computed in 2.655274462995294 seconds
#    Processing signal 5/10 Subject: 4 (78x193) -> computed in 2.6718077390032704 seconds
#    Processing signal 6/10 Subject: 5 (78x193) -> computed in 2.6428514390063356 seconds
#    Processing signal 7/10 Subject: 6 (78x193) -> computed in 2.6565820920004626 seconds
#    Processing signal 8/10 Subject: 7 (78x193) -> computed in 2.675403537999955 seconds
#    Processing signal 9/10 Subject: 8 (78x193) -> computed in 2.742560446000425 seconds
#    Processing signal 10/10 Subject: 9 (78x193) -> computed in 2.759774436999578 seconds
#    --- TOTAL TIME: 28.62737018000189 seconds ---
# #89/1: FC: 0.33101705819794486; phFCD: 0.05188131828278697;
#
#
#
# #####################################################################################################
# # Results (in (0.5, 4.95)):
# #####################################################################################################
#
#
# DONE!!!
# # Optimal FC =     0.4285859851244164 @ 2.05
# # Optimal phFCD =     0.013284827054716897 @ 2.9
