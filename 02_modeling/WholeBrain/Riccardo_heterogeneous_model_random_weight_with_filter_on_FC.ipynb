# %%
# Load all the packages needed for analyses
import sys
import numpy as np
import scipy.io as sio
from numba import jit
import matplotlib.pyplot as plt
import pickle


# Set up Hopf as our model 
import WholeBrain.Models.supHopf as Hopf
from WholeBrain.simulate_SimOnly import Tmaxneuronal
Hopf.initialValue = 0.1
neuronalModel = Hopf

# Set up our integrator
import WholeBrain.Integrator_EulerMaruyama as myIntegrator
integrator = myIntegrator
integrator.neuronalModel = neuronalModel
integrator.verbose = False
integrator.clamping = False

# Set up the integration parameters
dt = 5e-5
# tmax is equal to the number of timepoints: 193
tmax= 193
ds = 1e-4
Tmaxneuronal = int((tmax+dt))

import WholeBrain.simulate_SimOnly as simulateBOLD
simulateBOLD.warmUp = True
simulateBOLD.integrator = integrator
simulateBOLD.warmUpFactor = 606./2000.

# Set up the code to obtain the variables we want to maximize similarity to empirical FC
import WholeBrain.Observables.FC as FC
#import WholeBrain.Observables.swFCD as swFCD
import WholeBrain.Observables.phFCD as phFCD
import WholeBrain.Optimizers.ParmSeep as ParmSeep
ParmSeep.simulateBOLD = simulateBOLD
ParmSeep.integrator = integrator
ParmSeep.verbose = True

# set BOLD filter settings
import WholeBrain.Utils.filteredPowerSpectralDensity as filtPowSpectr
import WholeBrain.BOLDFilters as BOLDfilters

# These filters are applied in the filtPowSpectr function that we use to extract the intrinsic frequencies of each region.
# They are also applied to process the FC and swFCD and phFCD, but you can set the corresponding parameter to False later on. 0.04-0.07 Hz common to extract intrinsic frequencies
BOLDfilters.flp = 0.04
BOLDfilters.fhi = 0.07
BOLDfilters.TR = 3.0

# Get the list of names of all regions in the AAL atlas. This is needed to get the right indices, to then filter the FC
import csv
# This is a sublist of labels of the cortical regions that were included in the paper by Demirtas et al. - AAL atlas (78 regions, excluding infratentorial and deep)
with open ('/home/riccardo/ADNI_Hopf/Utils/aal_regions_included.csv', newline='') as f:
    new_reader = csv.reader(f)
    included_regions = list(new_reader)
f.close()

# Get the AAL atlas labels
import nilearn.datasets as datasets
aal = datasets.fetch_atlas_aal()
labels = np.array(aal.labels)
# create an array with the indices of each label (note that these are not the label number from the nifti image)
indices = np.array([i for i in enumerate(labels)])
SC_regions_index = np.isin(labels, included_regions)
# filter the indices that we want based on the position so to have a final SC matrix only for the regions we considered.
SC_78_regions_aal_atlas = indices[SC_regions_index]
filter_SC = np.array([int(i) for i in SC_78_regions_aal_atlas[:,0]])

# Set file path for SC matrix
x_path = '/home/riccardo/ADNI_Hopf/Utils/'
# Load structural connectivity matrix and use it as parameter in Hopf model
xfile = 'SCmatrices88healthy.mat' 
M = sio.loadmat(x_path + xfile); 
mat = M['SCmatrices']
# averaging the SC among subjects
mat0 = np.mean(mat,axis = 0)
# Filter the SC to have just the 78 regions we considered
x_mat0 = mat0[filter_SC]
new_mat0 = x_mat0.T[filter_SC]
# Prevent full synchronization of the model
SCnorm = new_mat0 * 0.2 / new_mat0.max() 
np.fill_diagonal(SCnorm,0)
print('SCnorm.shape={}'.format(new_mat0.shape))    
Hopf.setParms({'SC':SCnorm})

# ------------------------------------------------
# Retrieve the data for chosens subjects 
# ------------------------------------------------

conditionToStudy='mci' #lower case, can be hc or mci or all

if conditionToStudy == 'hc':
    timeseries = np.load('/home/riccardo/ADNI_Hopf/Results/timeseries_HC.npy')
    nsubjects, nNodes, Tmax = timeseries.shape
    all_fMRI = {s: d for s,d in enumerate(timeseries)} 
    
elif conditionToStudy == 'mci':
    timeseries = np.load('/home/riccardo/ADNI_Hopf/Results/timeseries_MCI.npy')
    nsubjects, nNodes, Tmax = timeseries.shape
    all_fMRI = {s: d for s,d in enumerate(timeseries)} 

elif conditionToStudy == 'all':
    timeseries = np.load('/home/riccardo/ADNI_Hopf/Results/timeseries_MCI.npy')
    nsubjects, nNodes, Tmax = timeseries.shape
    all_fMRI = {s: d for s,d in enumerate(timeseries)} 

# Since we aleardy filtered the data in the previous step from Nilearn, we aren't going to filter them again. Otherwise, a possible alternative, could be to add another
# BOLDfilters to actually re-set the filters after the f_diff was extracted and before the call to the simulation.
distanceSettings = {'FC': (FC, True), 'phFCD': (phFCD, True)}

simulateBOLD.TR = 3.  # Recording interval: 1 sample every 3 seconds
simulateBOLD.dt = 0.1 * simulateBOLD.TR / 2.
simulateBOLD.Tmax = Tmax  # This is the length, in seconds
simulateBOLD.dtt = simulateBOLD.TR  # We are not using milliseconds
simulateBOLD.t_min = 10 * simulateBOLD.TR
# simulateBOLD.recomputeTmaxneuronal() <- do not update Tmaxneuronal this way!
# simulateBOLD.warmUpFactor = 6.
simulateBOLD.Tmaxneuronal = (Tmax-1) * simulateBOLD.TR + 30
integrator.ds = simulateBOLD.TR  # record every TR millisecond

# Hopf.beta = 0.01
f_diff = filtPowSpectr.filtPowSpetraMultipleSubjects(timeseries, TR=3.)  # should be baseline_group_ts .. or baseling_group[0].reshape((1,52,193))
f_diff[np.where(f_diff == 0)] = np.mean(f_diff[np.where(f_diff != 0)])  # f_diff(find(f_diff==0))=mean(f_diff(find(f_diff~=0)))

Hopf.omega = 2 * np.pi * f_diff

print("ADHopf Setup done!")

base_a_value = -0.02
warmUp = True
warmUpFactor = 10.

def computeSubjectSimulation():
    # integrator.neuronalModel.SC = C
    # integrator.initBookkeeping(N, Tmaxneuronal)
    if warmUp:
        currObsVars = integrator.warmUpAndSimulate(dt, Tmaxneuronal, TWarmUp=Tmaxneuronal/warmUpFactor)
    else:
        currObsVars = integrator.simulate(dt, Tmaxneuronal)
    # currObsVars = integrator.returnBookkeeping()  # curr_xn, curr_rn
    neuro_act = currObsVars[:,1,:]  # curr_rn
    return neuro_act
    

def loadXBurden(condition):
    # ------------------- load and stack the different wm burdens
    wm_hc = np.load('/home/riccardo/ADNI_Hopf/Results/wmh_volumes_HC.npy')
    wm_mci = np.load('/home/riccardo/ADNI_Hopf/Results/wmh_volumes_MCI.npy')
    wm_overall = np.load('/home/riccardo/ADNI_Hopf/Results/wmh_volumes_ALL.npy')
    # ------------------- load the specific subject wm
    if condition == 'hc':
        wmBurden = wm_hc
    elif condition == 'mci':
        wmBurden = wm_mci
    elif condition == 'all':
        wmBurden = wm_overall
    # ------------------- normalize and return
    # wmBurdenNorm = (wmBurden - np.min(wmBurden))/np.ptp(wmBurden)  # Normalize each individual in [0,1]
    wmBurdenNorm = (wmBurden - np.min(wm_overall))/np.ptp(wm_overall)  # Normalize the whole group in [0,1]
    return wmBurdenNorm

# ------------ load wm burden
wmBurden = loadXBurden(conditionToStudy)
mode = 'random'  # homogeneous/heterogeneous/random

# Note that this homogeneous is intended as homogeneous inside the same patient, so all regions of one patient have the same wmBurden, but different patients have different wmBurdens.
# Heterogenous, instead, means that different regions in the same patient have different wmBurdens
if mode == 'homogeneous':
    #avgwm = np.average(wmBurden)
    wmBurden = np.array([np.ones([nNodes]) * wmBurden[i] for i in range(len(wmBurden))])
elif mode == 'random':
    np.random.shuffle(wmBurden)


outFilePath = '/home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights'

def fittingPipeline_homogeneous(subj_fMRI,
                    distanceSettings,  # This is a dictionary of {name: (distance module, apply filters bool)}
                    wms, wmBurden, subjectName):
    print("\n\n###################################################################")
    print("# Fitting with ParmSeep")
    print("###################################################################\n")
    # Now, optimize all we (G) values: determine optimal G to work with
    wmParms = [{'a': base_a_value + (wmW * wmBurden)} for wmW in wmWs]
    fitting = ParmSeep.distanceForAll_Parms(subj_fMRI,
                                            wmWs, 
                                            wmParms,
                                            NumSimSubjects=1,
                                            distanceSettings=distanceSettings,
                                            parmLabel='a_random_between_subjects_',
                                            fileNameSuffix='_'+subjectName,
                                            outFilePath=outFilePath)

    optimal = {sd: distanceSettings[sd][0].findMinMax(fitting[sd]) for sd in distanceSettings}
    return optimal, fitting


if conditionToStudy == 'hc':
    subj_list = np.load('/home/riccardo/ADNI_Hopf/Results/subject_list_timeseries_HC.npy')
elif conditionToStudy == 'mci':
    subj_list = np.load('/home/riccardo/ADNI_Hopf/Results/subject_list_timeseries_MCI.npy')

subjectName = ''
warmUp = True
warmUpFactor = 10.
Hopf.setParms({'we': 2.9})
wmWs = np.round(np.arange(-0.1,0.1,0.005), 4)


def fittingPipeline_heterogeneous(all_fMRI, wmBurden, wmWs):
    
    best_parameters_dict = {}
    fitting_parameters_dict = {}

    for k, subjectName in enumerate(subj_list):
        subj_fMRI = {k:all_fMRI[k]}
        wmBurden_subj = wmBurden[k]
        best_parameters, fitting_parameters = fittingPipeline_homogeneous(subj_fMRI=subj_fMRI, distanceSettings=distanceSettings, subjectName=subjectName, wms=wmWs, wmBurden = wmBurden_subj)
        best_parameters_dict[subjectName] = best_parameters
        fitting_parameters_dict[subjectName] = fitting_parameters

    return best_parameters_dict, fitting_parameters_dict

    
best_parms_dict, fitting_parms_dict = fittingPipeline_heterogeneous(all_fMRI=all_fMRI, wmBurden=wmBurden, wmWs=wmWs)
# Out:
# SCnorm.shape=(78, 78)
# filtPowSpetraMultipleSubjects: subject 0 (of 18)
# filtPowSpetraMultipleSubjects: subject 1 (of 18)
# filtPowSpetraMultipleSubjects: subject 2 (of 18)
# filtPowSpetraMultipleSubjects: subject 3 (of 18)
# filtPowSpetraMultipleSubjects: subject 4 (of 18)
# filtPowSpetraMultipleSubjects: subject 5 (of 18)
# filtPowSpetraMultipleSubjects: subject 6 (of 18)
# filtPowSpetraMultipleSubjects: subject 7 (of 18)
# filtPowSpetraMultipleSubjects: subject 8 (of 18)
# filtPowSpetraMultipleSubjects: subject 9 (of 18)
# filtPowSpetraMultipleSubjects: subject 10 (of 18)
# filtPowSpetraMultipleSubjects: subject 11 (of 18)
# filtPowSpetraMultipleSubjects: subject 12 (of 18)
# filtPowSpetraMultipleSubjects: subject 13 (of 18)
# filtPowSpetraMultipleSubjects: subject 14 (of 18)
# filtPowSpetraMultipleSubjects: subject 15 (of 18)
# filtPowSpetraMultipleSubjects: subject 16 (of 18)
# filtPowSpetraMultipleSubjects: subject 17 (of 18)
# ADHopf Setup done!
#
#
# ###################################################################
# # Fitting with ParmSeep
# ###################################################################
#
#
#
# *************** Starting: optim1D.distanceForAll_Parms *****************
#
#
# tc(1 subjects): each entry has N=78 regions
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fNeuro_emp_ADNI002S1155.mat !!!
#
#
#  ====================== Model Simulations ======================
#
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.1_ADNI002S1155.mat !!!
# #0/1: FC: 0.10897357949798026; phFCD: 0.28410172718618254;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.095_ADNI002S1155.mat !!!
# #1/1: FC: 0.23826563304145562; phFCD: 0.11893104855161163;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.09_ADNI002S1155.mat !!!
# #2/1: FC: 0.15649389695211763; phFCD: 0.22412620699034408;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.085_ADNI002S1155.mat !!!
# #3/1: FC: 0.11064003801866931; phFCD: 0.34387324901400784;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.08_ADNI002S1155.mat !!!
# #4/1: FC: 0.08910928735374449; phFCD: 0.4759281925744594;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.075_ADNI002S1155.mat !!!
# #5/1: FC: 0.2414921328416069; phFCD: 0.24153406772745822;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.07_ADNI002S1155.mat !!!
# #6/1: FC: 0.14683051392409002; phFCD: 0.35094519243846056;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.065_ADNI002S1155.mat !!!
# #7/1: FC: 0.11068803567766716; phFCD: 0.38950088399292804;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.06_ADNI002S1155.mat !!!
# #8/1: FC: 0.11496836135087135; phFCD: 0.16265469876240995;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.055_ADNI002S1155.mat !!!
# #9/1: FC: 0.25707281263258686; phFCD: 0.3714130286957704;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.05_ADNI002S1155.mat !!!
# #10/1: FC: 0.06520527881196729; phFCD: 0.34747722018223853;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.045_ADNI002S1155.mat !!!
# #11/1: FC: 0.16338139086119452; phFCD: 0.36767305861553107;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.04_ADNI002S1155.mat !!!
# #12/1: FC: 0.27961233507851524; phFCD: 0.2367061063511492;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.035_ADNI002S1155.mat !!!
# #13/1: FC: 0.24350919025655873; phFCD: 0.15565075479396168;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.03_ADNI002S1155.mat !!!
# #14/1: FC: 0.1677332140058542; phFCD: 0.09649122807017546;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.025_ADNI002S1155.mat !!!
# #15/1: FC: 0.09601252127761835; phFCD: 0.1927104583163335;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.02_ADNI002S1155.mat !!!
# #16/1: FC: 0.0681926103772179; phFCD: 0.2246702026383789;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.015_ADNI002S1155.mat !!!
# #17/1: FC: 0.20264595009706587; phFCD: 0.070515435876513;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.01_ADNI002S1155.mat !!!
# #18/1: FC: 0.08493117050444667; phFCD: 0.1889024887800898;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.005_ADNI002S1155.mat !!!
# #19/1: FC: 0.16658549478265236; phFCD: 0.3774649802801578;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.0_ADNI002S1155.mat !!!
# #20/1: FC: 0.17654255417865225; phFCD: 0.19101047191622467;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.005_ADNI002S1155.mat !!!
# #21/1: FC: 0.18463321120916829; phFCD: 0.2656058751529988;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.01_ADNI002S1155.mat !!!
# #22/1: FC: 0.15677185871370575; phFCD: 0.1231470148238814;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.015_ADNI002S1155.mat !!!
# #23/1: FC: 0.262167938307776; phFCD: 0.04018767849857208;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.02_ADNI002S1155.mat !!!
# #24/1: FC: 0.2660470369828286; phFCD: 0.09771521827825377;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.025_ADNI002S1155.mat !!!
# #25/1: FC: 0.038571669548659086; phFCD: 0.17135862913096694;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.03_ADNI002S1155.mat !!!
# #26/1: FC: 0.21343264935425824; phFCD: 0.21916224670202636;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.035_ADNI002S1155.mat !!!
# #27/1: FC: 0.19709404123947957; phFCD: 0.2042703658370733;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.04_ADNI002S1155.mat !!!
# #28/1: FC: 0.20271900766635317; phFCD: 0.11498708010335923;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.045_ADNI002S1155.mat !!!
# #29/1: FC: 0.10781721326149733; phFCD: 0.1173670610635115;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.05_ADNI002S1155.mat !!!
# #30/1: FC: 0.11416303258707625; phFCD: 0.3331973344213246;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.055_ADNI002S1155.mat !!!
# #31/1: FC: 0.085773581434822; phFCD: 0.3995648034815722;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.06_ADNI002S1155.mat !!!
# #32/1: FC: 0.19098151743167788; phFCD: 0.15157078743370056;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.065_ADNI002S1155.mat !!!
# #33/1: FC: 0.2238610079907272; phFCD: 0.10172718618251064;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.07_ADNI002S1155.mat !!!
# #34/1: FC: 0.1676159843546436; phFCD: 0.3922208622331021;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.075_ADNI002S1155.mat !!!
# #35/1: FC: 0.12453676238492309; phFCD: 0.26125390996872033;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.08_ADNI002S1155.mat !!!
# #36/1: FC: 0.1370654066110671; phFCD: 0.5595675234598123;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.085_ADNI002S1155.mat !!!
# #37/1: FC: 0.21339854062185995; phFCD: 0.13851489188086502;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.09_ADNI002S1155.mat !!!
# #38/1: FC: 0.13182272526465072; phFCD: 0.0605875152998776;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.095_ADNI002S1155.mat !!!
# #39/1: FC: 0.13858412864356154; phFCD: 0.078811369509044;
#
#
#
# #####################################################################################################
# # Results (in (-0.1, 0.095)):
# #####################################################################################################
#
#
# DONE!!!
#
#
# ###################################################################
# # Fitting with ParmSeep
# ###################################################################
#
#
#
# *************** Starting: optim1D.distanceForAll_Parms *****************
#
#
# tc(1 subjects): each entry has N=78 regions
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fNeuro_emp_ADNI002S4229.mat !!!
#
#
#  ====================== Model Simulations ======================
#
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.1_ADNI002S4229.mat !!!
# #0/1: FC: 0.23946320028590892; phFCD: 0.3000135998912009;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.095_ADNI002S4229.mat !!!
# #1/1: FC: 0.2926130225748994; phFCD: 0.3036175710594315;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.09_ADNI002S4229.mat !!!
# #2/1: FC: 0.26655730345046247; phFCD: 0.36638106895144845;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.085_ADNI002S4229.mat !!!
# #3/1: FC: 0.25036276878885355; phFCD: 0.3532571739426085;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.08_ADNI002S4229.mat !!!
# #4/1: FC: 0.297257981116865; phFCD: 0.1962464300285598;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.075_ADNI002S4229.mat !!!
# #5/1: FC: 0.20977402074128462; phFCD: 0.0758873929008568;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.07_ADNI002S4229.mat !!!
# #6/1: FC: 0.1782131733204707; phFCD: 0.33278933768529856;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.065_ADNI002S4229.mat !!!
# #7/1: FC: 0.16216231973700815; phFCD: 0.18135454916360672;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.06_ADNI002S4229.mat !!!
# #8/1: FC: 0.2108183890456615; phFCD: 0.09315925472596218;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.055_ADNI002S4229.mat !!!
# #9/1: FC: 0.26227365297650274; phFCD: 0.19658642730858156;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.05_ADNI002S4229.mat !!!
# #10/1: FC: 0.10431129992519314; phFCD: 0.13715490276077802;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.045_ADNI002S4229.mat !!!
# #11/1: FC: 0.29220425603310907; phFCD: 0.2714538283693731;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.04_ADNI002S4229.mat !!!
# #12/1: FC: 0.22608010349819171; phFCD: 0.255609955120359;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.035_ADNI002S4229.mat !!!
# #13/1: FC: 0.3271768659352843; phFCD: 0.26329389364885086;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.03_ADNI002S4229.mat !!!
# #14/1: FC: 0.2994685196584455; phFCD: 0.16523867809057524;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.025_ADNI002S4229.mat !!!
# #15/1: FC: 0.2519453460189414; phFCD: 0.1859785121719026;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.02_ADNI002S4229.mat !!!
# #16/1: FC: 0.2582779377435966; phFCD: 0.3476132190942472;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.015_ADNI002S4229.mat !!!
# #17/1: FC: 0.23704135513433175; phFCD: 0.29171766625866996;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.01_ADNI002S4229.mat !!!
# #18/1: FC: 0.22045376016466228; phFCD: 0.20243438052495583;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.005_ADNI002S4229.mat !!!
# #19/1: FC: 0.3135659526966993; phFCD: 0.29763361893104856;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.0_ADNI002S4229.mat !!!
# #20/1: FC: 0.23467057914431533; phFCD: 0.07867537059703528;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.005_ADNI002S4229.mat !!!
# #21/1: FC: 0.31491667192219464; phFCD: 0.1966544267645859;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.01_ADNI002S4229.mat !!!
# #22/1: FC: 0.23329929457186097; phFCD: 0.08873929008567938;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.015_ADNI002S4229.mat !!!
# #23/1: FC: 0.24922813528390222; phFCD: 0.25384196926424585;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.02_ADNI002S4229.mat !!!
# #24/1: FC: 0.20206941592547945; phFCD: 0.07928736570107442;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.025_ADNI002S4229.mat !!!
# #25/1: FC: 0.22883672514071304; phFCD: 0.15075479396164837;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.03_ADNI002S4229.mat !!!
# #26/1: FC: 0.3278350654676589; phFCD: 0.18625050999592002;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.035_ADNI002S4229.mat !!!
# #27/1: FC: 0.18096935249336707; phFCD: 0.5486196110431116;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.04_ADNI002S4229.mat !!!
# #28/1: FC: 0.32772293350735837; phFCD: 0.07683938528491774;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.045_ADNI002S4229.mat !!!
# #29/1: FC: 0.27686927838880226; phFCD: 0.1377668978648171;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.05_ADNI002S4229.mat !!!
# #30/1: FC: 0.3492025277376191; phFCD: 0.12260301917584662;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.055_ADNI002S4229.mat !!!
# #31/1: FC: 0.25303234740558733; phFCD: 0.15313477492180066;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.06_ADNI002S4229.mat !!!
# #32/1: FC: 0.25451782428099773; phFCD: 0.15510675914592686;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.065_ADNI002S4229.mat !!!
# #33/1: FC: 0.24570256049770475; phFCD: 0.7034543723650211;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.07_ADNI002S4229.mat !!!
# #34/1: FC: 0.1759442221960896; phFCD: 0.8540731674146608;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.075_ADNI002S4229.mat !!!
# #35/1: FC: 0.2184797510111447; phFCD: 0.7933496532027744;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.08_ADNI002S4229.mat !!!
# #36/1: FC: 0.1695088501986876; phFCD: 0.9963960288317694;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.085_ADNI002S4229.mat !!!
# #37/1: FC: 0.16378024124858515; phFCD: 0.9914320685434516;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.09_ADNI002S4229.mat !!!
# #38/1: FC: 0.2879783652755148; phFCD: 0.9152046783625731;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.095_ADNI002S4229.mat !!!
# #39/1: FC: 0.21914326359911052; phFCD: 0.9817761457908337;
#
#
#
# #####################################################################################################
# # Results (in (-0.1, 0.095)):
# #####################################################################################################
#
#
# DONE!!!
#
#
# ###################################################################
# # Fitting with ParmSeep
# ###################################################################
#
#
#
# *************** Starting: optim1D.distanceForAll_Parms *****************
#
#
# tc(1 subjects): each entry has N=78 regions
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fNeuro_emp_ADNI002S4654.mat !!!
#
#
#  ====================== Model Simulations ======================
#
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.1_ADNI002S4654.mat !!!
# #0/1: FC: 0.19192138032815023; phFCD: 0.4046647626818986;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.095_ADNI002S4654.mat !!!
# #1/1: FC: 0.2118332379841909; phFCD: 0.20454236366109074;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.09_ADNI002S4654.mat !!!
# #2/1: FC: 0.24966580648781306; phFCD: 0.04508363933088533;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.085_ADNI002S4654.mat !!!
# #3/1: FC: 0.21435074854241642; phFCD: 0.36223310213518295;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.08_ADNI002S4654.mat !!!
# #4/1: FC: 0.25065170448907503; phFCD: 0.25608595131238954;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.075_ADNI002S4654.mat !!!
# #5/1: FC: 0.1772415020200995; phFCD: 0.07534339725282196;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.07_ADNI002S4654.mat !!!
# #6/1: FC: 0.142382977247504; phFCD: 0.17503059975520197;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.065_ADNI002S4654.mat !!!
# #7/1: FC: 0.2478322265671384; phFCD: 0.0556915544675643;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.06_ADNI002S4654.mat !!!
# #8/1: FC: 0.14167621640014952; phFCD: 0.2624779001767986;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.055_ADNI002S4654.mat !!!
# #9/1: FC: 0.1910019594364921; phFCD: 0.11213110295117643;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.05_ADNI002S4654.mat !!!
# #10/1: FC: 0.15714647299457196; phFCD: 0.273765809873521;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.045_ADNI002S4654.mat !!!
# #11/1: FC: 0.2587075389862276; phFCD: 0.1051951584387324;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.04_ADNI002S4654.mat !!!
# #12/1: FC: 0.15763713639151822; phFCD: 0.12117503059975515;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.035_ADNI002S4654.mat !!!
# #13/1: FC: 0.2307581976366811; phFCD: 0.08431932544539644;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.03_ADNI002S4654.mat !!!
# #14/1: FC: 0.20542414595663436; phFCD: 0.144702842377261;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.025_ADNI002S4654.mat !!!
# #15/1: FC: 0.13401841488889601; phFCD: 0.1952264381884945;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.02_ADNI002S4654.mat !!!
# #16/1: FC: 0.13205707376306608; phFCD: 0.3338773289813681;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.015_ADNI002S4654.mat !!!
# #17/1: FC: 0.21539402328106544; phFCD: 0.1234190126478989;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.01_ADNI002S4654.mat !!!
# #18/1: FC: 0.20732759285904134; phFCD: 0.15741874065007483;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.005_ADNI002S4654.mat !!!
# #19/1: FC: 0.18172607560276569; phFCD: 0.13593091255269957;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.0_ADNI002S4654.mat !!!
# #20/1: FC: 0.17497855211577423; phFCD: 0.16591867265061888;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.005_ADNI002S4654.mat !!!
# #21/1: FC: 0.2767118800126046; phFCD: 0.09390724874201009;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.01_ADNI002S4654.mat !!!
# #22/1: FC: 0.26585725627006895; phFCD: 0.3377532979736162;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.015_ADNI002S4654.mat !!!
# #23/1: FC: 0.160908734224114; phFCD: 0.15565075479396168;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.02_ADNI002S4654.mat !!!
# #24/1: FC: 0.21069362081077525; phFCD: 0.15272677818577451;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.025_ADNI002S4654.mat !!!
# #25/1: FC: 0.16600756022192847; phFCD: 0.2705018359853122;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.03_ADNI002S4654.mat !!!
# #26/1: FC: 0.3001539480330192; phFCD: 0.09295525635794916;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.035_ADNI002S4654.mat !!!
# #27/1: FC: 0.23122066833656854; phFCD: 0.11838705290357687;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.04_ADNI002S4654.mat !!!
# #28/1: FC: 0.30065770376566314; phFCD: 0.4004487964096287;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.045_ADNI002S4654.mat !!!
# #29/1: FC: 0.24620914402940192; phFCD: 0.2585339317285462;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.05_ADNI002S4654.mat !!!
# #30/1: FC: 0.21036847903460473; phFCD: 0.05059159526723789;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.055_ADNI002S4654.mat !!!
# #31/1: FC: 0.19206886050107247; phFCD: 0.08261933904528762;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.06_ADNI002S4654.mat !!!
# #32/1: FC: 0.23181778499099412; phFCD: 0.18373453012375904;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.065_ADNI002S4654.mat !!!
# #33/1: FC: 0.2205605779408084; phFCD: 0.07391540867673052;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.07_ADNI002S4654.mat !!!
# #34/1: FC: 0.1570508635930205; phFCD: 0.2745138038895689;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.075_ADNI002S4654.mat !!!
# #35/1: FC: 0.13409315662398974; phFCD: 0.6216510267917857;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.08_ADNI002S4654.mat !!!
# #36/1: FC: 0.23491447715559674; phFCD: 0.078811369509044;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.085_ADNI002S4654.mat !!!
# #37/1: FC: 0.15272028041718164; phFCD: 0.23310213518291856;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.09_ADNI002S4654.mat !!!
# #38/1: FC: 0.14507586433854883; phFCD: 0.5539915680674554;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.095_ADNI002S4654.mat !!!
# #39/1: FC: 0.214057188807948; phFCD: 0.34475724194206453;
#
#
#
# #####################################################################################################
# # Results (in (-0.1, 0.095)):
# #####################################################################################################
#
#
# DONE!!!
#
#
# ###################################################################
# # Fitting with ParmSeep
# ###################################################################
#
#
#
# *************** Starting: optim1D.distanceForAll_Parms *****************
#
#
# tc(1 subjects): each entry has N=78 regions
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fNeuro_emp_ADNI003S6258.mat !!!
#
#
#  ====================== Model Simulations ======================
#
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.1_ADNI003S6258.mat !!!
# #0/1: FC: 0.1935047218634728; phFCD: 0.6736026111791107;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.095_ADNI003S6258.mat !!!
# #1/1: FC: 0.126580313642115; phFCD: 0.5781993744050048;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.09_ADNI003S6258.mat !!!
# #2/1: FC: 0.14155707340555373; phFCD: 0.6169590643274854;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.085_ADNI003S6258.mat !!!
# #3/1: FC: 0.13587505377135684; phFCD: 0.6200190398476813;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.08_ADNI003S6258.mat !!!
# #4/1: FC: 0.1316824243258619; phFCD: 0.6659186726506188;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.075_ADNI003S6258.mat !!!
# #5/1: FC: 0.10018445659101315; phFCD: 0.5950632394940841;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.07_ADNI003S6258.mat !!!
# #6/1: FC: 0.228121350016383; phFCD: 0.42975656194750445;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.065_ADNI003S6258.mat !!!
# #7/1: FC: 0.1830176350023994; phFCD: 0.5288997688018495;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.06_ADNI003S6258.mat !!!
# #8/1: FC: 0.16892327079025482; phFCD: 0.5072079423364613;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.055_ADNI003S6258.mat !!!
# #9/1: FC: 0.10864275337476606; phFCD: 0.5703794369645043;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.05_ADNI003S6258.mat !!!
# #10/1: FC: 0.21316838165920615; phFCD: 0.5316877464980281;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.045_ADNI003S6258.mat !!!
# #11/1: FC: 0.2052445836143295; phFCD: 0.5145518835849314;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.04_ADNI003S6258.mat !!!
# #12/1: FC: 0.12418088459725103; phFCD: 0.5191078471372229;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.035_ADNI003S6258.mat !!!
# #13/1: FC: 0.13118047282564962; phFCD: 0.4388004895960832;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.03_ADNI003S6258.mat !!!
# #14/1: FC: 0.19372590763945546; phFCD: 0.3853529171766626;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.025_ADNI003S6258.mat !!!
# #15/1: FC: 0.1865061747064312; phFCD: 0.43914048687610496;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.02_ADNI003S6258.mat !!!
# #16/1: FC: 0.17560575750986976; phFCD: 0.034951720386236895;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.015_ADNI003S6258.mat !!!
# #17/1: FC: 0.16339163809943158; phFCD: 0.22154222766217868;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.01_ADNI003S6258.mat !!!
# #18/1: FC: 0.07867023091020048; phFCD: 0.16054671562627498;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.005_ADNI003S6258.mat !!!
# #19/1: FC: 0.2856045641308063; phFCD: 0.06629946960424316;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.0_ADNI003S6258.mat !!!
# #20/1: FC: 0.033918800585406444; phFCD: 0.15095879232966136;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.005_ADNI003S6258.mat !!!
# #21/1: FC: 0.0837850008737848; phFCD: 0.275125798993608;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.01_ADNI003S6258.mat !!!
# #22/1: FC: 0.08695174348675097; phFCD: 0.3905208758329934;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.015_ADNI003S6258.mat !!!
# #23/1: FC: 0.1868793234629228; phFCD: 0.9787161702706378;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.02_ADNI003S6258.mat !!!
# #24/1: FC: 0.08176299009092583; phFCD: 1.0;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.025_ADNI003S6258.mat !!!
# #25/1: FC: 0.1411384898271763; phFCD: 1.0;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.03_ADNI003S6258.mat !!!
# #26/1: FC: 0.1384410335863297; phFCD: 1.0;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.035_ADNI003S6258.mat !!!
# #27/1: FC: 0.15158882923583183; phFCD: 1.0;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.04_ADNI003S6258.mat !!!
# #28/1: FC: 0.12746603126352526; phFCD: 1.0;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.045_ADNI003S6258.mat !!!
# #29/1: FC: 0.1638243306796164; phFCD: 1.0;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.05_ADNI003S6258.mat !!!
# #30/1: FC: 0.1339511113668952; phFCD: 1.0;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.055_ADNI003S6258.mat !!!
# #31/1: FC: 0.12342567008485315; phFCD: 1.0;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.06_ADNI003S6258.mat !!!
# #32/1: FC: 0.1492174578168228; phFCD: 1.0;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.065_ADNI003S6258.mat !!!
# #33/1: FC: 0.13615022435111368; phFCD: 1.0;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.07_ADNI003S6258.mat !!!
# #34/1: FC: 0.1052193366249139; phFCD: 1.0;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.075_ADNI003S6258.mat !!!
# #35/1: FC: 0.11404244144518083; phFCD: 1.0;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.08_ADNI003S6258.mat !!!
# #36/1: FC: 0.13165839104940674; phFCD: 1.0;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.085_ADNI003S6258.mat !!!
# #37/1: FC: 0.12449789655498243; phFCD: 1.0;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.09_ADNI003S6258.mat !!!
# #38/1: FC: 0.1394843106495017; phFCD: 1.0;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.095_ADNI003S6258.mat !!!
# #39/1: FC: 0.1277581870174705; phFCD: 1.0;
#
#
#
# #####################################################################################################
# # Results (in (-0.1, 0.095)):
# #####################################################################################################
#
#
# DONE!!!
#
#
# ###################################################################
# # Fitting with ParmSeep
# ###################################################################
#
#
#
# *************** Starting: optim1D.distanceForAll_Parms *****************
#
#
# tc(1 subjects): each entry has N=78 regions
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fNeuro_emp_ADNI003S6268.mat !!!
#
#
#  ====================== Model Simulations ======================
#
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.1_ADNI003S6268.mat !!!
# #0/1: FC: 0.29314823438965193; phFCD: 0.049571603427172595;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.095_ADNI003S6268.mat !!!
# #1/1: FC: 0.2679688175761123; phFCD: 0.051135590915272644;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.09_ADNI003S6268.mat !!!
# #2/1: FC: 0.18292101202561542; phFCD: 0.1712906296749626;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.085_ADNI003S6268.mat !!!
# #3/1: FC: 0.14315616647730528; phFCD: 0.23534611723106214;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.08_ADNI003S6268.mat !!!
# #4/1: FC: 0.16568472506374526; phFCD: 0.13742690058479534;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.075_ADNI003S6268.mat !!!
# #5/1: FC: 0.15760131314772305; phFCD: 0.1687746498028016;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.07_ADNI003S6268.mat !!!
# #6/1: FC: 0.1538749399446684; phFCD: 0.22562219502243985;
#
# ...
#    Processing signal 1/1 Subject: 0 (78x193) -> computed in 3.840295510002761 seconds
#    --- TOTAL TIME: 4.099981809999008 seconds ---
# #11/1: FC: 0.19763106874551598; phFCD: 0.161702706378349;
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.04_ADNI070S6236.mat
#    --- BEGIN TIME @ a_random_between_subjects_=-0.04 ---
# Current a is: -0.05185458118398428
# Current G is: 2.9
#    Simulating a_random_between_subjects_=-0.04 -> subject 0/1!!!
#    Processing signal 1/1 Subject: 0 (78x193) -> computed in 4.224413308998919 seconds
#    --- TOTAL TIME: 4.502432910001517 seconds ---
# #12/1: FC: 0.18429674204039553; phFCD: 0.2815857473140214;
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.035_ADNI070S6236.mat
#    --- BEGIN TIME @ a_random_between_subjects_=-0.035 ---
# Current a is: -0.04787275853598625
# Current G is: 2.9
#    Simulating a_random_between_subjects_=-0.035 -> subject 0/1!!!
#    Processing signal 1/1 Subject: 0 (78x193) -> computed in 4.103789811000752 seconds
#    --- TOTAL TIME: 4.37369801100067 seconds ---
# #13/1: FC: 0.30322843502340185; phFCD: 0.25866993064055493;
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.03_ADNI070S6236.mat
#    --- BEGIN TIME @ a_random_between_subjects_=-0.03 ---
# Current a is: -0.04389093588798821
# Current G is: 2.9
#    Simulating a_random_between_subjects_=-0.03 -> subject 0/1!!!
#    Processing signal 1/1 Subject: 0 (78x193) -> computed in 4.202133811002568 seconds
#    --- TOTAL TIME: 4.475586411997938 seconds ---
# #14/1: FC: 0.18699179390367765; phFCD: 0.3648170814633483;
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.025_ADNI070S6236.mat
#    --- BEGIN TIME @ a_random_between_subjects_=-0.025 ---
# Current a is: -0.03990911323999018
# Current G is: 2.9
#    Simulating a_random_between_subjects_=-0.025 -> subject 0/1!!!
#    Processing signal 1/1 Subject: 0 (78x193) -> computed in 4.190161005000846 seconds
#    --- TOTAL TIME: 4.466458606002561 seconds ---
# #15/1: FC: 0.15211947202721476; phFCD: 0.20603835169318646;
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.02_ADNI070S6236.mat
#    --- BEGIN TIME @ a_random_between_subjects_=-0.02 ---
# Current a is: -0.035927290591992136
# Current G is: 2.9
#    Simulating a_random_between_subjects_=-0.02 -> subject 0/1!!!
#    Processing signal 1/1 Subject: 0 (78x193) -> computed in 4.411780903999897 seconds
#    --- TOTAL TIME: 4.68830710399925 seconds ---
# #16/1: FC: 0.19077997540407418; phFCD: 0.1466748266013872;
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.015_ADNI070S6236.mat
#    --- BEGIN TIME @ a_random_between_subjects_=-0.015 ---
# Current a is: -0.0319454679439941
# Current G is: 2.9
#    Simulating a_random_between_subjects_=-0.015 -> subject 0/1!!!
#    Processing signal 1/1 Subject: 0 (78x193) -> computed in 4.589437483999063 seconds
#    --- TOTAL TIME: 4.879549082997983 seconds ---
# #17/1: FC: 0.1406839573489248; phFCD: 0.08357133142934858;
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.01_ADNI070S6236.mat
#    --- BEGIN TIME @ a_random_between_subjects_=-0.01 ---
# Current a is: -0.02796364529599607
# Current G is: 2.9
#    Simulating a_random_between_subjects_=-0.01 -> subject 0/1!!!
#    Processing signal 1/1 Subject: 0 (78x193) -> computed in 4.305942659997527 seconds
#    --- TOTAL TIME: 4.577258356999664 seconds ---
# #18/1: FC: 0.23674018095828908; phFCD: 0.389296885624915;
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_-0.005_ADNI070S6236.mat
#    --- BEGIN TIME @ a_random_between_subjects_=-0.005 ---
# Current a is: -0.023981822647998037
# Current G is: 2.9
#    Simulating a_random_between_subjects_=-0.005 -> subject 0/1!!!
#    Processing signal 1/1 Subject: 0 (78x193) -> computed in 4.284949446999235 seconds
#    --- TOTAL TIME: 4.595251445000031 seconds ---
# #19/1: FC: 0.1913217148083172; phFCD: 0.1466748266013872;
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.0_ADNI070S6236.mat
#    --- BEGIN TIME @ a_random_between_subjects_=0.0 ---
# Current a is: -0.02
# Current G is: 2.9
#    Simulating a_random_between_subjects_=0.0 -> subject 0/1!!!
#    Processing signal 1/1 Subject: 0 (78x193) -> computed in 4.312150161000318 seconds
#    --- TOTAL TIME: 4.5899297569994815 seconds ---
# #20/1: FC: 0.17672543955219816; phFCD: 0.35278117775057793;
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.005_ADNI070S6236.mat
#    --- BEGIN TIME @ a_random_between_subjects_=0.005 ---
# Current a is: -0.016018177352001964
# Current G is: 2.9
#    Simulating a_random_between_subjects_=0.005 -> subject 0/1!!!
#    Processing signal 1/1 Subject: 0 (78x193) -> computed in 4.10334226499981 seconds
#    --- TOTAL TIME: 4.380162762001419 seconds ---
# #21/1: FC: 0.1933599192853797; phFCD: 0.36270909832721343;
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.01_ADNI070S6236.mat
#    --- BEGIN TIME @ a_random_between_subjects_=0.01 ---
# Current a is: -0.01203635470400393
# Current G is: 2.9
#    Simulating a_random_between_subjects_=0.01 -> subject 0/1!!!
#    Processing signal 1/1 Subject: 0 (78x193) -> computed in 4.058987445001549 seconds
#    --- TOTAL TIME: 4.345385642998735 seconds ---
# #22/1: FC: 0.13933955312551385; phFCD: 0.5357677138582891;
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.015_ADNI070S6236.mat
#    --- BEGIN TIME @ a_random_between_subjects_=0.015 ---
# Current a is: -0.008054532056005896
# Current G is: 2.9
#    Simulating a_random_between_subjects_=0.015 -> subject 0/1!!!
#    Processing signal 1/1 Subject: 0 (78x193) -> computed in 4.170279040001333 seconds
#    --- TOTAL TIME: 4.452135136001743 seconds ---
# #23/1: FC: 0.10828582004137242; phFCD: 0.6912144702842378;
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.02_ADNI070S6236.mat
#    --- BEGIN TIME @ a_random_between_subjects_=0.02 ---
# Current a is: -0.004072709408007861
# Current G is: 2.9
#    Simulating a_random_between_subjects_=0.02 -> subject 0/1!!!
#    Processing signal 1/1 Subject: 0 (78x193) -> computed in 4.253824464998615 seconds
#    --- TOTAL TIME: 4.557359661001101 seconds ---
# #24/1: FC: 0.1936485762671984; phFCD: 0.9993200054399565;
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.025_ADNI070S6236.mat
#    --- BEGIN TIME @ a_random_between_subjects_=0.025 ---
# Current a is: -9.088676000982426e-05
# Current G is: 2.9
#    Simulating a_random_between_subjects_=0.025 -> subject 0/1!!!
#    Processing signal 1/1 Subject: 0 (78x193) -> computed in 3.9212002880012733 seconds
#    --- TOTAL TIME: 4.179460385999846 seconds ---
# #25/1: FC: 0.095127181087933; phFCD: 1.0;
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.03_ADNI070S6236.mat
#    --- BEGIN TIME @ a_random_between_subjects_=0.03 ---
# Current a is: 0.003890935887988209
# Current G is: 2.9
#    Simulating a_random_between_subjects_=0.03 -> subject 0/1!!!
#    Processing signal 1/1 Subject: 0 (78x193) -> computed in 4.019899995000742 seconds
#    --- TOTAL TIME: 4.279045194998616 seconds ---
# #26/1: FC: 0.15674064117954137; phFCD: 1.0;
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.035_ADNI070S6236.mat
#    --- BEGIN TIME @ a_random_between_subjects_=0.035 ---
# Current a is: 0.007872758535986249
# Current G is: 2.9
#    Simulating a_random_between_subjects_=0.035 -> subject 0/1!!!
#    Processing signal 1/1 Subject: 0 (78x193) -> computed in 4.197913998999866 seconds
#    --- TOTAL TIME: 4.472365697998612 seconds ---
# #27/1: FC: 0.15341577509521398; phFCD: 1.0;
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.04_ADNI070S6236.mat
#    --- BEGIN TIME @ a_random_between_subjects_=0.04 ---
# Current a is: 0.011854581183984279
# Current G is: 2.9
#    Simulating a_random_between_subjects_=0.04 -> subject 0/1!!!
#    Processing signal 1/1 Subject: 0 (78x193) -> computed in 4.310706260999723 seconds
#    --- TOTAL TIME: 4.593752365999535 seconds ---
# #28/1: FC: 0.06009379511819808; phFCD: 1.0;
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.045_ADNI070S6236.mat
#    --- BEGIN TIME @ a_random_between_subjects_=0.045 ---
# Current a is: 0.015836403831982312
# Current G is: 2.9
#    Simulating a_random_between_subjects_=0.045 -> subject 0/1!!!
#    Processing signal 1/1 Subject: 0 (78x193) -> computed in 4.355362246002187 seconds
#    --- TOTAL TIME: 4.644141046999721 seconds ---
# #29/1: FC: 0.10739774269231704; phFCD: 1.0;
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.05_ADNI070S6236.mat
#    --- BEGIN TIME @ a_random_between_subjects_=0.05 ---
# Current a is: 0.019818226479980352
# Current G is: 2.9
#    Simulating a_random_between_subjects_=0.05 -> subject 0/1!!!
#    Processing signal 1/1 Subject: 0 (78x193) -> computed in 4.416962397001043 seconds
#    --- TOTAL TIME: 4.752764085002127 seconds ---
# #30/1: FC: 0.1540358334056202; phFCD: 1.0;
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.055_ADNI070S6236.mat
#    --- BEGIN TIME @ a_random_between_subjects_=0.055 ---
# Current a is: 0.023800049127978385
# Current G is: 2.9
#    Simulating a_random_between_subjects_=0.055 -> subject 0/1!!!
#    Processing signal 1/1 Subject: 0 (78x193) -> computed in 4.658091635999881 seconds
#    --- TOTAL TIME: 4.938411732000532 seconds ---
# #31/1: FC: 0.11140891939890092; phFCD: 1.0;
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.06_ADNI070S6236.mat
#    --- BEGIN TIME @ a_random_between_subjects_=0.06 ---
# Current a is: 0.027781871775976418
# Current G is: 2.9
#    Simulating a_random_between_subjects_=0.06 -> subject 0/1!!!
#    Processing signal 1/1 Subject: 0 (78x193) -> computed in 4.404373550001765 seconds
#    --- TOTAL TIME: 4.716865845002758 seconds ---
# #32/1: FC: 0.12727167782303467; phFCD: 1.0;
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.065_ADNI070S6236.mat
#    --- BEGIN TIME @ a_random_between_subjects_=0.065 ---
# Current a is: 0.03176369442397446
# Current G is: 2.9
#    Simulating a_random_between_subjects_=0.065 -> subject 0/1!!!
#    Processing signal 1/1 Subject: 0 (78x193) -> computed in 4.685344567998982 seconds
#    --- TOTAL TIME: 4.975898954999138 seconds ---
# #33/1: FC: 0.1333977736608483; phFCD: 1.0;
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.07_ADNI070S6236.mat
#    --- BEGIN TIME @ a_random_between_subjects_=0.07 ---
# Current a is: 0.0357455170719725
# Current G is: 2.9
#    Simulating a_random_between_subjects_=0.07 -> subject 0/1!!!
#    Processing signal 1/1 Subject: 0 (78x193) -> computed in 5.211360429999331 seconds
#    --- TOTAL TIME: 5.525260424998123 seconds ---
# #34/1: FC: 0.11638739178654833; phFCD: 1.0;
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.075_ADNI070S6236.mat
#    --- BEGIN TIME @ a_random_between_subjects_=0.075 ---
# Current a is: 0.03972733971997053
# Current G is: 2.9
#    Simulating a_random_between_subjects_=0.075 -> subject 0/1!!!
#    Processing signal 1/1 Subject: 0 (78x193) -> computed in 4.420671037998545 seconds
#    --- TOTAL TIME: 4.736703933998797 seconds ---
# #35/1: FC: 0.09124279393459764; phFCD: 1.0;
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.08_ADNI070S6236.mat
#    --- BEGIN TIME @ a_random_between_subjects_=0.08 ---
# Current a is: 0.043709162367968554
# Current G is: 2.9
#    Simulating a_random_between_subjects_=0.08 -> subject 0/1!!!
#    Processing signal 1/1 Subject: 0 (78x193) -> computed in 4.268528063999838 seconds
#    --- TOTAL TIME: 4.552666261999548 seconds ---
# #36/1: FC: 0.1479501529210909; phFCD: 1.0;
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.085_ADNI070S6236.mat
#    --- BEGIN TIME @ a_random_between_subjects_=0.085 ---
# Current a is: 0.047690985015966594
# Current G is: 2.9
#    Simulating a_random_between_subjects_=0.085 -> subject 0/1!!!
#    Processing signal 1/1 Subject: 0 (78x193) -> computed in 4.193733470998268 seconds
#    --- TOTAL TIME: 4.533215968996956 seconds ---
# #37/1: FC: 0.16470783524779378; phFCD: 1.0;
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.09_ADNI070S6236.mat
#    --- BEGIN TIME @ a_random_between_subjects_=0.09 ---
# Current a is: 0.05167280766396462
# Current G is: 2.9
#    Simulating a_random_between_subjects_=0.09 -> subject 0/1!!!
#    Processing signal 1/1 Subject: 0 (78x193) -> computed in 4.121763300998282 seconds
#    --- TOTAL TIME: 4.397107299999334 seconds ---
# #38/1: FC: 0.1725810315009656; phFCD: 1.0;
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_random_weights/fitting_a_random_between_subjects_0.095_ADNI070S6236.mat
#    --- BEGIN TIME @ a_random_between_subjects_=0.095 ---
# Current a is: 0.05565463031196266
# Current G is: 2.9
#    Simulating a_random_between_subjects_=0.095 -> subject 0/1!!!
#    Processing signal 1/1 Subject: 0 (78x193) -> computed in 5.1740871410002 seconds
#    --- TOTAL TIME: 5.473792143999162 seconds ---
# #39/1: FC: 0.13721683215641792; phFCD: 1.0;
#
#
#
# #####################################################################################################
# # Results (in (-0.1, 0.095)):
# #####################################################################################################
#
#
# DONE!!!

# %%
if conditionToStudy == 'hc':

    # open file for writing, "w" 
    f = open("/home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/random_model_best_parameters_dictionary_HC.pkl","wb")
    # write json object to file
    pickle.dump(best_parms_dict, f)
    # close file
    f.close()
    # open file for writing, "w" 
    g = open("/home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/random_model_fitting_parameters_dictionary_HC.pkl","wb")
    # write json object to file
    pickle.dump(fitting_parms_dict, g)
    # close file
    g.close()

elif conditionToStudy == 'mci':

    # open file for writing, "w" 
    f = open("/home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/random_model_best_parameters_dictionary_MCI_.pkl","wb")
    # write json object to file
    pickle.dump(best_parms_dict, f)
    # close file
    f.close()
    # open file for writing, "w" 
    g = open("/home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/random_model_fitting_parameters_dictionary_MCI.pkl","wb")
    # write json object to file
    pickle.dump(fitting_parms_dict, g)
    # close file
    g.close()
