# %% [markdown]
# This notebook calculates the fitting for FC and phFCD for all patients with $a = -0.02$ and the best $G$ that we found $G=2.55$

# %%
# Load all the packages needed for analyses
import sys
import numpy as np
import scipy.io as sio
from numba import jit
import matplotlib.pyplot as plt

# Set up Hopf as our model 
import WholeBrain.Models.supHopf as Hopf
from WholeBrain.simulate_SimOnly import Tmaxneuronal
Hopf.initialValue = 0.1
neuronalModel = Hopf

# Set up our integrator
import WholeBrain.Integrator_EulerMaruyama as myIntegrator
integrator = myIntegrator
integrator.neuronalModel = neuronalModel
integrator.verbose = False
integrator.clamping = False

# Set up the integration parameters
dt = 5e-5
# tmax is equal to the number of timepoints: 193
tmax= 193
ds = 1e-4
Tmaxneuronal = int((tmax+dt))

import WholeBrain.simulate_SimOnly as simulateBOLD
simulateBOLD.warmUp = True
simulateBOLD.integrator = integrator
simulateBOLD.warmUpFactor = 606./2000.

# Set up the code to obtain the variables we want to maximize similarity to empirical FC
import WholeBrain.Observables.FC as FC
import WholeBrain.Observables.swFCD as swFCD
import WholeBrain.Observables.phFCD as phFCD
import WholeBrain.Optimizers.ParmSeep as ParmSeep
ParmSeep.simulateBOLD = simulateBOLD
ParmSeep.integrator = integrator
ParmSeep.verbose = True


# set BOLD filter settings
import WholeBrain.Utils.filteredPowerSpectralDensity as filtPowSpectr
import WholeBrain.BOLDFilters as BOLDfilters

# These filters are applied in the filtPowSpectr function that we use to extract the intrinsic frequencies of each region.
# They are also applied to process the FC and swFCD and phFCD, but you can set the corresponding parameter to False later on. 0.04-0.07 Hz common to extract intrinsic frequencies
BOLDfilters.flp = 0.04
BOLDfilters.fhi = 0.07
BOLDfilters.TR = 3.0


# Get the list of names of all regions in the AAL atlas. This is needed to get the right indices, to then filter the FC
import csv
# This is a sublist of label of the cortical regions that were included in the paper by Demirtas et al. - AAL atlas (78 regions, excluding infratentorial and deep)
with open ('/home/riccardo/ADNI_Hopf/Utils/aal_regions_included.csv', newline='') as g:
    new_reader = csv.reader(g)
    included_regions = list(new_reader)
g.close()

# Get the AAL atlas labels
import nilearn.datasets as datasets
aal = datasets.fetch_atlas_aal()
labels = np.array(aal.labels)
# create an array with the indices of each label (note that these are not the label number from the nifti image)
indices = np.array([i for i in enumerate(labels)])
FC_regions_index = np.isin(labels, included_regions)
# filter the indices that we want based on the position 
FC_78_regions_aal_atlas = indices[FC_regions_index]
filter_FC = np.array([int(i) for i in FC_78_regions_aal_atlas[:,0]])

# Set file path.
x_path = '/home/riccardo/ADNI_Hopf/Utils/'

# Load structural connectivity matrix and use it as parameter in Hopf model
xfile = 'SCmatrices88healthy.mat' 
M = sio.loadmat(x_path + xfile); 
mat = M['SCmatrices']
# averaging the SC among subjects
mat0 = np.mean(mat,axis = 0)
x_mat0 = mat0[filter_FC]
new_mat0 = x_mat0.T[filter_FC]
SCnorm = new_mat0 * 0.2 / new_mat0.max() 
np.fill_diagonal(SCnorm,0)
print('SCnorm.shape={}'.format(new_mat0.shape))    
Hopf.setParms({'SC':SCnorm})

# ------------------------------------------------
# Configure and compute Simulation for fixed a = -0.02 and fitting G to HC to find the best G
# ------------------------------------------------
timeseries = np.load('/home/riccardo/ADNI_Hopf/Results/timeseries_all.npy')
nsubjects, nNodes, Tmax = timeseries.shape
all_fMRI = {s: d for s,d in enumerate(timeseries)} 
subjectName = ''
conditionToStudy='all'
mode = 'homogeneous'  # homogeneous/heterogeneous
# Since we aleardy filtered the data in the previous step from Nilearn, we aren't going to filter them again. Otherwise, a possible alternative, could be to add another
# BOLDfilters to actually re-set the filters after the f_diff was extracted and before the call to the simulation.
distanceSettings = {'FC': (FC, False), 'phFCD': (phFCD, False)}

simulateBOLD.TR = 3.  # Recording interval: 1 sample every 3 seconds
simulateBOLD.dt = 0.1 * simulateBOLD.TR / 2.
simulateBOLD.Tmax = Tmax  # This is the length, in seconds
simulateBOLD.dtt = simulateBOLD.TR  # We are not using milliseconds
simulateBOLD.t_min = 10 * simulateBOLD.TR
# simulateBOLD.recomputeTmaxneuronal() <- do not update Tmaxneuronal this way!
# simulateBOLD.warmUpFactor = 6.
simulateBOLD.Tmaxneuronal = (Tmax-1) * simulateBOLD.TR + 30
integrator.ds = simulateBOLD.TR  # record every TR millisecond

base_a_value = -0.02
# Hopf.beta = 0.01
f_diff = filtPowSpectr.filtPowSpetraMultipleSubjects(timeseries, TR=3.)  # should be baseline_group_ts .. or baseling_group[0].reshape((1,52,193))
f_diff[np.where(f_diff == 0)] = np.mean(f_diff[np.where(f_diff != 0)])  # f_diff(find(f_diff==0))=mean(f_diff(find(f_diff~=0)))

Hopf.setParms({'a': base_a_value})
Hopf.omega = 2 * np.pi * f_diff

print("ADHopf Setup done!")

warmUp = True
warmUpFactor = 10.

def computeSubjectSimulation():
    # integrator.neuronalModel.SC = C
    # integrator.initBookkeeping(N, Tmaxneuronal)
    if warmUp:
        currObsVars = integrator.warmUpAndSimulate(dt, Tmaxneuronal, TWarmUp=Tmaxneuronal/warmUpFactor)
    else:
        currObsVars = integrator.simulate(dt, Tmaxneuronal)
    # currObsVars = integrator.returnBookkeeping()  # curr_xn, curr_rn
    neuro_act = currObsVars[:,1,:]  # curr_rn
    return neuro_act
    
outFilePath = '/home/riccardo/ADNI_Hopf/Results/Modeling/Fitting_ALL_baseline'
Gs = np.array([2.55])

def fittingPipeline_homogeneous(all_fMRI,
                    distanceSettings,  # This is a dictionary of {name: (distance module, apply filters bool)}
                    gs):
    print("\n\n###################################################################")
    print("# Fitting with ParmSeep")
    print("###################################################################\n")
    # Now, optimize all we (G) values: determine optimal G to work with
    gParms = [{'we': g} for g in Gs]
    fitting = ParmSeep.distanceForAll_Parms(all_fMRI,
                                            Gs, 
                                            gParms,
                                            NumSimSubjects=len(all_fMRI),
                                            distanceSettings=distanceSettings,
                                            parmLabel='Homogeneous_a_G_',
                                            outFilePath=outFilePath)

    optimal = {sd: distanceSettings[sd][0].findMinMax(fitting[sd]) for sd in distanceSettings}
    return optimal


best_parameters = fittingPipeline_homogeneous(all_fMRI=all_fMRI, distanceSettings=distanceSettings, gs=Gs)
# Out:
# SCnorm.shape=(78, 78)
# filtPowSpetraMultipleSubjects: subject 0 (of 33)
# filtPowSpetraMultipleSubjects: subject 1 (of 33)
# filtPowSpetraMultipleSubjects: subject 2 (of 33)
# filtPowSpetraMultipleSubjects: subject 3 (of 33)
# filtPowSpetraMultipleSubjects: subject 4 (of 33)
# filtPowSpetraMultipleSubjects: subject 5 (of 33)
# filtPowSpetraMultipleSubjects: subject 6 (of 33)
# filtPowSpetraMultipleSubjects: subject 7 (of 33)
# filtPowSpetraMultipleSubjects: subject 8 (of 33)
# filtPowSpetraMultipleSubjects: subject 9 (of 33)
# filtPowSpetraMultipleSubjects: subject 10 (of 33)
# filtPowSpetraMultipleSubjects: subject 11 (of 33)
# filtPowSpetraMultipleSubjects: subject 12 (of 33)
# filtPowSpetraMultipleSubjects: subject 13 (of 33)
# filtPowSpetraMultipleSubjects: subject 14 (of 33)
# filtPowSpetraMultipleSubjects: subject 15 (of 33)
# filtPowSpetraMultipleSubjects: subject 16 (of 33)
# filtPowSpetraMultipleSubjects: subject 17 (of 33)
# filtPowSpetraMultipleSubjects: subject 18 (of 33)
# filtPowSpetraMultipleSubjects: subject 19 (of 33)
# filtPowSpetraMultipleSubjects: subject 20 (of 33)
# filtPowSpetraMultipleSubjects: subject 21 (of 33)
# filtPowSpetraMultipleSubjects: subject 22 (of 33)
# filtPowSpetraMultipleSubjects: subject 23 (of 33)
# filtPowSpetraMultipleSubjects: subject 24 (of 33)
# filtPowSpetraMultipleSubjects: subject 25 (of 33)
# filtPowSpetraMultipleSubjects: subject 26 (of 33)
# filtPowSpetraMultipleSubjects: subject 27 (of 33)
# filtPowSpetraMultipleSubjects: subject 28 (of 33)
# filtPowSpetraMultipleSubjects: subject 29 (of 33)
# filtPowSpetraMultipleSubjects: subject 30 (of 33)
# filtPowSpetraMultipleSubjects: subject 31 (of 33)
# filtPowSpetraMultipleSubjects: subject 32 (of 33)
# ADHopf Setup done!
#
#
# ###################################################################
# # Fitting with ParmSeep
# ###################################################################
#
#
#
# *************** Starting: optim1D.distanceForAll_Parms *****************
#
#
# tc(33 subjects): each entry has N=78 regions
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/Modeling/Fitting_ALL_baseline/fNeuro_emp.mat
#    Processing signal 1/33 Subject: 0 (78x193) -> computed in 3.682693784008734 seconds
#    Processing signal 2/33 Subject: 1 (78x193) -> computed in 3.646257261003484 seconds
#    Processing signal 3/33 Subject: 2 (78x193) -> computed in 3.5363338619936258 seconds
#    Processing signal 4/33 Subject: 3 (78x193) -> computed in 3.9008264199947007 seconds
#    Processing signal 5/33 Subject: 4 (78x193) -> computed in 4.142007675007335 seconds
#    Processing signal 6/33 Subject: 5 (78x193) -> computed in 3.515582492997055 seconds
#    Processing signal 7/33 Subject: 6 (78x193) -> computed in 3.7383169759996235 seconds
#    Processing signal 8/33 Subject: 7 (78x193) -> computed in 3.633829133992549 seconds
#    Processing signal 9/33 Subject: 8 (78x193) -> computed in 3.7871961150085554 seconds
#    Processing signal 10/33 Subject: 9 (78x193) -> computed in 4.036509272002149 seconds
#    Processing signal 11/33 Subject: 10 (78x193) -> computed in 3.755021417993703 seconds
#    Processing signal 12/33 Subject: 11 (78x193) -> computed in 4.985640806000447 seconds
#    Processing signal 13/33 Subject: 12 (78x193) -> computed in 4.0498295899888035 seconds
#    Processing signal 14/33 Subject: 13 (78x193) -> computed in 3.974543527001515 seconds
#    Processing signal 15/33 Subject: 14 (78x193) -> computed in 3.5947108389955247 seconds
#    Processing signal 16/33 Subject: 15 (78x193) -> computed in 3.6234773350006435 seconds
#    Processing signal 17/33 Subject: 16 (78x193) -> computed in 3.544093717006035 seconds
#    Processing signal 18/33 Subject: 17 (78x193) -> computed in 3.51971131299797 seconds
#    Processing signal 19/33 Subject: 18 (78x193) -> computed in 3.8413211109873373 seconds
#    Processing signal 20/33 Subject: 19 (78x193) -> computed in 3.317823153003701 seconds
#    Processing signal 21/33 Subject: 20 (78x193) -> computed in 3.2409771569946315 seconds
#    Processing signal 22/33 Subject: 21 (78x193) -> computed in 3.446577814000193 seconds
#    Processing signal 23/33 Subject: 22 (78x193) -> computed in 3.4123048160108738 seconds
#    Processing signal 24/33 Subject: 23 (78x193) -> computed in 3.063921648004907 seconds
#    Processing signal 25/33 Subject: 24 (78x193) -> computed in 3.251935032007168 seconds
#    Processing signal 26/33 Subject: 25 (78x193) -> computed in 3.5232018189999508 seconds
#    Processing signal 27/33 Subject: 26 (78x193) -> computed in 3.6261807970004156 seconds
#    Processing signal 28/33 Subject: 27 (78x193) -> computed in 3.6210904710023897 seconds
#    Processing signal 29/33 Subject: 28 (78x193) -> computed in 3.4169304039969575 seconds
#    Processing signal 30/33 Subject: 29 (78x193) -> computed in 3.961343407005188 seconds
#    Processing signal 31/33 Subject: 30 (78x193) -> computed in 3.6496497290063417 seconds
#    Processing signal 32/33 Subject: 31 (78x193) -> computed in 3.812682927993592 seconds
#    Processing signal 33/33 Subject: 32 (78x193) -> computed in 4.027686096000252 seconds
#
#
#  ====================== Model Simulations ======================
#
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/Modeling/Fitting_ALL_baseline/fitting_Homogeneous_a_G_2.55.mat
#    --- BEGIN TIME @ Homogeneous_a_G_=2.55 ---
# Current a is: -0.02
# Current G is: 2.55
#    Simulating Homogeneous_a_G_=2.55 -> subject 0/33!!!
#    Simulating Homogeneous_a_G_=2.55 -> subject 1/33!!!
#    Simulating Homogeneous_a_G_=2.55 -> subject 2/33!!!
#    Simulating Homogeneous_a_G_=2.55 -> subject 3/33!!!
#    Simulating Homogeneous_a_G_=2.55 -> subject 4/33!!!
#    Simulating Homogeneous_a_G_=2.55 -> subject 5/33!!!
#    Simulating Homogeneous_a_G_=2.55 -> subject 6/33!!!
#    Simulating Homogeneous_a_G_=2.55 -> subject 7/33!!!
#    Simulating Homogeneous_a_G_=2.55 -> subject 8/33!!!
#    Simulating Homogeneous_a_G_=2.55 -> subject 9/33!!!
#    Simulating Homogeneous_a_G_=2.55 -> subject 10/33!!!
#    Simulating Homogeneous_a_G_=2.55 -> subject 11/33!!!
#    Simulating Homogeneous_a_G_=2.55 -> subject 12/33!!!
#    Simulating Homogeneous_a_G_=2.55 -> subject 13/33!!!
#    Simulating Homogeneous_a_G_=2.55 -> subject 14/33!!!
#    Simulating Homogeneous_a_G_=2.55 -> subject 15/33!!!
#    Simulating Homogeneous_a_G_=2.55 -> subject 16/33!!!
#    Simulating Homogeneous_a_G_=2.55 -> subject 17/33!!!
#    Simulating Homogeneous_a_G_=2.55 -> subject 18/33!!!
#    Simulating Homogeneous_a_G_=2.55 -> subject 19/33!!!
#    Simulating Homogeneous_a_G_=2.55 -> subject 20/33!!!
#    Simulating Homogeneous_a_G_=2.55 -> subject 21/33!!!
#    Simulating Homogeneous_a_G_=2.55 -> subject 22/33!!!
#    Simulating Homogeneous_a_G_=2.55 -> subject 23/33!!!
#    Simulating Homogeneous_a_G_=2.55 -> subject 24/33!!!
#    Simulating Homogeneous_a_G_=2.55 -> subject 25/33!!!
#    Simulating Homogeneous_a_G_=2.55 -> subject 26/33!!!
#    Simulating Homogeneous_a_G_=2.55 -> subject 27/33!!!
#    Simulating Homogeneous_a_G_=2.55 -> subject 28/33!!!
#    Simulating Homogeneous_a_G_=2.55 -> subject 29/33!!!
#    Simulating Homogeneous_a_G_=2.55 -> subject 30/33!!!
#    Simulating Homogeneous_a_G_=2.55 -> subject 31/33!!!
#    Simulating Homogeneous_a_G_=2.55 -> subject 32/33!!!
#    Processing signal 1/33 Subject: 0 (78x193) -> computed in 4.18177958499291 seconds
#    Processing signal 2/33 Subject: 1 (78x193) -> computed in 3.6189006690110546 seconds
#    Processing signal 3/33 Subject: 2 (78x193) -> computed in 3.472434091003379 seconds
#    Processing signal 4/33 Subject: 3 (78x193) -> computed in 3.363377391011454 seconds
#    Processing signal 5/33 Subject: 4 (78x193) -> computed in 3.692508808002458 seconds
#    Processing signal 6/33 Subject: 5 (78x193) -> computed in 3.4383439119992545 seconds
#    Processing signal 7/33 Subject: 6 (78x193) -> computed in 3.3263409179926384 seconds
#    Processing signal 8/33 Subject: 7 (78x193) -> computed in 3.5537097269989317 seconds
#    Processing signal 9/33 Subject: 8 (78x193) -> computed in 3.606416237002122 seconds
#    Processing signal 10/33 Subject: 9 (78x193) -> computed in 3.5278247730020666 seconds
#    Processing signal 11/33 Subject: 10 (78x193) -> computed in 4.043194454003242 seconds
#    Processing signal 12/33 Subject: 11 (78x193) -> computed in 3.9378043780016014 seconds
#    Processing signal 13/33 Subject: 12 (78x193) -> computed in 3.6031439310027054 seconds
#    Processing signal 14/33 Subject: 13 (78x193) -> computed in 3.5303996760048904 seconds
#    Processing signal 15/33 Subject: 14 (78x193) -> computed in 3.3744952190027107 seconds
#    Processing signal 16/33 Subject: 15 (78x193) -> computed in 3.4095306970120873 seconds
#    Processing signal 17/33 Subject: 16 (78x193) -> computed in 3.9742358590010554 seconds
#    Processing signal 18/33 Subject: 17 (78x193) -> computed in 3.787543815007666 seconds
#    Processing signal 19/33 Subject: 18 (78x193) -> computed in 4.171988836009405 seconds
#    Processing signal 20/33 Subject: 19 (78x193) -> computed in 3.4138344149978366 seconds
#    Processing signal 21/33 Subject: 20 (78x193) -> computed in 3.4101546530000633 seconds
#    Processing signal 22/33 Subject: 21 (78x193) -> computed in 3.440138667996507 seconds
#    Processing signal 23/33 Subject: 22 (78x193) -> computed in 3.1600744699971983 seconds
#    Processing signal 24/33 Subject: 23 (78x193) -> computed in 3.2808406880067196 seconds
#    Processing signal 25/33 Subject: 24 (78x193) -> computed in 3.4198678199900314 seconds
#    Processing signal 26/33 Subject: 25 (78x193) -> computed in 3.4101903590053553 seconds
#    Processing signal 27/33 Subject: 26 (78x193) -> computed in 3.2627362000057474 seconds
#    Processing signal 28/33 Subject: 27 (78x193) -> computed in 3.2816321379941655 seconds
#    Processing signal 29/33 Subject: 28 (78x193) -> computed in 3.165021633001743 seconds
#    Processing signal 30/33 Subject: 29 (78x193) -> computed in 3.222516279987758 seconds
#    Processing signal 31/33 Subject: 30 (78x193) -> computed in 3.495202411999344 seconds
#    Processing signal 32/33 Subject: 31 (78x193) -> computed in 3.8218537630018545 seconds
#    Processing signal 33/33 Subject: 32 (78x193) -> computed in 4.198430382995866 seconds
#    --- TOTAL TIME: 127.25953700899845 seconds ---
# #0/1: FC: 0.42727413478786214; phFCD: 0.04659199090043642;
#
#
#
# #####################################################################################################
# # Results (in (2.55, 2.55)):
# # Optimal FC =     0.42727413478786214 @ 2.55
# # Optimal phFCD =     0.04659199090043642 @ 2.55
# #####################################################################################################
#
#
# DONE!!!

# %%
# Out:
# {'FC': (0.42446662773036603, 0), 'phFCD': (0.1147789605561943, 0)}
