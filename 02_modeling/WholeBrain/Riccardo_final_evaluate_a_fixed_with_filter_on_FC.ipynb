# %%
# Note that all the code is basically taken from Gustavo Patow's WholeBrain module (https://github.com/dagush/WholeBrain)

# Load all the packages needed for analyses
import sys
import numpy as np
import scipy.io as sio
from numba import jit
import matplotlib.pyplot as plt
import pickle
import nilearn

# Set up Hopf as our model 
import WholeBrain.Models.supHopf as Hopf
from WholeBrain.simulate_SimOnly import Tmaxneuronal
Hopf.initialValue = 0.1
neuronalModel = Hopf

# Set up our integrator
import WholeBrain.Integrator_EulerMaruyama as myIntegrator
integrator = myIntegrator
integrator.neuronalModel = neuronalModel
integrator.verbose = False
integrator.clamping = False

# Set up the integration parameters
dt = 5e-5
# tmax is equal to the number of timepoints: 193
tmax= 193
ds = 1e-4
Tmaxneuronal = int((tmax+dt))

import WholeBrain.simulate_SimOnly as simulateBOLD
simulateBOLD.warmUp = True
simulateBOLD.integrator = integrator
simulateBOLD.warmUpFactor = 606./2000.

# Set up the code to obtain the variables we want to maximize similarity to empirical FC
import WholeBrain.Observables.FC as FC
import WholeBrain.Observables.phFCD as phFCD
import WholeBrain.Optimizers.ParmSeep as ParmSeep
ParmSeep.simulateBOLD = simulateBOLD
ParmSeep.integrator = integrator
ParmSeep.verbose = True

# set BOLD filter settings
import WholeBrain.Utils.filteredPowerSpectralDensity as filtPowSpectr
import WholeBrain.BOLDFilters as BOLDfilters

# These filters are applied in the filtPowSpectr function that we use to extract the intrinsic frequencies of each region.
# They are also applied to process the FC and swFCD and phFCD, but you can set the corresponding parameter to False later on. 0.04-0.07 Hz common to extract intrinsic frequencies
BOLDfilters.flp = 0.04
BOLDfilters.fhi = 0.07
BOLDfilters.TR = 3.0

# Get the list of names of all regions in the AAL atlas. This is needed to get the right indices, to then filter the FC
import csv
# This is a sublist of labels of the cortical regions that were included in the paper by Demirtas et al. - AAL atlas (78 regions, excluding infratentorial and deep)
with open ('/home/riccardo/ADNI_Hopf/Utils/aal_regions_included.csv', newline='') as f:
    new_reader = csv.reader(f)
    included_regions = list(new_reader)
f.close()

# Get the AAL atlas labels
import nilearn.datasets as datasets
aal = datasets.fetch_atlas_aal()
labels = np.array(aal.labels)
# create an array with the indices of each label (note that these are not the label number from the nifti image)
indices = np.array([i for i in enumerate(labels)])
SC_regions_index = np.isin(labels, included_regions)
# filter the indices that we want based on the position so to have a final SC matrix only for the regions we considered.
SC_78_regions_aal_atlas = indices[SC_regions_index]
filter_SC = np.array([int(i) for i in SC_78_regions_aal_atlas[:,0]])

# Set file path for SC matrix
x_path = '/home/riccardo/ADNI_Hopf/Utils/'
# Load structural connectivity matrix and use it as parameter in Hopf model
xfile = 'SCmatrices88healthy.mat' 
M = sio.loadmat(x_path + xfile); 
mat = M['SCmatrices']
# averaging the SC among subjects
mat0 = np.mean(mat,axis = 0)
# Filter the SC to have just the 78 regions we considered
x_mat0 = mat0[filter_SC]
new_mat0 = x_mat0.T[filter_SC]
# Prevent full synchronization of the model
SCnorm = new_mat0 * 0.2 / new_mat0.max() 
np.fill_diagonal(SCnorm,0)
print('SCnorm.shape={}'.format(new_mat0.shape))    
Hopf.setParms({'SC':SCnorm})

# Set the base_a_value 
base_a_value = -0.027
# We want to warmup the timeseries before modeling
warmUp = True
warmUpFactor = 10.

# Set up useful functions that we will use later

def computeSubjectSimulation():
    # integrator.neuronalModel.SC = C
    # integrator.initBookkeeping(N, Tmaxneuronal)
    if warmUp:
        currObsVars = integrator.warmUpAndSimulate(dt, Tmaxneuronal, TWarmUp=Tmaxneuronal/warmUpFactor)
    else:
        currObsVars = integrator.simulate(dt, Tmaxneuronal)
    # currObsVars = integrator.returnBookkeeping()  # curr_xn, curr_rn
    neuro_act = currObsVars[:,1,:]  # curr_rn
    return neuro_act
    

def loadXBurden(dict_type):

    # ------------------- load and stack the different wm burdens
    if dict_type == 'global':
        homo_wm_file = open('/home/riccardo/ADNI_Hopf/Results/overall_WMH_burden_all_normalized.pkl','rb')
        dict_wm_overall = pickle.load(homo_wm_file)
    
    elif dict_type == 'regional':
        hetero_wm_file = open('/home/riccardo/ADNI_Hopf/Results/normalized_WMH_lobewise_all.pkl','rb')
        dict_wm_overall = pickle.load(hetero_wm_file)
            
    # wm_hc = np.load('/home/riccardo/ADNI_Hopf/Results/wmh_volumes_HC.npy')
    # wm_mci = np.load('/home/riccardo/ADNI_Hopf/Results/wmh_volumes_MCI.npy')
    # wm_overall = np.load('/home/riccardo/ADNI_Hopf/Results/wmh_volumes_ALL.npy')
    # ------------------- load the specific subject wm

    # ------------------- normalize and return
    # wmBurdenNorm = (wmBurden - np.min(wmBurden))/np.ptp(wmBurden)  # Normalize each individual in [0,1]
    #wmBurdenNorm = (wmBurden - np.min(wm_overall))/np.ptp(wm_overall)  # Normalize the whole group in [0,1]
    return dict_wm_overall


# ------------------------------------------------
# Retrieve the data for all subjects 
# ------------------------------------------------
conditionToStudy = 'mci' # one of 'hc', 'mci', 'all'
mode = 'baseline' # one of 'homogeneous', 'heterogeneous', 'baseline'
random = False # set to true if you want to shuffle the wmh weights

# Probably all of this could be done in a different script....
# Load the timeseries for all subjects
all_timeseries = np.load('/home/riccardo/ADNI_Hopf/Results/timeseries_all.npy')
# Get the number of nodes and the Tmax
nNodes, Tmax = all_timeseries.shape[1:]
# Load the subject names for all subjects
all_subjects_names = np.load('/home/riccardo/ADNI_Hopf/Results/subject_list_timeseries_all.npy')
# Load the overall normalized WMH burden for each subject
global_wm_overall = loadXBurden('global')
# Load the normalized regional WMH burden for each subject
regional_wm_overall = loadXBurden('regional')
# create a unified dictionary to make sure we don't make mistakes when filtering
all_dictionary = {k:{'timeseries': all_timeseries[n],
                     'total_WMH_load': global_wm_overall[k],
                     'regional_WMH_load': regional_wm_overall[k]} for n, k in np.ndenumerate(all_subjects_names)}

if conditionToStudy == 'hc':

    #load the names of HC
    subjects_names = np.load('/home/riccardo/ADNI_Hopf/Results/subject_list_timeseries_HC.npy')
    # filter the unified dictionary to retain just HC
    all_fMRI = {k:v['timeseries'] for k, v in all_dictionary.items() if k in subjects_names}
    nsubjects = len(all_fMRI) 

    if mode == 'homogeneous':
        wmBurden_dict = {k:v['total_WMH_load'] for k, v in all_dictionary.items() if k in subjects_names}
        wmBurden = np.array([v for v in wmBurden_dict.values()])

    elif mode == 'heterogeneous':
        wmBurden_dict ={k:v['regional_WMH_load'] for k, v in all_dictionary.items() if k in subjects_names} 
        wmBurden = np.array([v for v in wmBurden_dict.values()])
    else:
        filter_HC = np.load('/home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/subject_list_wmh_volumes_HC_minimal.npy', allow_pickle = True).flatten()
        all_fMRI = {k:v for k, v in all_fMRI.items() if k not in filter_HC}

elif conditionToStudy == 'mci':

    #load the names of MCI
    subjects_names = np.load('/home/riccardo/ADNI_Hopf/Results/subject_list_timeseries_MCI.npy')
    # filter the unified dictionary to retain just MCI
    all_fMRI = {k:v['timeseries'] for k, v in all_dictionary.items() if k in subjects_names}
    nsubjects = len(all_fMRI) 

    if mode == 'homogeneous':
        wmBurden_dict = {k:v['total_WMH_load'] for k, v in all_dictionary.items() if k in subjects_names}
        wmBurden = np.array([v for v in wmBurden_dict.values()])

    elif mode == 'heterogeneous':
        wmBurden_dict ={k:v['regional_WMH_load'] for k, v in all_dictionary.items() if k in subjects_names} 
        wmBurden = np.array([v for v in wmBurden_dict.values()])
    else:
        filter_MCI = np.load('/home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/subject_list_wmh_volumes_MCI_minimal.npy', allow_pickle = True).flatten()
        all_fMRI = {k:v for k, v in all_fMRI.items() if k in filter_MCI}
        wmBurden = np.zeros([78])

if random:
    np.random.shuffle(wmBurden)


# We haven't filtered in Nilearn, so we are going to filter now.
distanceSettings = {'FC': (FC, True), 'phFCD': (phFCD, True)}

simulateBOLD.TR = 3.  # Recording interval: 1 sample every 3 seconds
simulateBOLD.dt = 0.1 * simulateBOLD.TR / 2.
simulateBOLD.Tmax = Tmax  # This is the length, in seconds
simulateBOLD.dtt = simulateBOLD.TR  # We are not using milliseconds
simulateBOLD.t_min = 10 * simulateBOLD.TR
# simulateBOLD.recomputeTmaxneuronal() <- do not update Tmaxneuronal this way!
# simulateBOLD.warmUpFactor = 6.
simulateBOLD.Tmaxneuronal = (Tmax-1) * simulateBOLD.TR + 30
integrator.ds = simulateBOLD.TR  # record every TR millisecond

timeseries_condition_4freq = np.array([v for k,v in all_fMRI.items()])
# Hopf.beta = 0.01
f_diff = filtPowSpectr.filtPowSpetraMultipleSubjects(timeseries_condition_4freq, TR=3.)  # should be baseline_group_ts .. or baseling_group[0].reshape((1,52,193))
f_diff[np.where(f_diff == 0)] = np.mean(f_diff[np.where(f_diff != 0)])  # f_diff(find(f_diff==0))=mean(f_diff(find(f_diff~=0)))

Hopf.omega = 2 * np.pi * f_diff

print("ADHopf Setup done!")
# Out:
# SCnorm.shape=(78, 78)
# filtPowSpetraMultipleSubjects: subject 0 (of 8)
# filtPowSpetraMultipleSubjects: subject 1 (of 8)
# filtPowSpetraMultipleSubjects: subject 2 (of 8)
# filtPowSpetraMultipleSubjects: subject 3 (of 8)
# filtPowSpetraMultipleSubjects: subject 4 (of 8)
# filtPowSpetraMultipleSubjects: subject 5 (of 8)
# filtPowSpetraMultipleSubjects: subject 6 (of 8)
# filtPowSpetraMultipleSubjects: subject 7 (of 8)
# ADHopf Setup done!

# %%
import os
# Change the file to where you want to save results
outFilePath = f'/home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/10iterations_baseline_homogeneous_model_on_MCI_withoutWMH_subjectwise_new' 

if not os.path.exists(outFilePath):
    os.makedirs(outFilePath)


def fittingPipeline_homogeneous(subj_fMRI,
                    distanceSettings,  # This is a dictionary of {name: (distance module, apply filters bool)}
                    wms, wmBurden, subjectName):
    print("\n\n###################################################################")
    print("# Fitting with ParmSeep")
    print("###################################################################\n")
    # Now, optimize all we (G) values: determine optimal G to work with
    wmParms = [{'a': base_a_value}]
    fitting = ParmSeep.distanceForAll_Parms(subj_fMRI,
                                            wmWs, 
                                            wmParms,
                                            NumSimSubjects=10,
                                            distanceSettings=distanceSettings,
                                            parmLabel=f'a_fixed_',
                                            fileNameSuffix='_'+subjectName,
                                            outFilePath=outFilePath)

    optimal = {sd: distanceSettings[sd][0].findMinMax(fitting[sd]) for sd in distanceSettings}
    return optimal, fitting

    subjectName = ''
warmUp = True
warmUpFactor = 10.
Hopf.setParms({'we': 2.9})

# This is the set of weights I used for all the simulations:
# Set of weights for homogeneous model: wmWs = np.round(np.arange(-0.09,0.05,0.001), 4)
#wmWs = np.round(np.arange(-0.08,0.0501,0.001), 4)
wmWs = np.zeros(1)


def fittingPipeline_heterogeneous(all_fMRI, wmBurden, wmWs):

    best_parameters_dict = {}
    fitting_parameters_dict = {}

    for subjectName, subj_ts in all_fMRI.items():

        subj_fMRI = {subjectName:subj_ts}
        #wmBurden_subj = wmBurden_dict[subjectName]
        best_parameters, fitting_parameters = fittingPipeline_homogeneous(subj_fMRI=subj_fMRI, distanceSettings=distanceSettings, subjectName=subjectName, wms=wmWs, wmBurden = wmBurden)
        best_parameters_dict[subjectName] = best_parameters
        fitting_parameters_dict[subjectName] = fitting_parameters

    return best_parameters_dict, fitting_parameters_dict


    
best_parms_dict, fitting_parms_dict = fittingPipeline_heterogeneous(all_fMRI=all_fMRI, wmBurden=wmBurden, wmWs=wmWs)

if not random:
    # open file for writing, "w" 
    f = open(outFilePath + f"/{mode}_model_best_parameters_dictionary_{conditionToStudy}.pkl","wb")
    # write json object to file
    pickle.dump(best_parms_dict, f)
    # close file
    f.close()
    # open file for writing, "w" 
    g = open(outFilePath + f"/{mode}_model_fitting_parameters_dictionary_{conditionToStudy}.pkl","wb")
    # write json object to file
    pickle.dump(fitting_parms_dict, g)
    # close file
    g.close()

else:
    # open file for writing, "w" 
    f = open(outFilePath + f"/random_{mode}_model_best_parameters_dictionary_{conditionToStudy}.pkl","wb")
    # write json object to file
    pickle.dump(best_parms_dict, f)
    # close file
    f.close()
    # open file for writing, "w" 
    g = open(outFilePath + f"/random_{mode}_model_fitting_parameters_dictionary_{conditionToStudy}.pkl","wb")
    # write json object to file
    pickle.dump(fitting_parms_dict, g)
    # close file
    g.close()
# Out:
# ###################################################################
# # Fitting with ParmSeep
# ###################################################################
#
#
#
# *************** Starting: optim1D.distanceForAll_Parms *****************
#
#
# tc(1 subjects): each entry has N=78 regions
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/10iterations_baseline_homogeneous_model_on_MCI_withoutWMH_subjectwise_new/fNeuro_emp_ADNI003S6268.mat
#    Processing signal 1/1 Subject: ADNI003S6268 (78x193) -> computed in 3.1054128399991896 seconds
#
#
#  ====================== Model Simulations ======================
#
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/10iterations_baseline_homogeneous_model_on_MCI_withoutWMH_subjectwise_new/fitting_a_fixed_0.0_ADNI003S6268.mat
#    --- BEGIN TIME @ a_fixed_=0.0 ---
# Current a is: -0.027
# Current G is: 2.9
#    Simulating a_fixed_=0.0 -> subject 0/10!!!
#    Simulating a_fixed_=0.0 -> subject 1/10!!!
#    Simulating a_fixed_=0.0 -> subject 2/10!!!
#    Simulating a_fixed_=0.0 -> subject 3/10!!!
#    Simulating a_fixed_=0.0 -> subject 4/10!!!
#    Simulating a_fixed_=0.0 -> subject 5/10!!!
#    Simulating a_fixed_=0.0 -> subject 6/10!!!
#    Simulating a_fixed_=0.0 -> subject 7/10!!!
#    Simulating a_fixed_=0.0 -> subject 8/10!!!
#    Simulating a_fixed_=0.0 -> subject 9/10!!!
#    Processing signal 1/10 Subject: 0 (78x193) -> computed in 3.1227780929984874 seconds
#    Processing signal 2/10 Subject: 1 (78x193) -> computed in 3.0125786999997217 seconds
#    Processing signal 3/10 Subject: 2 (78x193) -> computed in 3.001913230000355 seconds
#    Processing signal 4/10 Subject: 3 (78x193) -> computed in 2.7924847270005557 seconds
#    Processing signal 5/10 Subject: 4 (78x193) -> computed in 2.7759213740027917 seconds
#    Processing signal 6/10 Subject: 5 (78x193) -> computed in 2.786600281000574 seconds
#    Processing signal 7/10 Subject: 6 (78x193) -> computed in 2.7428424600002472 seconds
#    Processing signal 8/10 Subject: 7 (78x193) -> computed in 2.854352280999592 seconds
#    Processing signal 9/10 Subject: 8 (78x193) -> computed in 2.9590923989999283 seconds
#    Processing signal 10/10 Subject: 9 (78x193) -> computed in 3.1173033459999715 seconds
#    --- TOTAL TIME: 31.02682328499941 seconds ---
# #0/1: FC: 0.29717338671833426; phFCD: 0.08526451788385692;
#
#
#
# #####################################################################################################
# # Results (in (0.0, 0.0)):
# #####################################################################################################
#
#
# DONE!!!
#
#
# ###################################################################
# # Fitting with ParmSeep
# ###################################################################
#
#
#
# *************** Starting: optim1D.distanceForAll_Parms *****************
#
#
# tc(1 subjects): each entry has N=78 regions
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/10iterations_baseline_homogeneous_model_on_MCI_withoutWMH_subjectwise_new/fNeuro_emp_ADNI006S6651.mat
#    Processing signal 1/1 Subject: ADNI006S6651 (78x193) -> computed in 3.026592060999974 seconds
#
#
#  ====================== Model Simulations ======================
#
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/10iterations_baseline_homogeneous_model_on_MCI_withoutWMH_subjectwise_new/fitting_a_fixed_0.0_ADNI006S6651.mat
#    --- BEGIN TIME @ a_fixed_=0.0 ---
# Current a is: -0.027
# Current G is: 2.9
#    Simulating a_fixed_=0.0 -> subject 0/10!!!
#    Simulating a_fixed_=0.0 -> subject 1/10!!!
#    Simulating a_fixed_=0.0 -> subject 2/10!!!
#    Simulating a_fixed_=0.0 -> subject 3/10!!!
#    Simulating a_fixed_=0.0 -> subject 4/10!!!
#    Simulating a_fixed_=0.0 -> subject 5/10!!!
#    Simulating a_fixed_=0.0 -> subject 6/10!!!
#    Simulating a_fixed_=0.0 -> subject 7/10!!!
#    Simulating a_fixed_=0.0 -> subject 8/10!!!
#    Simulating a_fixed_=0.0 -> subject 9/10!!!
#    Processing signal 1/10 Subject: 0 (78x193) -> computed in 2.868419200000062 seconds
#    Processing signal 2/10 Subject: 1 (78x193) -> computed in 2.8521914969969657 seconds
#    Processing signal 3/10 Subject: 2 (78x193) -> computed in 3.459516528997483 seconds
#    Processing signal 4/10 Subject: 3 (78x193) -> computed in 3.3119691270003386 seconds
#    Processing signal 5/10 Subject: 4 (78x193) -> computed in 3.159280588999536 seconds
#    Processing signal 6/10 Subject: 5 (78x193) -> computed in 2.8846409369980393 seconds
#    Processing signal 7/10 Subject: 6 (78x193) -> computed in 2.8926586369998404 seconds
#    Processing signal 8/10 Subject: 7 (78x193) -> computed in 2.905271695999545 seconds
#    Processing signal 9/10 Subject: 8 (78x193) -> computed in 2.9006368959999236 seconds
#    Processing signal 10/10 Subject: 9 (78x193) -> computed in 2.877630192997458 seconds
#    --- TOTAL TIME: 32.06721254700096 seconds ---
# #0/1: FC: 0.26344149538567196; phFCD: 0.19453284373725016;
#
#
#
# #####################################################################################################
# # Results (in (0.0, 0.0)):
# #####################################################################################################
#
#
# DONE!!!
#
#
# ###################################################################
# # Fitting with ParmSeep
# ###################################################################
#
#
#
# *************** Starting: optim1D.distanceForAll_Parms *****************
#
#
# tc(1 subjects): each entry has N=78 regions
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/10iterations_baseline_homogeneous_model_on_MCI_withoutWMH_subjectwise_new/fNeuro_emp_ADNI018S6414.mat
#    Processing signal 1/1 Subject: ADNI018S6414 (78x193) -> computed in 2.9704762770015805 seconds
#
#
#  ====================== Model Simulations ======================
#
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/10iterations_baseline_homogeneous_model_on_MCI_withoutWMH_subjectwise_new/fitting_a_fixed_0.0_ADNI018S6414.mat
#    --- BEGIN TIME @ a_fixed_=0.0 ---
# Current a is: -0.027
# Current G is: 2.9
#    Simulating a_fixed_=0.0 -> subject 0/10!!!
#    Simulating a_fixed_=0.0 -> subject 1/10!!!
#    Simulating a_fixed_=0.0 -> subject 2/10!!!
#    Simulating a_fixed_=0.0 -> subject 3/10!!!
#    Simulating a_fixed_=0.0 -> subject 4/10!!!
#    Simulating a_fixed_=0.0 -> subject 5/10!!!
#    Simulating a_fixed_=0.0 -> subject 6/10!!!
#    Simulating a_fixed_=0.0 -> subject 7/10!!!
#    Simulating a_fixed_=0.0 -> subject 8/10!!!
#    Simulating a_fixed_=0.0 -> subject 9/10!!!
#    Processing signal 1/10 Subject: 0 (78x193) -> computed in 2.9256640340026934 seconds
#    Processing signal 2/10 Subject: 1 (78x193) -> computed in 2.889114038000116 seconds
#    Processing signal 3/10 Subject: 2 (78x193) -> computed in 2.866718335000769 seconds
#    Processing signal 4/10 Subject: 3 (78x193) -> computed in 2.826114712999697 seconds
#    Processing signal 5/10 Subject: 4 (78x193) -> computed in 2.8507808710019162 seconds
#    Processing signal 6/10 Subject: 5 (78x193) -> computed in 2.9664292490015214 seconds
#    Processing signal 7/10 Subject: 6 (78x193) -> computed in 2.8582151320006233 seconds
#    Processing signal 8/10 Subject: 7 (78x193) -> computed in 2.897963036000874 seconds
#    Processing signal 9/10 Subject: 8 (78x193) -> computed in 2.9064873370007263 seconds
#    Processing signal 10/10 Subject: 9 (78x193) -> computed in 2.927802536996751 seconds
#    --- TOTAL TIME: 30.85799356699863 seconds ---
# #0/1: FC: 0.15079811600476592; phFCD: 0.11853665170678634;
#
#
#
# #####################################################################################################
# # Results (in (0.0, 0.0)):
# #####################################################################################################
#
#
# DONE!!!
#
#
# ###################################################################
# # Fitting with ParmSeep
# ###################################################################
#
#
#
# *************** Starting: optim1D.distanceForAll_Parms *****************
#
#
# tc(1 subjects): each entry has N=78 regions
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/10iterations_baseline_homogeneous_model_on_MCI_withoutWMH_subjectwise_new/fNeuro_emp_ADNI024S6033.mat
#    Processing signal 1/1 Subject: ADNI024S6033 (78x193) -> computed in 2.8746298320002097 seconds
#
#
#  ====================== Model Simulations ======================
#
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/10iterations_baseline_homogeneous_model_on_MCI_withoutWMH_subjectwise_new/fitting_a_fixed_0.0_ADNI024S6033.mat
#    --- BEGIN TIME @ a_fixed_=0.0 ---
# Current a is: -0.027
# Current G is: 2.9
#    Simulating a_fixed_=0.0 -> subject 0/10!!!
#    Simulating a_fixed_=0.0 -> subject 1/10!!!
#    Simulating a_fixed_=0.0 -> subject 2/10!!!
#    Simulating a_fixed_=0.0 -> subject 3/10!!!
#    Simulating a_fixed_=0.0 -> subject 4/10!!!
#    Simulating a_fixed_=0.0 -> subject 5/10!!!
#    Simulating a_fixed_=0.0 -> subject 6/10!!!
#    Simulating a_fixed_=0.0 -> subject 7/10!!!
#    Simulating a_fixed_=0.0 -> subject 8/10!!!
#    Simulating a_fixed_=0.0 -> subject 9/10!!!
#    Processing signal 1/10 Subject: 0 (78x193) -> computed in 2.9082992110015766 seconds
#    Processing signal 2/10 Subject: 1 (78x193) -> computed in 2.853831409000122 seconds
#    Processing signal 3/10 Subject: 2 (78x193) -> computed in 2.888443408999592 seconds
#    Processing signal 4/10 Subject: 3 (78x193) -> computed in 2.920695845998125 seconds
#    Processing signal 5/10 Subject: 4 (78x193) -> computed in 2.952814552001655 seconds
#    Processing signal 6/10 Subject: 5 (78x193) -> computed in 2.8913542670015886 seconds
#    Processing signal 7/10 Subject: 6 (78x193) -> computed in 2.8499352609978814 seconds
#    Processing signal 8/10 Subject: 7 (78x193) -> computed in 3.125849598000059 seconds
#    Processing signal 9/10 Subject: 8 (78x193) -> computed in 2.953000678000535 seconds
#    Processing signal 10/10 Subject: 9 (78x193) -> computed in 2.8626737669983413 seconds
#    --- TOTAL TIME: 31.179880078001588 seconds ---
# #0/1: FC: 0.20798032327849342; phFCD: 0.26533387732898134;
#
#
#
# #####################################################################################################
# # Results (in (0.0, 0.0)):
# #####################################################################################################
#
#
# DONE!!!
#
#
# ###################################################################
# # Fitting with ParmSeep
# ###################################################################
#
#
#
# *************** Starting: optim1D.distanceForAll_Parms *****************
#
#
# tc(1 subjects): each entry has N=78 regions
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/10iterations_baseline_homogeneous_model_on_MCI_withoutWMH_subjectwise_new/fNeuro_emp_ADNI037S4706.mat
#    Processing signal 1/1 Subject: ADNI037S4706 (78x193) -> computed in 2.8468690589979815 seconds
#
#
#  ====================== Model Simulations ======================
#
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/10iterations_baseline_homogeneous_model_on_MCI_withoutWMH_subjectwise_new/fitting_a_fixed_0.0_ADNI037S4706.mat
#    --- BEGIN TIME @ a_fixed_=0.0 ---
# Current a is: -0.027
# Current G is: 2.9
#    Simulating a_fixed_=0.0 -> subject 0/10!!!
#    Simulating a_fixed_=0.0 -> subject 1/10!!!
#    Simulating a_fixed_=0.0 -> subject 2/10!!!
#    Simulating a_fixed_=0.0 -> subject 3/10!!!
#    Simulating a_fixed_=0.0 -> subject 4/10!!!
#    Simulating a_fixed_=0.0 -> subject 5/10!!!
#    Simulating a_fixed_=0.0 -> subject 6/10!!!
#    Simulating a_fixed_=0.0 -> subject 7/10!!!
#    Simulating a_fixed_=0.0 -> subject 8/10!!!
#    Simulating a_fixed_=0.0 -> subject 9/10!!!
#    Processing signal 1/10 Subject: 0 (78x193) -> computed in 2.7142896380028105 seconds
#    Processing signal 2/10 Subject: 1 (78x193) -> computed in 2.7484783270010666 seconds
#    Processing signal 3/10 Subject: 2 (78x193) -> computed in 2.7412026260026323 seconds
#    Processing signal 4/10 Subject: 3 (78x193) -> computed in 2.6397716969986504 seconds
#    Processing signal 5/10 Subject: 4 (78x193) -> computed in 2.690665819998685 seconds
#    Processing signal 6/10 Subject: 5 (78x193) -> computed in 2.7525204250014212 seconds
#    Processing signal 7/10 Subject: 6 (78x193) -> computed in 3.1050739500024065 seconds
#    Processing signal 8/10 Subject: 7 (78x193) -> computed in 2.984413730999222 seconds
#    Processing signal 9/10 Subject: 8 (78x193) -> computed in 3.0017900329985423 seconds
#    Processing signal 10/10 Subject: 9 (78x193) -> computed in 3.4750542210022104 seconds
#    --- TOTAL TIME: 30.76033410599848 seconds ---
# #0/1: FC: 0.23050352928822404; phFCD: 0.150047599619203;
#
#
#
# #####################################################################################################
# # Results (in (0.0, 0.0)):
# #####################################################################################################
#
#
# DONE!!!
#
#
# ###################################################################
# # Fitting with ParmSeep
# ###################################################################
#
#
#
# *************** Starting: optim1D.distanceForAll_Parms *****************
#
#
# tc(1 subjects): each entry has N=78 regions
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/10iterations_baseline_homogeneous_model_on_MCI_withoutWMH_subjectwise_new/fNeuro_emp_ADNI068S2187.mat
#    Processing signal 1/1 Subject: ADNI068S2187 (78x193) -> computed in 3.1427234939983464 seconds
#
#
#  ====================== Model Simulations ======================
#
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/10iterations_baseline_homogeneous_model_on_MCI_withoutWMH_subjectwise_new/fitting_a_fixed_0.0_ADNI068S2187.mat
#    --- BEGIN TIME @ a_fixed_=0.0 ---
# Current a is: -0.027
# Current G is: 2.9
#    Simulating a_fixed_=0.0 -> subject 0/10!!!
#    Simulating a_fixed_=0.0 -> subject 1/10!!!
#    Simulating a_fixed_=0.0 -> subject 2/10!!!
#    Simulating a_fixed_=0.0 -> subject 3/10!!!
#    Simulating a_fixed_=0.0 -> subject 4/10!!!
#    Simulating a_fixed_=0.0 -> subject 5/10!!!
#    Simulating a_fixed_=0.0 -> subject 6/10!!!
#    Simulating a_fixed_=0.0 -> subject 7/10!!!
#    Simulating a_fixed_=0.0 -> subject 8/10!!!
#    Simulating a_fixed_=0.0 -> subject 9/10!!!
#    Processing signal 1/10 Subject: 0 (78x193) -> computed in 2.7952610939973965 seconds
#    Processing signal 2/10 Subject: 1 (78x193) -> computed in 2.9563619879991165 seconds
#    Processing signal 3/10 Subject: 2 (78x193) -> computed in 3.0310817470017355 seconds
#    Processing signal 4/10 Subject: 3 (78x193) -> computed in 3.037737342001492 seconds
#    Processing signal 5/10 Subject: 4 (78x193) -> computed in 2.9322317080004723 seconds
#    Processing signal 6/10 Subject: 5 (78x193) -> computed in 2.898035966001771 seconds
#    Processing signal 7/10 Subject: 6 (78x193) -> computed in 2.9513365599996177 seconds
#    Processing signal 8/10 Subject: 7 (78x193) -> computed in 2.8700924269978714 seconds
#    Processing signal 9/10 Subject: 8 (78x193) -> computed in 2.7734204920016055 seconds
#    Processing signal 10/10 Subject: 9 (78x193) -> computed in 2.764977392998844 seconds
#    --- TOTAL TIME: 30.831287548000546 seconds ---
# #0/1: FC: 0.21733078830712188; phFCD: 0.16619747042023664;
#
#
#
# #####################################################################################################
# # Results (in (0.0, 0.0)):
# #####################################################################################################
#
#
# DONE!!!
#
#
# ###################################################################
# # Fitting with ParmSeep
# ###################################################################
#
#
#
# *************** Starting: optim1D.distanceForAll_Parms *****************
#
#
# tc(1 subjects): each entry has N=78 regions
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/10iterations_baseline_homogeneous_model_on_MCI_withoutWMH_subjectwise_new/fNeuro_emp_ADNI068S4431.mat
#    Processing signal 1/1 Subject: ADNI068S4431 (78x193) -> computed in 2.747281498999655 seconds
#
#
#  ====================== Model Simulations ======================
#
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/10iterations_baseline_homogeneous_model_on_MCI_withoutWMH_subjectwise_new/fitting_a_fixed_0.0_ADNI068S4431.mat
#    --- BEGIN TIME @ a_fixed_=0.0 ---
# Current a is: -0.027
# Current G is: 2.9
#    Simulating a_fixed_=0.0 -> subject 0/10!!!
#    Simulating a_fixed_=0.0 -> subject 1/10!!!
#    Simulating a_fixed_=0.0 -> subject 2/10!!!
#    Simulating a_fixed_=0.0 -> subject 3/10!!!
#    Simulating a_fixed_=0.0 -> subject 4/10!!!
#    Simulating a_fixed_=0.0 -> subject 5/10!!!
#    Simulating a_fixed_=0.0 -> subject 6/10!!!
#    Simulating a_fixed_=0.0 -> subject 7/10!!!
#    Simulating a_fixed_=0.0 -> subject 8/10!!!
#    Simulating a_fixed_=0.0 -> subject 9/10!!!
#    Processing signal 1/10 Subject: 0 (78x193) -> computed in 3.199185970999679 seconds
#    Processing signal 2/10 Subject: 1 (78x193) -> computed in 2.96162168400042 seconds
#    Processing signal 3/10 Subject: 2 (78x193) -> computed in 2.985976183001185 seconds
#    Processing signal 4/10 Subject: 3 (78x193) -> computed in 2.9394843199988827 seconds
#    Processing signal 5/10 Subject: 4 (78x193) -> computed in 2.961370312001236 seconds
#    Processing signal 6/10 Subject: 5 (78x193) -> computed in 2.9023992360016564 seconds
#    Processing signal 7/10 Subject: 6 (78x193) -> computed in 2.922202431000187 seconds
#    Processing signal 8/10 Subject: 7 (78x193) -> computed in 2.9274836059994414 seconds
#    Processing signal 9/10 Subject: 8 (78x193) -> computed in 2.971047863000422 seconds
#    Processing signal 10/10 Subject: 9 (78x193) -> computed in 2.948897821999708 seconds
#    --- TOTAL TIME: 31.810862951999297 seconds ---
# #0/1: FC: 0.34731408321997664; phFCD: 0.11807425540595673;
#
#
#
# #####################################################################################################
# # Results (in (0.0, 0.0)):
# #####################################################################################################
#
#
# DONE!!!
#
#
# ###################################################################
# # Fitting with ParmSeep
# ###################################################################
#
#
#
# *************** Starting: optim1D.distanceForAll_Parms *****************
#
#
# tc(1 subjects): each entry has N=78 regions
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/10iterations_baseline_homogeneous_model_on_MCI_withoutWMH_subjectwise_new/fNeuro_emp_ADNI070S6236.mat
#    Processing signal 1/1 Subject: ADNI070S6236 (78x193) -> computed in 2.9460316210024757 seconds
#
#
#  ====================== Model Simulations ======================
#
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/10iterations_baseline_homogeneous_model_on_MCI_withoutWMH_subjectwise_new/fitting_a_fixed_0.0_ADNI070S6236.mat
#    --- BEGIN TIME @ a_fixed_=0.0 ---
# Current a is: -0.027
# Current G is: 2.9
#    Simulating a_fixed_=0.0 -> subject 0/10!!!
#    Simulating a_fixed_=0.0 -> subject 1/10!!!
#    Simulating a_fixed_=0.0 -> subject 2/10!!!
#    Simulating a_fixed_=0.0 -> subject 3/10!!!
#    Simulating a_fixed_=0.0 -> subject 4/10!!!
#    Simulating a_fixed_=0.0 -> subject 5/10!!!
#    Simulating a_fixed_=0.0 -> subject 6/10!!!
#    Simulating a_fixed_=0.0 -> subject 7/10!!!
#    Simulating a_fixed_=0.0 -> subject 8/10!!!
#    Simulating a_fixed_=0.0 -> subject 9/10!!!
#    Processing signal 1/10 Subject: 0 (78x193) -> computed in 2.9779189360015152 seconds
#    Processing signal 2/10 Subject: 1 (78x193) -> computed in 2.917081829997187 seconds
#    Processing signal 3/10 Subject: 2 (78x193) -> computed in 2.982685807000962 seconds
#    Processing signal 4/10 Subject: 3 (78x193) -> computed in 2.9446007080005074 seconds
#    Processing signal 5/10 Subject: 4 (78x193) -> computed in 2.956336671999452 seconds
#    Processing signal 6/10 Subject: 5 (78x193) -> computed in 2.9199342369975056 seconds
#    Processing signal 7/10 Subject: 6 (78x193) -> computed in 2.935995235999144 seconds
#    Processing signal 8/10 Subject: 7 (78x193) -> computed in 2.9267146739985037 seconds
#    Processing signal 9/10 Subject: 8 (78x193) -> computed in 2.985732051998639 seconds
#    Processing signal 10/10 Subject: 9 (78x193) -> computed in 2.998485743999481 seconds
#    --- TOTAL TIME: 31.516205819996685 seconds ---
# #0/1: FC: 0.2327136466137279; phFCD: 0.0853937168502652;
#
#
#
# #####################################################################################################
# # Results (in (0.0, 0.0)):
# #####################################################################################################
#
#
# DONE!!!
