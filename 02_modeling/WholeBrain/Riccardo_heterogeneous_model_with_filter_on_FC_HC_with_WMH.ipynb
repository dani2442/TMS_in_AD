# %%
# Load all the packages needed for analyses
import sys
import numpy as np
import scipy.io as sio
from numba import jit
import matplotlib.pyplot as plt

# Set up Hopf as our model 
import WholeBrain.Models.supHopf as Hopf
from WholeBrain.simulate_SimOnly import Tmaxneuronal
Hopf.initialValue = 0.1
neuronalModel = Hopf

# Set up our integrator
import WholeBrain.Integrator_EulerMaruyama as myIntegrator
integrator = myIntegrator
integrator.neuronalModel = neuronalModel
integrator.verbose = False
integrator.clamping = False

# Set up the integration parameters
dt = 5e-5
# tmax is equal to the number of timepoints: 193
tmax= 193
ds = 1e-4
Tmaxneuronal = int((tmax+dt))

import WholeBrain.simulate_SimOnly as simulateBOLD
simulateBOLD.warmUp = True
simulateBOLD.integrator = integrator
simulateBOLD.warmUpFactor = 606./2000.

# Set up the code to obtain the variables we want to maximize similarity to empirical FC
import WholeBrain.Observables.FC as FC
#import WholeBrain.Observables.swFCD as swFCD
import WholeBrain.Observables.phFCD as phFCD
import WholeBrain.Optimizers.ParmSeep as ParmSeep
ParmSeep.simulateBOLD = simulateBOLD
ParmSeep.integrator = integrator
ParmSeep.verbose = True

# set BOLD filter settings
import WholeBrain.Utils.filteredPowerSpectralDensity as filtPowSpectr
import WholeBrain.BOLDFilters as BOLDfilters

# These filters are applied in the filtPowSpectr function that we use to extract the intrinsic frequencies of each region.
# They are also applied to process the FC and swFCD and phFCD, but you can set the corresponding parameter to False later on. 0.04-0.07 Hz common to extract intrinsic frequencies
BOLDfilters.flp = 0.04
BOLDfilters.fhi = 0.07
BOLDfilters.TR = 3.0
# Out:
# Going to use the supercritical Hopf bifurcation neuronal model...
# Going to use the Euler-Maruyama Integrator...
# Going to use Functional Connectivity (FC)...
# Going to use Phase-Interaction Matrix...
# Going to use Phase Functional Connectivity Dynamics (phFCD)...

# %%
# Get the list of names of all regions in the AAL atlas. This is needed to get the right indices, to then filter the FC
import csv
# This is a sublist of labels of the cortical regions that were included in the paper by Demirtas et al. - AAL atlas (78 regions, excluding infratentorial and deep)
with open ('/home/riccardo/ADNI_Hopf/Utils/aal_regions_included.csv', newline='') as f:
    new_reader = csv.reader(f)
    included_regions = list(new_reader)
f.close()

# Get the AAL atlas labels
import nilearn.datasets as datasets
aal = datasets.fetch_atlas_aal()
labels = np.array(aal.labels)
# create an array with the indices of each label (note that these are not the label number from the nifti image)
indices = np.array([i for i in enumerate(labels)])
SC_regions_index = np.isin(labels, included_regions)
# filter the indices that we want based on the position so to have a final SC matrix only for the regions we considered.
SC_78_regions_aal_atlas = indices[SC_regions_index]
filter_SC = np.array([int(i) for i in SC_78_regions_aal_atlas[:,0]])

# Set file path for SC matrix
x_path = '/home/riccardo/ADNI_Hopf/Utils/'
# Load structural connectivity matrix and use it as parameter in Hopf model
xfile = 'SCmatrices88healthy.mat' 
M = sio.loadmat(x_path + xfile); 
mat = M['SCmatrices']
# averaging the SC among subjects
mat0 = np.mean(mat,axis = 0)
# Filter the SC to have just the 78 regions we considered
x_mat0 = mat0[filter_SC]
new_mat0 = x_mat0.T[filter_SC]
# Prevent full synchronization of the model
SCnorm = new_mat0 * 0.2 / new_mat0.max() 
np.fill_diagonal(SCnorm,0)
print('SCnorm.shape={}'.format(new_mat0.shape))    
Hopf.setParms({'SC':SCnorm})

# ------------------------------------------------
# Retrieve the data for all subjects 
# ------------------------------------------------
timeseries = np.load('/home/riccardo/ADNI_Hopf/Results/timeseries_HC.npy')
nsubjects, nNodes, Tmax = timeseries.shape
all_fMRI = {s: d for s,d in enumerate(timeseries)} 
# Since we aleardy filtered the data in the previous step from Nilearn, we aren't going to filter them again. Otherwise, a possible alternative, could be to add another
# BOLDfilters to actually re-set the filters after the f_diff was extracted and before the call to the simulation.
distanceSettings = {'FC': (FC, True), 'phFCD': (phFCD, True)}

simulateBOLD.TR = 3.  # Recording interval: 1 sample every 3 seconds
simulateBOLD.dt = 0.1 * simulateBOLD.TR / 2.
simulateBOLD.Tmax = Tmax  # This is the length, in seconds
simulateBOLD.dtt = simulateBOLD.TR  # We are not using milliseconds
simulateBOLD.t_min = 10 * simulateBOLD.TR
# simulateBOLD.recomputeTmaxneuronal() <- do not update Tmaxneuronal this way!
# simulateBOLD.warmUpFactor = 6.
simulateBOLD.Tmaxneuronal = (Tmax-1) * simulateBOLD.TR + 30
integrator.ds = simulateBOLD.TR  # record every TR millisecond

# Hopf.beta = 0.01
f_diff = filtPowSpectr.filtPowSpetraMultipleSubjects(timeseries, TR=3.)  # should be baseline_group_ts .. or baseling_group[0].reshape((1,52,193))
f_diff[np.where(f_diff == 0)] = np.mean(f_diff[np.where(f_diff != 0)])  # f_diff(find(f_diff==0))=mean(f_diff(find(f_diff~=0)))

Hopf.omega = 2 * np.pi * f_diff

print("ADHopf Setup done!")
# Out:
# SCnorm.shape=(78, 78)
# filtPowSpetraMultipleSubjects: subject 0 (of 9)
# filtPowSpetraMultipleSubjects: subject 1 (of 9)
# filtPowSpetraMultipleSubjects: subject 2 (of 9)
# filtPowSpetraMultipleSubjects: subject 3 (of 9)
# filtPowSpetraMultipleSubjects: subject 4 (of 9)
# filtPowSpetraMultipleSubjects: subject 5 (of 9)
# filtPowSpetraMultipleSubjects: subject 6 (of 9)
# filtPowSpetraMultipleSubjects: subject 7 (of 9)
# filtPowSpetraMultipleSubjects: subject 8 (of 9)
# ADHopf Setup done!

# %%
base_a_value = -0.02
warmUp = True
warmUpFactor = 10.

def computeSubjectSimulation():
    # integrator.neuronalModel.SC = C
    # integrator.initBookkeeping(N, Tmaxneuronal)
    if warmUp:
        currObsVars = integrator.warmUpAndSimulate(dt, Tmaxneuronal, TWarmUp=Tmaxneuronal/warmUpFactor)
    else:
        currObsVars = integrator.simulate(dt, Tmaxneuronal)
    # currObsVars = integrator.returnBookkeeping()  # curr_xn, curr_rn
    neuro_act = currObsVars[:,1,:]  # curr_rn
    return neuro_act
    

def loadXBurden(condition):
    # ------------------- load and stack the different wm burdens
    wm_hc = np.load('/home/riccardo/ADNI_Hopf/Results/wmh_volumes_HC.npy')
    wm_mci = np.load('/home/riccardo/ADNI_Hopf/Results/wmh_volumes_MCI.npy')
    wm_overall = np.load('/home/riccardo/ADNI_Hopf/Results/wmh_volumes_ALL.npy')
    # ------------------- load the specific subject wm
    if condition == 'hc':
        wmBurden = wm_hc
    elif condition == 'mci':
        wmBurden = wm_mci
    elif condition == 'all':
        wmBurden = wm_overall
    # ------------------- normalize and return
    # wmBurdenNorm = (wmBurden - np.min(wmBurden))/np.ptp(wmBurden)  # Normalize each individual in [0,1]
    wmBurdenNorm = (wmBurden - np.min(wm_overall))/np.ptp(wm_overall)  # Normalize the whole group in [0,1]
    return wmBurdenNorm

# ------------ load wm burden
conditionToStudy='hc' #lower case, can be hc or mci or all
wmBurden = loadXBurden(conditionToStudy)
mode = 'homogeneous'  # homogeneous/heterogeneous/random

# Note that this homogeneous is intended as homogeneous inside the same patient, so all regions of one patient have the same wmBurden, but different patients have different wmBurdens.
# Heterogenous, instead, means that different regions in the same patient have different wmBurdens
if mode == 'homogeneous':
    #avgwm = np.average(wmBurden)
    wmBurden = np.array([np.ones([nNodes]) * wmBurden[i] for i in range(len(wmBurden))])
elif mode == 'random':
    np.random.shuffle(wmBurden)

# %%
outFilePath = '/home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight'

def fittingPipeline_homogeneous(subj_fMRI,
                    distanceSettings,  # This is a dictionary of {name: (distance module, apply filters bool)}
                    wms, wmBurden, subjectName):
    print("\n\n###################################################################")
    print("# Fitting with ParmSeep")
    print("###################################################################\n")
    # Now, optimize all we (G) values: determine optimal G to work with
    wmParms = [{'a': base_a_value + (wmW * wmBurden)} for wmW in wmWs]
    fitting = ParmSeep.distanceForAll_Parms(subj_fMRI,
                                            wmWs, 
                                            wmParms,
                                            NumSimSubjects=1,
                                            distanceSettings=distanceSettings,
                                            parmLabel='a_heterogeneous_between_subjects_current_wmW_',
                                            fileNameSuffix='_'+subjectName,
                                            outFilePath=outFilePath)

    optimal = {sd: distanceSettings[sd][0].findMinMax(fitting[sd]) for sd in distanceSettings}
    return optimal, fitting

# %%
subj_list = np.load('/home/riccardo/ADNI_Hopf/Results/subject_list_timeseries_HC.npy')

subjectName = ''
warmUp = True
warmUpFactor = 10.
Hopf.setParms({'we': 2.9})
wmWs = np.round(np.arange(-0.1,0.1,0.005), 4)


def fittingPipeline_heterogeneous(all_fMRI, wmBurden, wmWs):
    best_parameters_dict = {}
    fitting_parameters_dict = {}

    for k, subjectName in enumerate(subj_list):
        subj_fMRI = {k:all_fMRI[k]}
        wmBurden_subj = wmBurden[k]
        best_parameters, fitting_parameters = fittingPipeline_homogeneous(subj_fMRI=subj_fMRI, distanceSettings=distanceSettings, subjectName=subjectName, wms=wmWs, wmBurden = wmBurden_subj)
        best_parameters_dict[subjectName] = best_parameters
        fitting_parameters_dict[subjectName] = fitting_parameters

    return best_parameters_dict, fitting_parameters_dict

# %% [markdown]
# Due to the memory load the simulations cannot be run all in the same batch, at least not in Jupyter for VSCode where I am working at the moment on my personal laptop. Luckily the code can be run in batches, this means that we can subdivide the whole simulation into 3 separate batches and run it 3 times. Each time you have to close down the notebook and reopen it. After the simulation is run and the files are saved for all patients we can just re-run the functions altogether and this will just load the already computed simulations. Also this crashes VSCode ( [it is a known bug](https://github.com/microsoft/vscode/issues/155242)), but we are still able to run the code, just we won't see any output on the screen, but we can save a combined dictionary as a pickle file.

# %%
best_parms_dict, fitting_parms_dict = fittingPipeline_heterogeneous(all_fMRI=all_fMRI, wmBurden=wmBurden, wmWs=wmWs)
# Out:
# ###################################################################
# # Fitting with ParmSeep
# ###################################################################
#
#
#
# *************** Starting: optim1D.distanceForAll_Parms *****************
#
#
# tc(1 subjects): each entry has N=78 regions
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fNeuro_emp_ADNI002S4799.mat !!!
#
#
#  ====================== Model Simulations ======================
#
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.1_ADNI002S4799.mat !!!
# #0/1: FC: 0.15908588981078664; phFCD: 0.05548755609955125;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.095_ADNI002S4799.mat !!!
# #1/1: FC: 0.11810693270168024; phFCD: 0.07282741738066095;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.09_ADNI002S4799.mat !!!
# #2/1: FC: 0.17996193139756186; phFCD: 0.3304093567251462;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.085_ADNI002S4799.mat !!!
# #3/1: FC: 0.0706094107989241; phFCD: 0.3002855977152183;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.08_ADNI002S4799.mat !!!
# #4/1: FC: 0.15624657114188423; phFCD: 0.2745818033455732;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.075_ADNI002S4799.mat !!!
# #5/1: FC: 0.10199555126861547; phFCD: 0.23092615259077925;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.07_ADNI002S4799.mat !!!
# #6/1: FC: 0.1739302389558927; phFCD: 0.28199374405004757;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.065_ADNI002S4799.mat !!!
# #7/1: FC: 0.1399319876815907; phFCD: 0.37270501835985315;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.06_ADNI002S4799.mat !!!
# #8/1: FC: 0.2682585939831889; phFCD: 0.09961920304637573;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.055_ADNI002S4799.mat !!!
# #9/1: FC: 0.08510055666465852; phFCD: 0.269141846865225;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.05_ADNI002S4799.mat !!!
# #10/1: FC: 0.2749422696210103; phFCD: 0.25690194478444167;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.045_ADNI002S4799.mat !!!
# #11/1: FC: 0.15889566236579483; phFCD: 0.3342173262613899;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.04_ADNI002S4799.mat !!!
# #12/1: FC: 0.260274875775397; phFCD: 0.4001767985856113;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.035_ADNI002S4799.mat !!!
# #13/1: FC: 0.1502934485786294; phFCD: 0.20529035767713857;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.03_ADNI002S4799.mat !!!
# #14/1: FC: 0.06819905123909396; phFCD: 0.27274581803345577;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.025_ADNI002S4799.mat !!!
# #15/1: FC: 0.16463874393980787; phFCD: 0.2508499932000544;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.02_ADNI002S4799.mat !!!
# #16/1: FC: 0.16521937101933024; phFCD: 0.26846185230518155;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.015_ADNI002S4799.mat !!!
# #17/1: FC: 0.18030869539071084; phFCD: 0.22181422548619611;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.01_ADNI002S4799.mat !!!
# #18/1: FC: 0.07504911697074995; phFCD: 0.15612675098599216;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.005_ADNI002S4799.mat !!!
# #19/1: FC: 0.2077571728717913; phFCD: 0.10907112743098057;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.0_ADNI002S4799.mat !!!
# #20/1: FC: 0.21758318222754794; phFCD: 0.19237046103631172;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.005_ADNI002S4799.mat !!!
# #21/1: FC: 0.19231949133468343; phFCD: 0.15605875152998777;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.01_ADNI002S4799.mat !!!
# #22/1: FC: 0.2867435679037658; phFCD: 0.13429892560859513;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.015_ADNI002S4799.mat !!!
# #23/1: FC: 0.21192601424388852; phFCD: 0.40697674418604646;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.02_ADNI002S4799.mat !!!
# #24/1: FC: 0.23420046736470526; phFCD: 0.28124575003399976;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.025_ADNI002S4799.mat !!!
# #25/1: FC: 0.09481966779604847; phFCD: 0.395076839385285;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.03_ADNI002S4799.mat !!!
# #26/1: FC: 0.22375024954757095; phFCD: 0.11627906976744187;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.035_ADNI002S4799.mat !!!
# #27/1: FC: 0.18263591512442215; phFCD: 0.4065007479940161;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.04_ADNI002S4799.mat !!!
# #28/1: FC: 0.1393047967444125; phFCD: 0.3283013735890113;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.045_ADNI002S4799.mat !!!
# #29/1: FC: 0.04000308932296737; phFCD: 0.34115327077383384;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.05_ADNI002S4799.mat !!!
# #30/1: FC: 0.17332188338216697; phFCD: 0.11131510947912418;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.055_ADNI002S4799.mat !!!
# #31/1: FC: 0.17677491913958968; phFCD: 0.2145382836937304;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.06_ADNI002S4799.mat !!!
# #32/1: FC: 0.10047241573858944; phFCD: 0.2534339725282198;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.065_ADNI002S4799.mat !!!
# #33/1: FC: 0.23229243102765362; phFCD: 0.18801849585203317;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.07_ADNI002S4799.mat !!!
# #34/1: FC: 0.17341905342675748; phFCD: 0.250373997008024;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.075_ADNI002S4799.mat !!!
# #35/1: FC: 0.16875182798546226; phFCD: 0.28872569019447847;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.08_ADNI002S4799.mat !!!
# #36/1: FC: 0.1104799462208136; phFCD: 0.4584523323813409;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.085_ADNI002S4799.mat !!!
# #37/1: FC: 0.1386808518196746; phFCD: 0.13123895008839925;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.09_ADNI002S4799.mat !!!
# #38/1: FC: 0.13842283481014764; phFCD: 0.08384332925336602;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.095_ADNI002S4799.mat !!!
# #39/1: FC: 0.08200072449927648; phFCD: 0.3314293485652115;
#
#
#
# #####################################################################################################
# # Results (in (-0.1, 0.095)):
# #####################################################################################################
#
#
# DONE!!!
#
#
# ###################################################################
# # Fitting with ParmSeep
# ###################################################################
#
#
#
# *************** Starting: optim1D.distanceForAll_Parms *****************
#
#
# tc(1 subjects): each entry has N=78 regions
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fNeuro_emp_ADNI002S5178.mat !!!
#
#
#  ====================== Model Simulations ======================
#
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.1_ADNI002S5178.mat !!!
# #0/1: FC: 0.23065086987088432; phFCD: 0.18903848769209852;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.095_ADNI002S5178.mat !!!
# #1/1: FC: 0.2051116098919437; phFCD: 0.4011287909696723;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.09_ADNI002S5178.mat !!!
# #2/1: FC: 0.28849939206208497; phFCD: 0.10934312525499801;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.085_ADNI002S5178.mat !!!
# #3/1: FC: 0.20820802437945454; phFCD: 0.24704202366381073;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.08_ADNI002S5178.mat !!!
# #4/1: FC: 0.28368607606045143; phFCD: 0.23595811233510133;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.075_ADNI002S5178.mat !!!
# #5/1: FC: 0.2638151404069326; phFCD: 0.15163878688970484;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.07_ADNI002S5178.mat !!!
# #6/1: FC: 0.1638343037785407; phFCD: 0.12267101863185093;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.065_ADNI002S5178.mat !!!
# #7/1: FC: 0.2389648749040665; phFCD: 0.1147150822793418;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.06_ADNI002S5178.mat !!!
# #8/1: FC: 0.26767183981726905; phFCD: 0.03515571875424997;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.055_ADNI002S5178.mat !!!
# #9/1: FC: 0.28620033804204764; phFCD: 0.10968312253501972;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.05_ADNI002S5178.mat !!!
# #10/1: FC: 0.3035394399535111; phFCD: 0.17890656874745003;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.045_ADNI002S5178.mat !!!
# #11/1: FC: 0.2542486644893876; phFCD: 0.22378620971032231;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.04_ADNI002S5178.mat !!!
# #12/1: FC: 0.23661516701861735; phFCD: 0.21073031415748678;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.035_ADNI002S5178.mat !!!
# #13/1: FC: 0.2116721238797124; phFCD: 0.1758465932272542;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.03_ADNI002S5178.mat !!!
# #14/1: FC: 0.21942800052890993; phFCD: 0.05888752889976881;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.025_ADNI002S5178.mat !!!
# #15/1: FC: 0.26582811249722943; phFCD: 0.1275669794641643;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.02_ADNI002S5178.mat !!!
# #16/1: FC: 0.34033499565285674; phFCD: 0.1283149734802122;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.015_ADNI002S5178.mat !!!
# #17/1: FC: 0.2459505952896612; phFCD: 0.45512035903712766;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.01_ADNI002S5178.mat !!!
# #18/1: FC: 0.30384503261174656; phFCD: 0.10920712634298929;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.005_ADNI002S5178.mat !!!
# #19/1: FC: 0.28672420119643083; phFCD: 0.13103495172038626;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.0_ADNI002S5178.mat !!!
# #20/1: FC: 0.28224988703704607; phFCD: 0.16190670474636204;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.005_ADNI002S5178.mat !!!
# #21/1: FC: 0.31114406342921375; phFCD: 0.1357949136406909;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.01_ADNI002S5178.mat !!!
# #22/1: FC: 0.30487477091095183; phFCD: 0.1638106895144839;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.015_ADNI002S5178.mat !!!
# #23/1: FC: 0.247535242560611; phFCD: 0.441656466748266;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.02_ADNI002S5178.mat !!!
# #24/1: FC: 0.20905199020189208; phFCD: 0.16952264381884952;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.025_ADNI002S5178.mat !!!
# #25/1: FC: 0.08342361607907148; phFCD: 0.3447572419420644;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.03_ADNI002S5178.mat !!!
# #26/1: FC: 0.16785120549593027; phFCD: 0.18665850673194617;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.035_ADNI002S5178.mat !!!
# #27/1: FC: 0.20849671727864422; phFCD: 0.06759145926832588;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.04_ADNI002S5178.mat !!!
# #28/1: FC: 0.3090273093392107; phFCD: 0.1594587243302054;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.045_ADNI002S5178.mat !!!
# #29/1: FC: 0.2318270044872147; phFCD: 0.14429484564123496;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.05_ADNI002S5178.mat !!!
# #30/1: FC: 0.14507995608996602; phFCD: 0.09649122807017546;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.055_ADNI002S5178.mat !!!
# #31/1: FC: 0.2958907441427173; phFCD: 0.16938664490684074;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.06_ADNI002S5178.mat !!!
# #32/1: FC: 0.2869928999620109; phFCD: 0.15320277437780505;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.065_ADNI002S5178.mat !!!
# #33/1: FC: 0.19933287734224228; phFCD: 0.06398748810009525;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.07_ADNI002S5178.mat !!!
# #34/1: FC: 0.23128899619251522; phFCD: 0.05453556371549029;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.075_ADNI002S5178.mat !!!
# #35/1: FC: 0.2179828670667161; phFCD: 0.09696722426220594;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.08_ADNI002S5178.mat !!!
# #36/1: FC: 0.23822893038651477; phFCD: 0.24207806337549304;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.085_ADNI002S5178.mat !!!
# #37/1: FC: 0.1134155992936805; phFCD: 0.23459812321501433;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.09_ADNI002S5178.mat !!!
# #38/1: FC: 0.24486528177800337; phFCD: 0.20950632394940838;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.095_ADNI002S5178.mat !!!
# #39/1: FC: 0.33292274917718456; phFCD: 0.09594723242214065;
#
#
#
# #####################################################################################################
# # Results (in (-0.1, 0.095)):
# #####################################################################################################
#
#
# DONE!!!
#
#
# ###################################################################
# # Fitting with ParmSeep
# ###################################################################
#
#
#
# *************** Starting: optim1D.distanceForAll_Parms *****************
#
#
# tc(1 subjects): each entry has N=78 regions
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fNeuro_emp_ADNI002S6456.mat !!!
#
#
#  ====================== Model Simulations ======================
#
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.1_ADNI002S6456.mat !!!
# #0/1: FC: 0.24868066085939672; phFCD: 0.1391948864409085;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.095_ADNI002S6456.mat !!!
# #1/1: FC: 0.3045390362021183; phFCD: 0.07928736570107442;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.09_ADNI002S6456.mat !!!
# #2/1: FC: 0.20147836629501875; phFCD: 0.05616755065959475;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.085_ADNI002S6456.mat !!!
# #3/1: FC: 0.25055145432329046; phFCD: 0.06888344893240861;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.08_ADNI002S6456.mat !!!
# #4/1: FC: 0.24153857058267217; phFCD: 0.10798313613491095;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.075_ADNI002S6456.mat !!!
# #5/1: FC: 0.16826494282791732; phFCD: 0.2331701346389229;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.07_ADNI002S6456.mat !!!
# #6/1: FC: 0.25512437241308444; phFCD: 0.19692642458860332;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.065_ADNI002S6456.mat !!!
# #7/1: FC: 0.24323563217337502; phFCD: 0.08187134502923976;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.06_ADNI002S6456.mat !!!
# #8/1: FC: 0.23115617281194586; phFCD: 0.19903440772473824;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.055_ADNI002S6456.mat !!!
# #9/1: FC: 0.1949358824747387; phFCD: 0.05045559635522917;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.05_ADNI002S6456.mat !!!
# #10/1: FC: 0.20626280739937922; phFCD: 0.09309125526995787;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.045_ADNI002S6456.mat !!!
# #11/1: FC: 0.10609118582095463; phFCD: 0.14198286413708688;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.04_ADNI002S6456.mat !!!
# #12/1: FC: 0.25618525450925483; phFCD: 0.24445804433564533;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.035_ADNI002S6456.mat !!!
# #13/1: FC: 0.19533591481381324; phFCD: 0.29858561131510947;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.03_ADNI002S6456.mat !!!
# #14/1: FC: 0.16535071546414926; phFCD: 0.04929960560315519;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.025_ADNI002S6456.mat !!!
# #15/1: FC: 0.20306032694140666; phFCD: 0.17618659050727592;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.02_ADNI002S6456.mat !!!
# #16/1: FC: 0.17517070679847227; phFCD: 0.17271861825105397;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.015_ADNI002S6456.mat !!!
# #17/1: FC: 0.16898366756538893; phFCD: 0.061879504963960275;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.01_ADNI002S6456.mat !!!
# #18/1: FC: 0.19285607506688446; phFCD: 0.08357133142934856;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.005_ADNI002S6456.mat !!!
# #19/1: FC: 0.2533955178729188; phFCD: 0.3144294845641235;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.0_ADNI002S6456.mat !!!
# #20/1: FC: 0.1593541920694781; phFCD: 0.4844961240310078;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.005_ADNI002S6456.mat !!!
# #21/1: FC: 0.28965773708082776; phFCD: 0.1732626138990888;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.01_ADNI002S6456.mat !!!
# #22/1: FC: 0.21362936780825031; phFCD: 0.6113151094791242;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.015_ADNI002S6456.mat !!!
# #23/1: FC: 0.17753154944534996; phFCD: 0.40711274309805523;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.02_ADNI002S6456.mat !!!
# #24/1: FC: 0.1901068985613991; phFCD: 0.09234326125391001;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.025_ADNI002S6456.mat !!!
# #25/1: FC: 0.23244159683059695; phFCD: 0.3924248606011152;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.03_ADNI002S6456.mat !!!
# #26/1: FC: 0.2285725229385114; phFCD: 0.4407044743642051;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.035_ADNI002S6456.mat !!!
# #27/1: FC: 0.23511337365185148; phFCD: 0.5360397116823066;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.04_ADNI002S6456.mat !!!
# #28/1: FC: 0.3119593000466086; phFCD: 0.6360669114647083;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.045_ADNI002S6456.mat !!!
# #29/1: FC: 0.2583405866062695; phFCD: 0.9129606963144294;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.05_ADNI002S6456.mat !!!
# #30/1: FC: 0.22173071686885662; phFCD: 0.9344485244118047;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.055_ADNI002S6456.mat !!!
# #31/1: FC: 0.28133758630971123; phFCD: 0.9973480212158303;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.06_ADNI002S6456.mat !!!
# #32/1: FC: 0.24030088163445001; phFCD: 0.9973480212158303;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.065_ADNI002S6456.mat !!!
# #33/1: FC: 0.23059889269091585; phFCD: 0.9979600163198694;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.07_ADNI002S6456.mat !!!
# #34/1: FC: 0.23464626013477252; phFCD: 1.0;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.075_ADNI002S6456.mat !!!
# #35/1: FC: 0.2950655423816768; phFCD: 1.0;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.08_ADNI002S6456.mat !!!
# #36/1: FC: 0.20783054486490554; phFCD: 1.0;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.085_ADNI002S6456.mat !!!
# #37/1: FC: 0.24911663227202935; phFCD: 1.0;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.09_ADNI002S6456.mat !!!
# #38/1: FC: 0.3285183535276065; phFCD: 1.0;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.095_ADNI002S6456.mat !!!
# #39/1: FC: 0.2508489044851945; phFCD: 1.0;
#
#
#
# #####################################################################################################
# # Results (in (-0.1, 0.095)):
# #####################################################################################################
#
#
# DONE!!!
#
#
# ###################################################################
# # Fitting with ParmSeep
# ###################################################################
#
#
#
# *************** Starting: optim1D.distanceForAll_Parms *****************
#
#
# tc(1 subjects): each entry has N=78 regions
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fNeuro_emp_ADNI003S6259.mat !!!
#
#
#  ====================== Model Simulations ======================
#
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.1_ADNI003S6259.mat !!!
# #0/1: FC: 0.22451801444488784; phFCD: 0.10743914048687608;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.095_ADNI003S6259.mat !!!
# #1/1: FC: 0.16033132014888565; phFCD: 0.13042295661634706;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.09_ADNI003S6259.mat !!!
# #2/1: FC: 0.1568077035057598; phFCD: 0.26859785121719026;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.085_ADNI003S6259.mat !!!
# #3/1: FC: 0.1316915205843582; phFCD: 0.24826601387188907;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.08_ADNI003S6259.mat !!!
# #4/1: FC: 0.0820500047429113; phFCD: 0.17985856113151094;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.075_ADNI003S6259.mat !!!
# #5/1: FC: 0.14765490167350562; phFCD: 0.1999864001087991;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.07_ADNI003S6259.mat !!!
# #6/1: FC: 0.19145109557088164; phFCD: 0.20801033591731266;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.065_ADNI003S6259.mat !!!
# #7/1: FC: 0.1852597144879331; phFCD: 0.19964640282877733;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.06_ADNI003S6259.mat !!!
# #8/1: FC: 0.13359225546905276; phFCD: 0.31701346389228885;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.055_ADNI003S6259.mat !!!
# #9/1: FC: 0.2625504657225057; phFCD: 0.16469468244254049;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.05_ADNI003S6259.mat !!!
# #10/1: FC: 0.2116533800077833; phFCD: 0.2022983816129471;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.045_ADNI003S6259.mat !!!
# #11/1: FC: 0.196827802774004; phFCD: 0.1663946688426493;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.04_ADNI003S6259.mat !!!
# #12/1: FC: 0.23759870414760018; phFCD: 0.1298789609683123;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.035_ADNI003S6259.mat !!!
# #13/1: FC: 0.1829019718426614; phFCD: 0.13219094247246027;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.03_ADNI003S6259.mat !!!
# #14/1: FC: 0.26553488706697237; phFCD: 0.18638650890792874;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.025_ADNI003S6259.mat !!!
# #15/1: FC: 0.16578383084394; phFCD: 0.3041615667074663;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.02_ADNI003S6259.mat !!!
# #16/1: FC: 0.22669208947657316; phFCD: 0.15272677818577451;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.015_ADNI003S6259.mat !!!
# #17/1: FC: 0.21406523826296145; phFCD: 0.22990616075071402;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.01_ADNI003S6259.mat !!!
# #18/1: FC: 0.10429989930467405; phFCD: 0.2135862913096695;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.005_ADNI003S6259.mat !!!
# #19/1: FC: 0.20205193391698317; phFCD: 0.051815585475316284;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.0_ADNI003S6259.mat !!!
# #20/1: FC: 0.17614399888103077; phFCD: 0.04977560179518564;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.005_ADNI003S6259.mat !!!
# #21/1: FC: 0.2792660745633747; phFCD: 0.16632666938664492;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.01_ADNI003S6259.mat !!!
# #22/1: FC: 0.2616381005469374; phFCD: 0.3518971848225214;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.015_ADNI003S6259.mat !!!
# #23/1: FC: 0.2269892552814581; phFCD: 0.2732898136814905;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.02_ADNI003S6259.mat !!!
# #24/1: FC: 0.13238625525781741; phFCD: 0.18230654154766762;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.025_ADNI003S6259.mat !!!
# #25/1: FC: 0.2137398812785525; phFCD: 0.3412892696858425;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.03_ADNI003S6259.mat !!!
# #26/1: FC: 0.1704873829571305; phFCD: 0.05072759417924655;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.035_ADNI003S6259.mat !!!
# #27/1: FC: 0.24078066899683903; phFCD: 0.07139942880456951;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.04_ADNI003S6259.mat !!!
# #28/1: FC: 0.1708768241972131; phFCD: 0.1989664082687339;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.045_ADNI003S6259.mat !!!
# #29/1: FC: 0.1509615318405394; phFCD: 0.14096287229702162;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.05_ADNI003S6259.mat !!!
# #30/1: FC: 0.19956947495215616; phFCD: 0.28892968856249146;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.055_ADNI003S6259.mat !!!
# #31/1: FC: 0.2570575275850278; phFCD: 0.09213926288589694;
#
# ...
# #29/1: FC: 0.12428019485500545; phFCD: 0.1369509043927648;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.05_ADNI037S4214.mat !!!
# #30/1: FC: 0.13511466900172353; phFCD: 0.037739698082415285;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.055_ADNI037S4214.mat !!!
# #31/1: FC: 0.0967429940990341; phFCD: 0.5892832857337141;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.06_ADNI037S4214.mat !!!
# #32/1: FC: 0.0261931104468124; phFCD: 0.496532027743778;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.065_ADNI037S4214.mat !!!
# #33/1: FC: 0.2398821668724774; phFCD: 0.6016591867265062;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.07_ADNI037S4214.mat !!!
# #34/1: FC: 0.2141032304686409; phFCD: 0.9743642050863593;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.075_ADNI037S4214.mat !!!
# #35/1: FC: 0.20070127973196825; phFCD: 0.21562627498980014;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.08_ADNI037S4214.mat !!!
# #36/1: FC: 0.11870878125194408; phFCD: 0.9374405004759961;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.085_ADNI037S4214.mat !!!
# #37/1: FC: 0.20065227649785636; phFCD: 0.9783761729906161;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.09_ADNI037S4214.mat !!!
# #38/1: FC: 0.1395025486162674; phFCD: 0.9966000271997825;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.095_ADNI037S4214.mat !!!
# #39/1: FC: 0.17093931319387315; phFCD: 0.9734802121583028;
#
#
#
# #####################################################################################################
# # Results (in (-0.1, 0.095)):
# #####################################################################################################
#
#
# DONE!!!
#
#
# ###################################################################
# # Fitting with ParmSeep
# ###################################################################
#
#
#
# *************** Starting: optim1D.distanceForAll_Parms *****************
#
#
# tc(1 subjects): each entry has N=78 regions
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fNeuro_emp_ADNI100S4556.mat !!!
#
#
#  ====================== Model Simulations ======================
#
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.1_ADNI100S4556.mat !!!
# #0/1: FC: 0.20183824475316964; phFCD: 0.14932680538555693;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.095_ADNI100S4556.mat !!!
# #1/1: FC: 0.1657478454888922; phFCD: 0.18053855569155441;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.09_ADNI100S4556.mat !!!
# #2/1: FC: 0.14456611354940105; phFCD: 0.14579083367333062;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.085_ADNI100S4556.mat !!!
# #3/1: FC: 0.1917232238773413; phFCD: 0.6418468652250782;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.08_ADNI100S4556.mat !!!
# #4/1: FC: 0.1900422313847942; phFCD: 0.11906704746362023;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.075_ADNI100S4556.mat !!!
# #5/1: FC: 0.22930856092971616; phFCD: 0.10179518563851492;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.07_ADNI100S4556.mat !!!
# #6/1: FC: 0.2075454028495235; phFCD: 0.6917584659322725;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.065_ADNI100S4556.mat !!!
# #7/1: FC: 0.19882701171189304; phFCD: 0.1525907792737658;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.06_ADNI100S4556.mat !!!
# #8/1: FC: 0.1308304092598871; phFCD: 0.16081871345029242;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.055_ADNI100S4556.mat !!!
# #9/1: FC: 0.15230981949671643; phFCD: 0.08581531347749216;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.05_ADNI100S4556.mat !!!
# #10/1: FC: 0.1573949388291116; phFCD: 0.36311709506323947;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.045_ADNI100S4556.mat !!!
# #11/1: FC: 0.12285020376734916; phFCD: 0.474500203998368;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.04_ADNI100S4556.mat !!!
# #12/1: FC: 0.10558805952458857; phFCD: 0.12851897184822525;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.035_ADNI100S4556.mat !!!
# #13/1: FC: 0.11241599009365504; phFCD: 0.4381884944920441;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.03_ADNI100S4556.mat !!!
# #14/1: FC: 0.16248667101789493; phFCD: 0.17829457364341084;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.025_ADNI100S4556.mat !!!
# #15/1: FC: 0.17656695222294977; phFCD: 0.4405684754521964;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.02_ADNI100S4556.mat !!!
# #16/1: FC: 0.15225360681344297; phFCD: 0.1334149326805385;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.015_ADNI100S4556.mat !!!
# #17/1: FC: 0.1737876274942476; phFCD: 0.11219910240718078;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.01_ADNI100S4556.mat !!!
# #18/1: FC: 0.2443450421153869; phFCD: 0.09288725690194477;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_-0.005_ADNI100S4556.mat !!!
# #19/1: FC: 0.10629431870153493; phFCD: 0.5159118727050184;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.0_ADNI100S4556.mat !!!
# #20/1: FC: 0.16523730459491606; phFCD: 0.2836257309941521;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.005_ADNI100S4556.mat !!!
# #21/1: FC: 0.17670107954048386; phFCD: 0.09961920304637567;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.01_ADNI100S4556.mat !!!
# #22/1: FC: 0.17910953964334914; phFCD: 0.43839249286005705;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.015_ADNI100S4556.mat !!!
# #23/1: FC: 0.15421049261994058; phFCD: 0.4266965864273086;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.02_ADNI100S4556.mat !!!
# #24/1: FC: 0.17420922273815231; phFCD: 0.18013055895552832;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.025_ADNI100S4556.mat !!!
# #25/1: FC: 0.15737082585054732; phFCD: 0.6388548891608867;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.03_ADNI100S4556.mat !!!
# #26/1: FC: 0.17231013508331205; phFCD: 0.24201006391948865;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.035_ADNI100S4556.mat !!!
# #27/1: FC: 0.13619440774016964; phFCD: 0.49490004079967365;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.04_ADNI100S4556.mat !!!
# #28/1: FC: 0.10783420945018643; phFCD: 0.07445940432476539;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.045_ADNI100S4556.mat !!!
# #29/1: FC: 0.10548459525800008; phFCD: 0.23493812049503604;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.05_ADNI100S4556.mat !!!
# #30/1: FC: 0.14208753053450185; phFCD: 0.04283965728274175;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.055_ADNI100S4556.mat !!!
# #31/1: FC: 0.1561887944618464; phFCD: 0.12899496804025568;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.06_ADNI100S4556.mat !!!
# #32/1: FC: 0.22523538278394376; phFCD: 0.21923024615803077;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.065_ADNI100S4556.mat !!!
# #33/1: FC: 0.21318520187127582; phFCD: 0.4137766897864817;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.07_ADNI100S4556.mat !!!
# #34/1: FC: 0.15161954349772735; phFCD: 0.19386644906840744;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.075_ADNI100S4556.mat !!!
# #35/1: FC: 0.1637886873812172; phFCD: 0.467156262749898;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.08_ADNI100S4556.mat !!!
# #36/1: FC: 0.18249653663820767; phFCD: 0.0933632530939752;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.085_ADNI100S4556.mat !!!
# #37/1: FC: 0.1273174966862033; phFCD: 0.2703658370733034;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.09_ADNI100S4556.mat !!!
# #38/1: FC: 0.10486837563383732; phFCD: 0.8234734122127023;
#
# Loading file (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_across_subject_homogeneous_regional_WMH_weight/fitting_a_heterogeneous_between_subjects_current_wmW_0.095_ADNI100S4556.mat !!!
# #39/1: FC: 0.13958341043893646; phFCD: 0.44077247382020945;
#
#
#
# #####################################################################################################
# # Results (in (-0.1, 0.095)):
# #####################################################################################################
#
#
# DONE!!!

# %%
import pickle

# open file for writing, "w" 
f = open("/home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_best_parameters_dictionary_HC.pkl","wb")

# write json object to file
pickle.dump(best_parms_dict, f)

# close file
f.close()



# open file for writing, "w" 
g = open("/home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/heterogeneous_model_fitting_parameters_dictionary_HC.pkl","wb")

# write json object to file
pickle.dump(fitting_parms_dict, g)

# close file
g.close()
