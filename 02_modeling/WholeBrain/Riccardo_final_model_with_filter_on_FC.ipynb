# %%
# Note that all the code is basically taken from Gustavo Patow's WholeBrain module (https://github.com/dagush/WholeBrain)

# Load all the packages needed for analyses
import sys
import numpy as np
import scipy.io as sio
from numba import jit
import matplotlib.pyplot as plt
import pickle


# Set up Hopf as our model 
import WholeBrain.Models.supHopf as Hopf
from WholeBrain.simulate_SimOnly import Tmaxneuronal
Hopf.initialValue = 0.1
neuronalModel = Hopf

# Set up our integrator
import WholeBrain.Integrator_EulerMaruyama as myIntegrator
integrator = myIntegrator
integrator.neuronalModel = neuronalModel
integrator.verbose = False
integrator.clamping = False

# Set up the integration parameters
dt = 5e-5
# tmax is equal to the number of timepoints: 193
tmax= 193
ds = 1e-4
Tmaxneuronal = int((tmax+dt))

import WholeBrain.simulate_SimOnly as simulateBOLD
simulateBOLD.warmUp = True
simulateBOLD.integrator = integrator
simulateBOLD.warmUpFactor = 606./2000.

# Set up the code to obtain the variables we want to maximize similarity to empirical FC
import WholeBrain.Observables.FC as FC
import WholeBrain.Observables.phFCD as phFCD
import WholeBrain.Optimizers.ParmSeep as ParmSeep
ParmSeep.simulateBOLD = simulateBOLD
ParmSeep.integrator = integrator
ParmSeep.verbose = True

# set BOLD filter settings
import WholeBrain.Utils.filteredPowerSpectralDensity as filtPowSpectr
import WholeBrain.BOLDFilters as BOLDfilters

# These filters are applied in the filtPowSpectr function that we use to extract the intrinsic frequencies of each region.
# They are also applied to process the FC and swFCD and phFCD, but you can set the corresponding parameter to False later on. 0.04-0.07 Hz common to extract intrinsic frequencies
BOLDfilters.flp = 0.04
BOLDfilters.fhi = 0.07
BOLDfilters.TR = 3.0

# %%
# Get the list of names of all regions in the AAL atlas. This is needed to get the right indices, to then filter the FC
import csv
# This is a sublist of labels of the cortical regions that were included in the paper by Demirtas et al. - AAL atlas (78 regions, excluding infratentorial and deep)
with open ('/home/riccardo/ADNI_Hopf/Utils/aal_regions_included.csv', newline='') as f:
    new_reader = csv.reader(f)
    included_regions = list(new_reader)
f.close()

# Get the AAL atlas labels
import nilearn.datasets as datasets
aal = datasets.fetch_atlas_aal()
labels = np.array(aal.labels)
# create an array with the indices of each label (note that these are not the label number from the nifti image)
indices = np.array([i for i in enumerate(labels)])
SC_regions_index = np.isin(labels, included_regions)
# filter the indices that we want based on the position so to have a final SC matrix only for the regions we considered.
SC_78_regions_aal_atlas = indices[SC_regions_index]
filter_SC = np.array([int(i) for i in SC_78_regions_aal_atlas[:,0]])

# Set file path for SC matrix
x_path = '/home/riccardo/ADNI_Hopf/Utils/'
# Load structural connectivity matrix and use it as parameter in Hopf model
xfile = 'SCmatrices88healthy.mat' 
M = sio.loadmat(x_path + xfile); 
mat = M['SCmatrices']
# averaging the SC among subjects
mat0 = np.mean(mat,axis = 0)
# Filter the SC to have just the 78 regions we considered
x_mat0 = mat0[filter_SC]
new_mat0 = x_mat0.T[filter_SC]
# Prevent full synchronization of the model
SCnorm = new_mat0 * 0.2 / new_mat0.max() 
np.fill_diagonal(SCnorm,0)
print('SCnorm.shape={}'.format(new_mat0.shape))    
Hopf.setParms({'SC':SCnorm})

# Set the base_a_value to the same as previous studies
base_a_value = -0.02
# We want to warmup the timeseries before modeling
warmUp = True
warmUpFactor = 10.
# Out:
# SCnorm.shape=(78, 78)

# %%
# Set up useful functions that we will use later

def computeSubjectSimulation():
    # integrator.neuronalModel.SC = C
    # integrator.initBookkeeping(N, Tmaxneuronal)
    if warmUp:
        currObsVars = integrator.warmUpAndSimulate(dt, Tmaxneuronal, TWarmUp=Tmaxneuronal/warmUpFactor)
    else:
        currObsVars = integrator.simulate(dt, Tmaxneuronal)
    # currObsVars = integrator.returnBookkeeping()  # curr_xn, curr_rn
    neuro_act = currObsVars[:,1,:]  # curr_rn
    return neuro_act
    

def loadXBurden(dict_type):

    # ------------------- load and stack the different wm burdens
    if dict_type == 'global':
        homo_wm_file = open('/home/riccardo/ADNI_Hopf/Results/overall_WMH_burden_all_normalized.pkl','rb')
        dict_wm_overall = pickle.load(homo_wm_file)
    
    elif dict_type == 'regional':
        hetero_wm_file = open('/home/riccardo/ADNI_Hopf/Results/normalized_WMH_lobewise_all.pkl','rb')
        dict_wm_overall = pickle.load(hetero_wm_file)
            
    # wm_hc = np.load('/home/riccardo/ADNI_Hopf/Results/wmh_volumes_HC.npy')
    # wm_mci = np.load('/home/riccardo/ADNI_Hopf/Results/wmh_volumes_MCI.npy')
    # wm_overall = np.load('/home/riccardo/ADNI_Hopf/Results/wmh_volumes_ALL.npy')
    # ------------------- load the specific subject wm

    # ------------------- normalize and return
    # wmBurdenNorm = (wmBurden - np.min(wmBurden))/np.ptp(wmBurden)  # Normalize each individual in [0,1]
    #wmBurdenNorm = (wmBurden - np.min(wm_overall))/np.ptp(wm_overall)  # Normalize the whole group in [0,1]
    return dict_wm_overall

# %%
# ------------------------------------------------
# Retrieve the data for all subjects 
# ------------------------------------------------
conditionToStudy = 'mci' # one of 'hc', 'mci', 'all'
mode = 'homogeneous' # one of 'homogeneous', 'heterogeneous'
random = False # set to true if you want to shuffle the wmh weights

# Probably all of this could be done in a different script....
# Load the timeseries for all subjects
all_timeseries = np.load('/home/riccardo/ADNI_Hopf/Results/timeseries_all.npy')
# Get the number of nodes and the Tmax
nNodes, Tmax = all_timeseries.shape[1:]
# Load the subject names for all subjects
all_subjects_names = np.load('/home/riccardo/ADNI_Hopf/Results/subject_list_timeseries_all.npy')
# Load the overall normalized WMH burden for each subject
global_wm_overall = loadXBurden('global')
# Load the normalized regional WMH burden for each subject
regional_wm_overall = loadXBurden('regional')
# create a unified dictionary to make sure we don't make mistakes when filtering
all_dictionary = {k:{'timeseries': all_timeseries[n],
                     'total_WMH_load': global_wm_overall[k],
                     'regional_WMH_load': regional_wm_overall[k]} for n, k in np.ndenumerate(all_subjects_names)}

if conditionToStudy == 'hc':

    #load the names of HC
    subjects_names = np.load('/home/riccardo/ADNI_Hopf/Results/subject_list_timeseries_HC.npy')
    # filter the unified dictionary to retain just HC
    all_fMRI = {k:v['timeseries'] for k, v in all_dictionary.items() if k in subjects_names}
    nsubjects = len(all_fMRI) 

    if mode == 'homogeneous':
        wmBurden_dict = {k:v['total_WMH_load'] for k, v in all_dictionary.items() if k in subjects_names}
        wmBurden = np.array([v for v in wmBurden_dict.values()])

    elif mode == 'heterogeneous':
        wmBurden_dict ={k:v['regional_WMH_load'] for k, v in all_dictionary.items() if k in subjects_names} 
        wmBurden = np.array([v for v in wmBurden_dict.values()])
        
elif conditionToStudy == 'mci':

    #load the names of MCI
    subjects_names = np.load('/home/riccardo/ADNI_Hopf/Results/subject_list_timeseries_MCI.npy')
    # filter the unified dictionary to retain just MCI
    all_fMRI = {k:v['timeseries'] for k, v in all_dictionary.items() if k in subjects_names}
    nsubjects = len(all_fMRI) 

    if mode == 'homogeneous':
        wmBurden_dict = {k:v['total_WMH_load'] for k, v in all_dictionary.items() if k in subjects_names}
        wmBurden = np.array([v for v in wmBurden_dict.values()])

    elif mode == 'heterogeneous':
        wmBurden_dict ={k:v['regional_WMH_load'] for k, v in all_dictionary.items() if k in subjects_names} 
        wmBurden = np.array([v for v in wmBurden_dict.values()])

if random:
    np.random.shuffle(wmBurden)


# We haven't filtered in Nilearn, so we are going to filter now.
distanceSettings = {'FC': (FC, True), 'phFCD': (phFCD, True)}

simulateBOLD.TR = 3.  # Recording interval: 1 sample every 3 seconds
simulateBOLD.dt = 0.1 * simulateBOLD.TR / 2.
simulateBOLD.Tmax = Tmax  # This is the length, in seconds
simulateBOLD.dtt = simulateBOLD.TR  # We are not using milliseconds
simulateBOLD.t_min = 10 * simulateBOLD.TR
# simulateBOLD.recomputeTmaxneuronal() <- do not update Tmaxneuronal this way!
# simulateBOLD.warmUpFactor = 6.
simulateBOLD.Tmaxneuronal = (Tmax-1) * simulateBOLD.TR + 30
integrator.ds = simulateBOLD.TR  # record every TR millisecond

timeseries_condition_4freq = np.array([v for k,v in all_fMRI.items()])
# Hopf.beta = 0.01
f_diff = filtPowSpectr.filtPowSpetraMultipleSubjects(timeseries_condition_4freq, TR=3.)  # should be baseline_group_ts .. or baseling_group[0].reshape((1,52,193))
f_diff[np.where(f_diff == 0)] = np.mean(f_diff[np.where(f_diff != 0)])  # f_diff(find(f_diff==0))=mean(f_diff(find(f_diff~=0)))

Hopf.omega = 2 * np.pi * f_diff

print("ADHopf Setup done!")
# Out:
# filtPowSpetraMultipleSubjects: subject 0 (of 18)
# filtPowSpetraMultipleSubjects: subject 1 (of 18)
# filtPowSpetraMultipleSubjects: subject 2 (of 18)
# filtPowSpetraMultipleSubjects: subject 3 (of 18)
# filtPowSpetraMultipleSubjects: subject 4 (of 18)
# filtPowSpetraMultipleSubjects: subject 5 (of 18)
# filtPowSpetraMultipleSubjects: subject 6 (of 18)
# filtPowSpetraMultipleSubjects: subject 7 (of 18)
# filtPowSpetraMultipleSubjects: subject 8 (of 18)
# filtPowSpetraMultipleSubjects: subject 9 (of 18)
# filtPowSpetraMultipleSubjects: subject 10 (of 18)
# filtPowSpetraMultipleSubjects: subject 11 (of 18)
# filtPowSpetraMultipleSubjects: subject 12 (of 18)
# filtPowSpetraMultipleSubjects: subject 13 (of 18)
# filtPowSpetraMultipleSubjects: subject 14 (of 18)
# filtPowSpetraMultipleSubjects: subject 15 (of 18)
# filtPowSpetraMultipleSubjects: subject 16 (of 18)
# filtPowSpetraMultipleSubjects: subject 17 (of 18)
# ADHopf Setup done!

# %%
# Change the file to where you want to save results
outFilePath = f'/home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/10iterations_{mode}_model' 


def fittingPipeline_homogeneous(subj_fMRI,
                    distanceSettings,  # This is a dictionary of {name: (distance module, apply filters bool)}
                    wms, wmBurden, subjectName):
    print("\n\n###################################################################")
    print("# Fitting with ParmSeep")
    print("###################################################################\n")
    # Now, optimize all we (G) values: determine optimal G to work with
    wmParms = [{'a': base_a_value + (wmW * wmBurden)} for wmW in wmWs]
    fitting = ParmSeep.distanceForAll_Parms(subj_fMRI,
                                            wmWs, 
                                            wmParms,
                                            NumSimSubjects=10,
                                            distanceSettings=distanceSettings,
                                            parmLabel=f'a_{mode}_{conditionToStudy}_random_{random}',
                                            fileNameSuffix='_'+subjectName,
                                            outFilePath=outFilePath)

    optimal = {sd: distanceSettings[sd][0].findMinMax(fitting[sd]) for sd in distanceSettings}
    return optimal, fitting

# %%
subjectName = ''
warmUp = True
warmUpFactor = 10.
Hopf.setParms({'we': 2.9})

# This is the set of weights I used for all the simulations:
# Set of weights for homogeneous model: wmWs = np.round(np.arange(-0.09,0.05,0.001), 4)
wmWs = np.round(np.arange(-0.08,0.05,0.001), 4)


def fittingPipeline_heterogeneous(all_fMRI, wmBurden, wmWs):

    best_parameters_dict = {}
    fitting_parameters_dict = {}

    for subjectName, subj_ts in all_fMRI.items():

        subj_fMRI = {subjectName:subj_ts}
        wmBurden_subj = wmBurden_dict[subjectName]
        best_parameters, fitting_parameters = fittingPipeline_homogeneous(subj_fMRI=subj_fMRI, distanceSettings=distanceSettings, subjectName=subjectName, wms=wmWs, wmBurden = wmBurden_subj)
        best_parameters_dict[subjectName] = best_parameters
        fitting_parameters_dict[subjectName] = fitting_parameters

    return best_parameters_dict, fitting_parameters_dict

# %% [markdown]
# Due to the memory load the simulations cannot be run all in the same batch, at least not in Jupyter for VSCode where I am working at the moment on my personal laptop. Luckily the code can be run in batches, this means that we can subdivide the whole simulation into 3 separate batches and run it 3 times. Each time you have to close down the notebook and reopen it. After the simulation is run and the files are saved for all patients we can just re-run the functions altogether and this will just load the already computed simulations. Also this crashes VSCode ( [it is a known bug](https://github.com/microsoft/vscode/issues/155242)), but we are still able to run the code, just we won't see any output on the screen, but we can save a combined dictionary as a pickle file.

# %%
best_parms_dict, fitting_parms_dict = fittingPipeline_heterogeneous(all_fMRI=all_fMRI, wmBurden=wmBurden, wmWs=wmWs)
# Out:
# ###################################################################
# # Fitting with ParmSeep
# ###################################################################
#
#
#
# *************** Starting: optim1D.distanceForAll_Parms *****************
#
#
# tc(1 subjects): each entry has N=78 regions
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/10iterations_homogeneous_model/fNeuro_emp_ADNI002S1155.mat
#    Processing signal 1/1 Subject: ADNI002S1155 (78x193) -> computed in 2.937501776003046 seconds
#
#
#  ====================== Model Simulations ======================
#
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/10iterations_homogeneous_model/fitting_a_homogeneous_mci_random_False-0.08_ADNI002S1155.mat
#    --- BEGIN TIME @ a_homogeneous_mci_random_False=-0.08 ---
# Current a is: -0.0276904
# Current G is: 2.9
#    Simulating a_homogeneous_mci_random_False=-0.08 -> subject 0/10!!!
#    Simulating a_homogeneous_mci_random_False=-0.08 -> subject 1/10!!!
#    Simulating a_homogeneous_mci_random_False=-0.08 -> subject 2/10!!!
#    Simulating a_homogeneous_mci_random_False=-0.08 -> subject 3/10!!!
#    Simulating a_homogeneous_mci_random_False=-0.08 -> subject 4/10!!!
#    Simulating a_homogeneous_mci_random_False=-0.08 -> subject 5/10!!!
#    Simulating a_homogeneous_mci_random_False=-0.08 -> subject 6/10!!!
#    Simulating a_homogeneous_mci_random_False=-0.08 -> subject 7/10!!!
#    Simulating a_homogeneous_mci_random_False=-0.08 -> subject 8/10!!!
#    Simulating a_homogeneous_mci_random_False=-0.08 -> subject 9/10!!!
#    Processing signal 1/10 Subject: 0 (78x193) -> computed in 2.7601056450002943 seconds
#    Processing signal 2/10 Subject: 1 (78x193) -> computed in 2.670871429996623 seconds
#    Processing signal 3/10 Subject: 2 (78x193) -> computed in 2.598618925003393 seconds
#    Processing signal 4/10 Subject: 3 (78x193) -> computed in 2.59892147800565 seconds
#    Processing signal 5/10 Subject: 4 (78x193) -> computed in 2.6911635669966927 seconds
#    Processing signal 6/10 Subject: 5 (78x193) -> computed in 2.6184048550057923 seconds
#    Processing signal 7/10 Subject: 6 (78x193) -> computed in 2.568290570998215 seconds
#    Processing signal 8/10 Subject: 7 (78x193) -> computed in 2.5072448649953003 seconds
#    Processing signal 9/10 Subject: 8 (78x193) -> computed in 2.5026177629988524 seconds
#    Processing signal 10/10 Subject: 9 (78x193) -> computed in 2.5334568710022722 seconds
#    --- TOTAL TIME: 30.89129001100082 seconds ---
# #0/1: FC: 0.2023042245410074; phFCD: 0.07157622739018088;
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/10iterations_homogeneous_model/fitting_a_homogeneous_mci_random_False-0.079_ADNI002S1155.mat
#    --- BEGIN TIME @ a_homogeneous_mci_random_False=-0.079 ---
# Current a is: -0.02759427
# Current G is: 2.9
#    Simulating a_homogeneous_mci_random_False=-0.079 -> subject 0/10!!!
#    Simulating a_homogeneous_mci_random_False=-0.079 -> subject 1/10!!!
#    Simulating a_homogeneous_mci_random_False=-0.079 -> subject 2/10!!!
#    Simulating a_homogeneous_mci_random_False=-0.079 -> subject 3/10!!!
#    Simulating a_homogeneous_mci_random_False=-0.079 -> subject 4/10!!!
#    Simulating a_homogeneous_mci_random_False=-0.079 -> subject 5/10!!!
#    Simulating a_homogeneous_mci_random_False=-0.079 -> subject 6/10!!!
#    Simulating a_homogeneous_mci_random_False=-0.079 -> subject 7/10!!!
#    Simulating a_homogeneous_mci_random_False=-0.079 -> subject 8/10!!!
#    Simulating a_homogeneous_mci_random_False=-0.079 -> subject 9/10!!!
#    Processing signal 1/10 Subject: 0 (78x193) -> computed in 2.747226692001277 seconds
#    Processing signal 2/10 Subject: 1 (78x193) -> computed in 5.227536981001322 seconds
#    Processing signal 3/10 Subject: 2 (78x193) -> computed in 3.5568252000011853 seconds
#    Processing signal 4/10 Subject: 3 (78x193) -> computed in 3.9752631779992953 seconds
#    Processing signal 5/10 Subject: 4 (78x193) -> computed in 3.6422476820007432 seconds
#    Processing signal 6/10 Subject: 5 (78x193) -> computed in 3.5285957460000645 seconds
#    Processing signal 7/10 Subject: 6 (78x193) -> computed in 3.28220082000189 seconds
#    Processing signal 8/10 Subject: 7 (78x193) -> computed in 3.4110279509986867 seconds
#    Processing signal 9/10 Subject: 8 (78x193) -> computed in 3.443474621999485 seconds
#    Processing signal 10/10 Subject: 9 (78x193) -> computed in 3.497029026002565 seconds
#    --- TOTAL TIME: 38.27174546199967 seconds ---
# #1/1: FC: 0.23039251607151964; phFCD: 0.03821569427444582;
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/10iterations_homogeneous_model/fitting_a_homogeneous_mci_random_False-0.078_ADNI002S1155.mat
#    --- BEGIN TIME @ a_homogeneous_mci_random_False=-0.078 ---
# Current a is: -0.02749814
# Current G is: 2.9
#    Simulating a_homogeneous_mci_random_False=-0.078 -> subject 0/10!!!
#    Simulating a_homogeneous_mci_random_False=-0.078 -> subject 1/10!!!
#    Simulating a_homogeneous_mci_random_False=-0.078 -> subject 2/10!!!
#    Simulating a_homogeneous_mci_random_False=-0.078 -> subject 3/10!!!
#    Simulating a_homogeneous_mci_random_False=-0.078 -> subject 4/10!!!
#    Simulating a_homogeneous_mci_random_False=-0.078 -> subject 5/10!!!
#    Simulating a_homogeneous_mci_random_False=-0.078 -> subject 6/10!!!
#    Simulating a_homogeneous_mci_random_False=-0.078 -> subject 7/10!!!
#    Simulating a_homogeneous_mci_random_False=-0.078 -> subject 8/10!!!
#    Simulating a_homogeneous_mci_random_False=-0.078 -> subject 9/10!!!
#    Processing signal 1/10 Subject: 0 (78x193) -> computed in 3.8531166070024483 seconds
#    Processing signal 2/10 Subject: 1 (78x193) -> computed in 3.5718390379988705 seconds
#    Processing signal 3/10 Subject: 2 (78x193) -> computed in 3.5247688529998413 seconds
#    Processing signal 4/10 Subject: 3 (78x193) -> computed in 3
seconds
#    Processing signal 2/10 Subject: 1 (78x193) -> computed in 2.6177372120000655 seconds
#    Processing signal 3/10 Subject: 2 (78x193) -> computed in 2.611789812988718 seconds
#    Processing signal 4/10 Subject: 3 (78x193) -> computed in 2.6213619020127226 seconds
#    Processing signal 5/10 Subject: 4 (78x193) -> computed in 2.61347838799702 seconds
#    Processing signal 6/10 Subject: 5 (78x193) -> computed in 2.558278287993744 seconds
#    Processing signal 7/10 Subject: 6 (78x193) -> computed in 2.6171639680105727 seconds
#    Processing signal 8/10 Subject: 7 (78x193) -> computed in 2.555020029001753 seconds
#    Processing signal 9/10 Subject: 8 (78x193) -> computed in 2.5711256289941957 seconds
#    Processing signal 10/10 Subject: 9 (78x193) -> computed in 2.5933428399875993 seconds
#    --- TOTAL TIME: 27.739247821999015 seconds ---
# #37/1: FC: 0.4089941066229301; phFCD: 0.2599823201414389;
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/10iterations_homogeneous_model/fitting_a_homogeneous_mci_random_False-0.042_ADNI011S6618.mat
#    --- BEGIN TIME @ a_homogeneous_mci_random_False=-0.042 ---
# Current a is: -0.04742894
# Current G is: 2.9
#    Simulating a_homogeneous_mci_random_False=-0.042 -> subject 0/10!!!
#    Simulating a_homogeneous_mci_random_False=-0.042 -> subject 1/10!!!
#    Simulating a_homogeneous_mci_random_False=-0.042 -> subject 2/10!!!
#    Simulating a_homogeneous_mci_random_False=-0.042 -> subject 3/10!!!
#    Simulating a_homogeneous_mci_random_False=-0.042 -> subject 4/10!!!
#    Simulating a_homogeneous_mci_random_False=-0.042 -> subject 5/10!!!
#    Simulating a_homogeneous_mci_random_False=-0.042 -> subject 6/10!!!
#    Simulating a_homogeneous_mci_random_False=-0.042 -> subject 7/10!!!
#    Simulating a_homogeneous_mci_random_False=-0.042 -> subject 8/10!!!
#    Simulating a_homogeneous_mci_random_False=-0.042 -> subject 9/10!!!
#    Processing signal 1/10 Subject: 0 (78x193) -> computed in 2.612632186996052 seconds
#    Processing signal 2/10 Subject: 1 (78x193) -> computed in 2.5401191040000413 seconds
#    Processing signal 3/10 Subject: 2 (78x193) -> computed in 2.5455612130026566 seconds
#    Processing signal 4/10 Subject: 3 (78x193) -> computed in 2.618217513008858 seconds
#    Processing signal 5/10 Subject: 4 (78x193) -> computed in 2.642397718009306 seconds
#    Processing signal 6/10 Subject: 5 (78x193) -> computed in 2.6367084219964454 seconds
#    Processing signal 7/10 Subject: 6 (78x193) -> computed in 2.546496221999405 seconds
#    Processing signal 8/10 Subject: 7 (78x193) -> computed in 2.601636325009167 seconds
#    Processing signal 9/10 Subject: 8 (78x193) -> computed in 2.54157042800216 seconds
#    Processing signal 10/10 Subject: 9 (78x193) -> computed in 2.647325029000058 seconds
#    --- TOTAL TIME: 27.650710051995702 seconds ---
# #38/1: FC: 0.354105306567153; phFCD: 0.2946144430844554;
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/10iterations_homogeneous_model/fitting_a_homogeneous_mci_random_False-0.041_ADNI011S6618.mat
#    --- BEGIN TIME @ a_homogeneous_mci_random_False=-0.041 ---
# Current a is: -0.046775870000000004
# Current G is: 2.9
#    Simulating a_homogeneous_mci_random_False=-0.041 -> subject 0/10!!!
#    Simulating a_homogeneous_mci_random_False=-0.041 -> subject 1/10!!!
#    Simulating a_homogeneous_mci_random_False=-0.041 -> subject 2/10!!!
#    Simulating a_homogeneous_mci_random_False=-0.041 -> subject 3/10!!!
#    Simulating a_homogeneous_mci_random_False=-0.041 -> subject 4/10!!!
#    Simulating a_homogeneous_mci_random_False=-0.041 -> subject 5/10!!!
#    Simulating a_homogeneous_mci_random_False=-0.041 -> subject 6/10!!!
#    Simulating a_homogeneous_mci_random_False=-0.041 -> subject 7/10!!!
#    Simulating a_homogeneous_mci_random_False=-0.041 -> subject 8/10!!!
#    Simulating a_homogeneous_mci_random_False=-0.041 -> subject 9/10!!!
#    Processing signal 1/10 Subject: 0 (78x193) -> computed in 2.6724511879874626 seconds
#    Processing signal 2/10 Subject: 1 (78x193) -> computed in 2.539178189006634 seconds
#    Processing signal 3/10 Subject: 2 (78x193) -> computed in 2.600499910011422 seconds
#    Processing signal 4/10 Subject: 3 (78x193) -> computed in 2.5137913130020024 seconds
#    Processing signal 5/10 Subject: 4 (78x193) -> computed in 2.5785874139983207 seconds
#    Processing signal 6/10 Subject: 5 (78x193) -> computed in 2.5612523240124574 seconds
#    Processing signal 7/10 Subject: 6 (78x193) -> computed in 2.5675762280006893 seconds
#    Processing signal 8/10 Subject: 7 (78x193) -> computed in 2.5652328279975336 seconds
#    Processing signal 9/10 Subject: 8 (78x193) -> computed in 2.568123288001516 seconds
#    Processing signal 10/10 Subject: 9 (78x193) -> computed in 2.5814080279960763 seconds
#    --- TOTAL TIME: 27.520397702013724 seconds ---
# #39/1: FC: 0.34497923852972273; phFCD: 0.24181286549707603;
#
# Computing (@loadOrCompute): /home/riccardo/ADNI_Hopf/Results/G_fitted_to_HC-minimalWMH/10iterations_homogeneous_model/fitting_a_homogeneous_mci_random_False-0.04_ADNI011S6618.mat
#    --- BEGIN TIME @ a_homogeneous_mci_random_False=-0.04 ---
# Current a is: -0.046122800000000005
# Current G is: 2.9
#    Simulating a_homogeneous_mci_random_False=-0.04 -> subject 0/10!!!
#    Simulating a_homogeneous_mci_random_False=-0.04 -> subject 1/10!!!
#    Simulating a_homogeneous_mci_random_False=-0.04 -> subject 2/10!!!
#    Simulating a_homogeneous_mci_random_False=-0.04 -> subject 3/10!!!
#    Simulating a_homogeneous_mci_random_False=-0.04 -> subject 4/10!!!
#    Simulating a_homogeneous_mci_random_False=-0.04 -> subject 5/10!!!
#    Simulating a_homogeneous_mci_random_False=-0.04 -> subject 6/10!!!
#    Simulating a_homogeneous_mci_random_False=-0.04 -> subject 7/10!!!
#    Simulating a_homogeneous_mci_random_False=-0.04 -> subject 8/10!!!
#    Simulating a_homogeneous_mci_random_False=-0.04 -> subject 9/10!!!
#    Processing signal 1/10 Subject: 0 (78x193) -> computed in 2.6235452179971617 seconds
#    Processing signal 2/10 Subject: 1 (78x193) -> computed in 2.5445085170067614 seconds
#    Processing signal 3/10 Subject: 2 (78x193) -> computed in 2.594432517988025 seconds
#    Processing signal 4/10 Subject: 3 (78x193) -> computed in 2.549126117999549 seconds
#    Processing signal 5/10 Subject: 4 (78x193) -> computed in 2.648485318000894 seconds
#    Processing signal 6/10 Subject: 5 (78x193) -> computed in 2.6122206169966375 seconds
#    Processing signal 7/10 Subject: 6 (78x193) -> computed in 2.603122513013659 seconds
#    Processing signal 8/10 Subject: 7 (78x193) -> computed in 2.6013573939999333 seconds
#    Processing signal 9/10 Subject: 8 (78x193) -> computed in 2.532165797005291 seconds
#    Processing signal 10/10 Subject: 9 (78x193)

# %%
if not random:
    # open file for writing, "w" 
    f = open(outFilePath + f"/{mode}_model_best_parameters_dictionary_{conditionToStudy}.pkl","wb")
    # write json object to file
    pickle.dump(best_parms_dict, f)
    # close file
    f.close()
    # open file for writing, "w" 
    g = open(outFilePath + f"/{mode}_model_fitting_parameters_dictionary_{conditionToStudy}.pkl","wb")
    # write json object to file
    pickle.dump(fitting_parms_dict, g)
    # close file
    g.close()

else:
    # open file for writing, "w" 
    f = open(outFilePath + f"/random_{mode}_model_best_parameters_dictionary_{conditionToStudy}.pkl","wb")
    # write json object to file
    pickle.dump(best_parms_dict, f)
    # close file
    f.close()
    # open file for writing, "w" 
    g = open(outFilePath + f"/random_{mode}_model_fitting_parameters_dictionary_{conditionToStudy}.pkl","wb")
    # write json object to file
    pickle.dump(fitting_parms_dict, g)
    # close file
    g.close()
