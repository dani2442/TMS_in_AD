# %%
import numpy as np
from petTOAD_load import * 

layout, subjs = get_layout_subjs()
ts = get_method_ts(subjs[0]).T
# Out:
# Getting the layout...
# Done with the layout...

# %%
window_length = 100; 
C = zeros(p,p,total_session_duration - window_length + 1); 
for t = 1:total_session_duration - window_length + 1 
    C(:,:,t) = corr(X(t:t+window_length-1,:))

# %%
window_length = 15
C = np.zeros((ts.shape[1], ts.shape[1], ts.shape[0]-window_length + 1))
for t in np.arange(ts.shape[0]-window_length + 1):
    C[:,:,t] = np.corrcoef(ts.T[:,t:t+window_length-1])
