# %%
import pandas as pd
import scipy.io as sio
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

# %%
SPINE = Path.cwd().parents[2]
RES_DIR = SPINE / "results"
G_DIR = RES_DIR / "Finding_best_G"
AVG_DIR = G_DIR / "AvgHC"

files = AVG_DIR.glob('*.mat')

# %%
filelist = []
for f in files:
    a = sio.loadmat(f)
    filelist.append(a)

# %%
# Out:
# [{'__header__': b'MATLAB 5.0 MAT-file Platform: posix, Created on: Wed Mar 29 16:56:53 2023',
#   '__version__': '1.0',
#   '__globals__': [],
#   'FC': array([[nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan],
#          ...,
#          [nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan]]),
#   'phFCD': array([[nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]]),
#   'we': array([[6.]])},
#  {'__header__': b'MATLAB 5.0 MAT-file Platform: posix, Created on: Wed Mar 29 16:56:45 2023',
#   '__version__': '1.0',
#   '__globals__': [],
#   'FC': array([[nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan],
#          ...,
#          [nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan],
# ...

# %%
fEmp = sio.loadmat(AVG_DIR / "fNeuro_emp.mat")
f0 = sio.loadmat(AVG_DIR / "fitting_we0.0.mat")

fc_emp = fEmp['FC']
fc_0 = f0['FC'] 
plt.subplot(2,2,1)
plt.imshow(fc_emp)
plt.subplot(2,2,2)
plt.imshow(fc_0)
print(f"FC shape is: {fc.shape[0]} x {fc.shape[1]}")
# Out:
# FC shape is: 200 x 200

# %%
f0
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file Platform: posix, Created on: Wed Mar 29 16:38:30 2023',
#  '__version__': '1.0',
#  '__globals__': [],
#  'FC': array([[ 1.        ,  0.00920087, -0.00986746, ..., -0.04601815,
#          -0.08405588, -0.01855856],
#         [ 0.00920087,  1.        , -0.01367271, ...,  0.16291881,
#          -0.14338705,  0.03984854],
#         [-0.00986746, -0.01367271,  1.        , ...,  0.05235078,
#           0.04736585,  0.05297412],
#         ...,
#         [-0.04601815,  0.16291881,  0.05235078, ...,  1.        ,
#          -0.06362436,  0.02308597],
#         [-0.08405588, -0.14338705,  0.04736585, ..., -0.06362436,
#           1.        ,  0.05966083],
#         [-0.01855856,  0.03984854,  0.05297412, ...,  0.02308597,
#           0.05966083,  1.        ]]),
#  'phFCD': array([[0.98908438, 0.9557269 , 0.89946016, ..., 0.98402414, 0.93963737,
#          0.98322462]]),
#  'we': array([[0.]])}

# %%
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file Platform: posix, Created on: Wed Mar 29 16:32:56 2023',
#  '__version__': '1.0',
#  '__globals__': [],
#  'FC': array([[ 1.        ,  0.27141806,  0.4971487 , ..., -0.03968325,
#           0.02772531, -0.02434086],
#         [ 0.27141806,  1.        ,  0.34247358, ...,  0.03718617,
#           0.07204144,  0.03930791],
#         [ 0.4971487 ,  0.34247358,  1.        , ..., -0.07263528,
#           0.07435604, -0.06523311],
#         ...,
#         [-0.03968325,  0.03718617, -0.07263528, ...,  1.        ,
#           0.43397895,  0.34391944],
#         [ 0.02772531,  0.07204144,  0.07435604, ...,  0.43397895,
#           1.        ,  0.49606662],
#         [-0.02434086,  0.03930791, -0.06523311, ...,  0.34391944,
#           0.49606662,  1.        ]]),
#  'phFCD': array([[0.95650937, 0.83642906, 0.69142863, ..., 0.97624215, 0.91001096,
#          0.97518365]])}
